# %% [markdown]
# # OpenCV Faster R-CNN

# %% [markdown]
# > ## Video Object Detection

# %% [markdown]
# * Pretrained 모델 파일 로드 후 OpenCV 기반 Object Detection 수행

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Video File Download

# %% [markdown]
# * matrix.mp4 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/image/matrix.mp4
# Out:
# --2023-04-17 04:04:05--  https://raw.githubusercontent.com/rusita-ai/pyData/master/image/matrix.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386522 (377K) [application/octet-stream]
# Saving to: ‘matrix.mp4’
#
# matrix.mp4          100%[===================>] 377.46K  --.-KB/s    in 0.005s
#
# 2023-04-17 04:04:05 (80.2 MB/s) - ‘matrix.mp4’ saved [386522/386522]

# %% [markdown]
# * matrix.mp4 확인

# %%
import io
import base64
from IPython.display import HTML

video = io.open('/content/matrix.mp4', 'r+b').read()

encoded = base64.b64encode(video)

HTML(data='''<video width = "70%" controls>
    <source src = "data:video/mp4;base64,{0}" type = "video/mp4"/>
    </video>'''.format(encoded.decode('ascii')))
# Out:
# <video width = "70%" controls>
#     <source src = "data:video/mp4;base64,..." type = "video/mp4"/>
#     </video>

# %% [markdown]
# # II. Video Frame Information

# %% [markdown]
# > ## 1) VideoCapture( )

# %% [markdown]
# * cv2.CAP_PROP_FRAME_COUNT

# %%
import cv2
video_input_path = '/content/matrix.mp4'
cap = cv2.VideoCapture(video_input_path)
frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print('Frame Count:', frame_cnt)
# Out:
# Frame Count: 134

# %% [markdown]
# > ## 2) VideoWriter( )

# %% [markdown]
# * Encoding Codec and FPS and Size

# %%
video_input_path = '/content/matrix.mp4'
video_output_path = '/content/matrix_rcnn.mp4'
cap = cv2.VideoCapture(video_input_path)

codec = cv2.VideoWriter_fourcc(*'XVID')
vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
vid_fps = cap.get(cv2.CAP_PROP_FPS )
vid_writer = cv2.VideoWriter(video_output_path, codec, vid_fps, vid_size)
print('FPS Count:', vid_fps)
print('Video Size:', vid_size)
# Out:
# FPS Count: 30.0
# Video Size: (640, 360)

# %% [markdown]
# # III. Object Detection API Download

# %% [markdown]
# > ## 1) Pretrained Model Download

# %% [markdown]
# * https://github.com/opencv/opencv/wiki/TensorFlow-Object-Detection-API
# * http://download.tensorflow.org/models/object_detection/faster_rcnn_resnet50_coco_2018_01_28.tar.gz
# * faster_rcnn_resnet50_coco_2018_01_28.tar.gz 다운로드

# %%
# !wget http://download.tensorflow.org/models/object_detection/faster_rcnn_resnet50_coco_2018_01_28.tar.gz
# Out:
# --2023-04-17 04:06:53--  http://download.tensorflow.org/models/object_detection/faster_rcnn_resnet50_coco_2018_01_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.253.62.128, 2607:f8b0:4004:c1b::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.253.62.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381355771 (364M) [application/x-tar]
# Saving to: ‘faster_rcnn_resnet50_coco_2018_01_28.tar.gz’
#
# faster_rcnn_resnet5 100%[===================>] 363.69M   272MB/s    in 1.3s
#
# 2023-04-17 04:06:54 (272 MB/s) - ‘faster_rcnn_resnet50_coco_2018_01_28.tar.gz’ saved [381355771/381355771]

# %% [markdown]
# * faster_rcnn_resnet50_coco_2018_01_28.tar.gz 압축해제

# %%
# !tar -xvf faster_rcnn_resnet50_coco_2018_01_28.tar.gz
# Out:
# faster_rcnn_resnet50_coco_2018_01_28/
# faster_rcnn_resnet50_coco_2018_01_28/model.ckpt.index
# faster_rcnn_resnet50_coco_2018_01_28/checkpoint
# faster_rcnn_resnet50_coco_2018_01_28/pipeline.config
# faster_rcnn_resnet50_coco_2018_01_28/model.ckpt.data-00000-of-00001
# faster_rcnn_resnet50_coco_2018_01_28/model.ckpt.meta
# faster_rcnn_resnet50_coco_2018_01_28/saved_model/
# faster_rcnn_resnet50_coco_2018_01_28/saved_model/saved_model.pb
# faster_rcnn_resnet50_coco_2018_01_28/saved_model/variables/
# faster_rcnn_resnet50_coco_2018_01_28/frozen_inference_graph.pb

# %% [markdown]
# * 결과 확인
#   * frozen_inference_graph.pb

# %%
# !ls -l /content/faster_rcnn_resnet50_coco_2018_01_28
# Out:
# total 296068
# -rw-r--r-- 1 345018 5000        77 Feb  1  2018 checkpoint
# -rw-r--r-- 1 345018 5000 120549957 Feb  1  2018 frozen_inference_graph.pb
# -rw-r--r-- 1 345018 5000 176914228 Feb  1  2018 model.ckpt.data-00000-of-00001
# -rw-r--r-- 1 345018 5000     14460 Feb  1  2018 model.ckpt.index
# -rw-r--r-- 1 345018 5000   5675175 Feb  1  2018 model.ckpt.meta
# -rw-r--r-- 1 345018 5000      3240 Feb  1  2018 pipeline.config
# drwxr-xr-x 3 345018 5000      4096 Feb  1  2018 saved_model

# %% [markdown]
# > ## 2) Model Configuration Download

# %% [markdown]
# * https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/faster_rcnn_resnet50_coco_2018_01_28.pbtxt

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/faster_rcnn_resnet50_coco_2018_01_28.pbtxt
# Out:
# --2023-04-17 04:13:13--  https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/faster_rcnn_resnet50_coco_2018_01_28.pbtxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90893 (89K) [text/plain]
# Saving to: ‘faster_rcnn_resnet50_coco_2018_01_28.pbtxt’
#
# faster_rcnn_resnet5 100%[===================>]  88.76K  --.-KB/s    in 0.003s
#
# 2023-04-17 04:13:13 (31.6 MB/s) - ‘faster_rcnn_resnet50_coco_2018_01_28.pbtxt’ saved [90893/90893]

# %% [markdown]
# # IV. Model and Configuration load

# %% [markdown]
# * v2.dnn.readNetFromTensorflow()

# %%
cv_net = cv2.dnn.readNetFromTensorflow('/content/faster_rcnn_resnet50_coco_2018_01_28/frozen_inference_graph.pb',
                                       '/content/faster_rcnn_resnet50_coco_2018_01_28.pbtxt')

# %% [markdown]
# # V. Class ID Setting

# %% [markdown]
# * COCO Dataset

# %% [markdown]
# > ## 1) OpenCV - TensorFlow

# %% [markdown]
# * Faster R-CNN

# %%
labels_to_names_0 = {0:'person',1:'bicycle',2:'car',3:'motorcycle',4:'airplane',5:'bus',6:'train',7:'truck',8:'boat',9:'traffic light',
                     10:'fire hydrant',11:'street sign',12:'stop sign',13:'parking meter',14:'bench',15:'bird',16:'cat',17:'dog',18:'horse',19:'sheep',
                     20:'cow',21:'elephant',22:'bear',23:'zebra',24:'giraffe',25:'hat',26:'backpack',27:'umbrella',28:'shoe',29:'eye glasses',
                     30:'handbag',31:'tie',32:'suitcase',33:'frisbee',34:'skis',35:'snowboard',36:'sports ball',37:'kite',38:'baseball bat',39:'baseball glove',
                     40:'skateboard',41:'surfboard',42:'tennis racket',43:'bottle',44:'plate',45:'wine glass',46:'cup',47:'fork',48:'knife',49:'spoon',
                     50:'bowl',51:'banana',52:'apple',53:'sandwich',54:'orange',55:'broccoli',56:'carrot',57:'hot dog',58:'pizza',59:'donut',
                     60:'cake',61:'chair',62:'couch',63:'potted plant',64:'bed',65:'mirror',66:'dining table',67:'window',68:'desk',69:'toilet',
                     70:'door',71:'tv',72:'laptop',73:'mouse',74:'remote',75:'keyboard',76:'cell phone',77:'microwave',78:'oven',79:'toaster',
                     80:'sink',81:'refrigerator',82:'blender',83:'book',84:'clock',85:'vase',86:'scissors',87:'teddy bear',88:'hair drier',89:'toothbrush',
                     90:'hair brush'}

# %% [markdown]
# # VI. Object Detection

# %% [markdown]
# * 약 20분
# * 총 Frame 별로 iteration 하면서 Object Detection 수행. 개별 frame별로 단일 이미지 Object Detection과 유사

# %%
# %%time

import time

green_color = (0, 255, 0)
red_color = (0, 0, 255)

while True:
  hasFrame, img_frame = cap.read()
  if not hasFrame:
    print('No more Frames')
    break

  rows = img_frame.shape[0]
  cols = img_frame.shape[1]
  cv_net.setInput(cv2.dnn.blobFromImage(img_frame, swapRB = True))
  start= time.time()
  cv_out = cv_net.forward()
  frame_index = 0

  for detection in cv_out[0, 0, :, :]:
    score = float(detection[2])
    class_id = int(detection[1])
    if score > 0.5:
      left = detection[3] * cols
      top = detection[4] * rows
      right = detection[5] * cols
      bottom = detection[6] * rows
      caption = "{}: {:.4f}".format(labels_to_names_0[class_id], score)
      cv2.rectangle(img_frame, (int(left), int(top)), (int(right), int(bottom)), color = green_color, thickness = 2)
      cv2.putText(img_frame, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, red_color, 1)
  print('Detection Time:', round(time.time() - start, 2), '초')
  vid_writer.write(img_frame)

vid_writer.release()
cap.release()
# Out:
# Detection Time: 7.49 초
# Detection Time: 7.71 초
# Detection Time: 7.91 초
# Detection Time: 6.84 초
# Detection Time: 8.05 초
# Detection Time: 6.52 초
# Detection Time: 7.84 초
# Detection Time: 6.89 초
# Detection Time: 7.85 초
# Detection Time: 7.83 초
# Detection Time: 6.59 초
# Detection Time: 7.85 초
# Detection Time: 6.75 초
# Detection Time: 7.89 초
# Detection Time: 6.61 초
# Detection Time: 7.92 초
# Detection Time: 7.57 초
# Detection Time: 6.9 초
# Detection Time: 7.85 초
# Detection Time: 6.69 초
# Detection Time: 7.84 초
# Detection Time: 6.63 초
# Detection Time: 7.99 초
# Detection Time: 6.78 초
# Detection Time: 7.51 초
# Detection Time: 7.97 초
# Detection Time: 6.61 초
# Detection Time: 7.9 초
# Detection Time: 6.69 초
# Detection Time: 7.86 초
# Detection Time: 6.61 초
# Detection Time: 7.87 초
# Detection Time: 7.5 초
# Detection Time: 6.93 초
# Detection Time: 7.93 초
# Detection Time: 6.68 초
# Detection Time: 7.86 초
# Detection Time: 6.68 초
# Detection Time: 7.92 초
# Detection Time: 7.25 초
# Detection Time: 7.14 초
# Detection Time: 7.88 초
# Detection Time: 6.64 초
# Detection Time: 7.92 초
# Detection Time: 6.62 초
# Detection Time: 7.82 초
# Detection Time: 6.79 초
# Detection Time: 7.6 초
# Detection Time: 7.89 초
# Detection Time: 6.59 초
# Detection Time: 7.85 초
# Detection Time: 6.7 초
# Detection Time: 7.94 초
# Detection Time: 6.86 초
# Detection Time: 7.84 초
# Detection Time: 7.5 초
# Detection Time: 7.0 초
# Detection Time: 7.97 초
# Detection Time: 6.63 초
# Detection Time: 11.55 초
# Detection Time: 7.89 초
# Detection Time: 6.6 초
# Detection Time: 7.89 초
# Detection Time: 6.66 초
# Detection Time: 7.87 초
# Detection Time: 6.59 초
# Detection Time: 7.71 초
# Detection Time: 7.67 초
# Detection Time: 6.71 초
# Detection Time: 7.84 초
# Detection Time: 6.65 초
# Detection Time: 7.89 초
# Detection Time: 6.6 초
# Detection Time: 7.87 초
# Detection Time: 7.02 초
# Detection Time: 7.25 초
# Detection Time: 7.81 초
# Detection Time: 6.55 초
# Detection Time: 7.82 초
# Detection Time: 6.45 초
# Detection Time: 7.93 초
# Detection Time: 6.54 초
# Detection Time: 7.9 초
# Detection Time: 6.85 초
# Detection Time: 7.55 초
# Detection Time: 7.88 초
# Detection Time: 6.61 초
# Detection Time: 7.91 초
# Detection Time: 6.6 초
# Detection Time: 7.95 초
# Detection Time: 6.53 초
# Detection Time: 7.86 초
# Detection Time: 7.29 초
# Detection Time: 7.13 초
# Detection Time: 7.93 초
# Detection Time: 6.6 초
# Detection Time: 7.93 초
# Detection Time: 6.58 초
# Detection Time: 7.83 초
# Detection Time: 6.59 초
# Detection Time: 7.72 초
# Detection Time: 7.74 초
# Detection Time: 6.69 초
# Detection Time: 7.8 초
# Detection Time: 6.67 초
# Detection Time: 7.91 초
# Detection Time: 6.52 초
# Detection Time: 7.9 초
# Detection Time: 6.68 초
# Detection Time: 7.57 초
# Detection Time: 7.77 초
# Detection Time: 6.7 초
# Detection Time: 7.82 초
# Detection Time: 6.6 초
# Detection Time: 7.96 초
# Detection Time: 6.67 초
# Detection Time: 7.79 초
# Detection Time: 6.89 초
# Detection Time: 7.45 초
# Detection Time: 7.85 초
# Detection Time: 6.44 초
# Detection Time: 7.96 초
# Detection Time: 6.59 초
# Detection Time: 7.85 초
# Detection Time: 6.65 초
# Detection Time: 7.98 초
# Detection Time: 7.27 초
# Detection Time: 7.33 초
# Detection Time: 7.84 초
# Detection Time: 6.49 초
# Detection Time: 7.84 초
# Detection Time: 6.66 초
# Detection Time: 7.85 초
# Detection Time: 6.59 초
# No more Frames
# CPU times: user 28min 22s, sys: 5.98 s, total: 28min 28s
# Wall time: 16min 25s

# %% [markdown]
# # VII. Define Object Detection Function

# %% [markdown]
# > ## 1) get_detected_img( ) 정의

# %%
import time
def get_detected_img(cv_net, img_array, score_threshold, use_copied_array = True, is_print = True):
  rows = img_array.shape[0]
  cols = img_array.shape[1]
  draw_img = None

  if use_copied_array:
    draw_img = img_array.copy()
  else:
    draw_img = img_array
    cv_net.setInput(cv2.dnn.blobFromImage(img_array, swapRB = True))
    start = time.time()
    cv_out = cv_net.forward()
    green_color = (0, 255, 0)
    red_color = (0, 0, 255)

    for detection in cv_out[0, 0, :, :]:
      score = float(detection[2])
      class_id = int(detection[1])

      # score_threshold 이상만 추출
      if score > score_threshold:
        left = detection[3] * cols
        top = detection[4] * rows
        right = detection[5] * cols
        bottom = detection[6] * rows
        caption = "{}: {:.4f}".format(labels_to_names_0[class_id], score)
        print(caption)
        cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color = green_color, thickness = 2)
        cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, red_color, 1)
        
    if is_print:
      print('Detection Time:',round(time.time() - start, 2), '초')
  return draw_img

# %% [markdown]
# > ## 2) do_deteced_video( ) 정의

# %%
def do_detected_video(cv_net, input_path, output_path, score_threshold, is_print):
  cap = cv2.VideoCapture(input_path)
  codec = cv2.VideoWriter_fourcc(*'XVID')
  vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
  vid_fps = cap.get(cv2.CAP_PROP_FPS)
  vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size)
  frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
  print('Frame Count:', frame_cnt)
  green_color=(0, 255, 0)
  red_color=(0, 0, 255)
  while True:
    hasFrame, img_frame = cap.read()
    if not hasFrame:
      print('No more Frames')
      break
    img_frame = get_detected_img(cv_net, img_frame, score_threshold = score_threshold, use_copied_array = False, is_print = is_print)
    vid_writer.write(img_frame)

  # end of while loop
  vid_writer.release()
  cap.release()

# %% [markdown]
# > ## 3) korea2.mp4 Download

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/image/korea2.mp4
# Out:
# --2023-04-17 04:34:58--  https://raw.githubusercontent.com/rusita-ai/pyData/master/image/korea2.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1447138 (1.4M) [application/octet-stream]
# Saving to: ‘korea2.mp4’
#
# korea2.mp4          100%[===================>]   1.38M  --.-KB/s    in 0.02s
#
# 2023-04-17 04:34:58 (79.4 MB/s) - ‘korea2.mp4’ saved [1447138/1447138]

# %% [markdown]
# * korea2.mp4 확인

# %%
import io
import base64
from IPython.display import HTML

video = io.open('/content/korea2.mp4', 'r+b').read()
encoded = base64.b64encode(video)

HTML(data='''<video width = "70%" controls>
  <source src = "data:video/mp4;base64,{0}" type = "video/mp4"/>
  </video>'''.format(encoded.decode('ascii')))
# Out:
# <video width = "70%" controls>
#   <source src = "data:video/mp4;base64,..." type = "video/mp4"/>
#   </video>

# %% [markdown]
# > ## 4) do_deteced_video( ) 실행

# %% [markdown]
# * 약 33분

# %%
# %%time
do_detected_video(cv_net, '/content/korea2.mp4', '/content/korea2_rcnn.mp4', 0.3, False)
# Out:
# Frame Count: 251
# person: 0.8919
# backpack: 0.7089
# person: 0.9235
# backpack: 0.5941
# person: 0.9297
# backpack: 0.6627
# backpack: 0.3945
# person: 0.9039
# backpack: 0.7465
# backpack: 0.3817
# person: 0.9426
# backpack: 0.5906
# backpack: 0.3256
# person: 0.9157
# backpack: 0.4152
# person: 0.9155
# backpack: 0.4344
# person: 0.9353
# backpack: 0.4038
# person: 0.9500
# person: 0.9259
# backpack: 0.3012
# person: 0.8858
# person: 0.9180
# person: 0.9040
# person: 0.9653
# person: 0.9690
# person: 0.8520
# person: 0.4351
# person: 0.6908
# person: 0.6078
# person: 0.5596
# car: 0.9960
# car: 0.9851
# car: 0.8598
# person: 0.7734
# person: 0.7609
# person: 0.6983
# person: 0.5518
# person: 0.5120
# person: 0.4585
# person: 0.4038
# person: 0.3625
# person: 0.3454
# person: 0.3250
# car: 0.9976
# car: 0.9840
# car: 0.8092
# person: 0.6140
# person: 0.5295
# person: 0.5170
# person: 0.5027
# person: 0.4947
# person: 0.4889
# person: 0.4738
# person: 0.4284
# person: 0.3892
# person: 0.3745
# person: 0.3655
# person: 0.3012
# car: 0.9991
# car: 0.9567
# car: 0.6855
# person: 0.5087
# car: 0.5040
# person: 0.4972
# person: 0.4907
# person: 0.4811
# person: 0.4651
# person: 0.4615
# person: 0.4533
# person: 0.4517
# person: 0.4479
# person: 0.3936
# person: 0.3804
# person: 0.3771
# truck: 0.3587
# car: 0.3199
# person: 0.3196
# car: 0.9991
# car: 0.9555
# car: 0.7156
# person: 0.4891
# person: 0.4734
# person: 0.4698
# person: 0.4648
# person: 0.4599
# person: 0.4515
# car: 0.4449
# person: 0.4423
# person: 0.4416
# person: 0.3925
# person: 0.3749
# person: 0.3675
# truck: 0.3341
# car: 0.9981
# car: 0.8907
# car: 0.8443
# person: 0.5261
# person: 0.5229
# person: 0.4928
# person: 0.4810
# car: 0.4731
# person: 0.4572
# person: 0.4142
# person: 0.3575
# person: 0.3339
# car: 0.3261
# car: 0.9985
# car: 0.9615
# car: 0.8745
# person: 0.4398
# person: 0.4003
# person: 0.3917
# person: 0.3775
# car: 0.3054
# person: 0.3035
# car: 0.9986
# car: 0.9779
# car: 0.7299
# car: 0.7294
# person: 0.5017
# person: 0.4737
# truck: 0.3560
# person: 0.3416
# person: 0.3265
# person: 0.3261
# person: 0.3160
# person: 0.3033
# car: 0.9975
# car: 0.9713
# car: 0.7036
# person: 0.5639
# person: 0.4505
# truck: 0.4417
# car: 0.4221
# person: 0.4168
# bus: 0.3403
# person: 0.3226
# person: 0.3001
# car: 0.9974
# car: 0.9614
# car: 0.6934
# car: 0.6873
# person: 0.5669
# person: 0.4238
# truck: 0.4235
# person: 0.4029
# person: 0.3142
# person: 0.3011
# car: 0.9972
# car: 0.9623
# car: 0.6809
# car: 0.6746
# person: 0.5550
# truck: 0.4340
# person: 0.3944
# person: 0.3914
# person: 0.3018
# person: 0.3014
# car: 0.9980
# car: 0.9469
# car: 0.7086
# person: 0.5306
# person: 0.4941
# truck: 0.3931
# person: 0.3771
# person: 0.3679
# person: 0.3498
# person: 0.3054
# car: 0.9974
# car: 0.9150
# car: 0.9123
# car: 0.8247
# person: 0.5842
# car: 0.5391
# person: 0.4778
# car: 0.3715
# car: 0.3613
# person: 0.3388
# person: 0.3339
# truck: 0.3067
# car: 0.9989
# car: 0.9108
# car: 0.8825
# car: 0.8818
# car: 0.6652
# person: 0.5647
# person: 0.4829
# person: 0.4810
# person: 0.4628
# car: 0.4482
# tv: 0.3503
# car: 0.9978
# car: 0.9115
# car: 0.9098
# car: 0.7667
# car: 0.7552
# car: 0.6116
# car: 0.4969
# car: 0.4775
# tv: 0.3421
# truck: 0.3316
# car: 0.3148
# car: 0.9993
# car: 0.9433
# car: 0.9169
# car: 0.8268
# car: 0.6988
# car: 0.4802
# car: 0.4615
# car: 0.3283
# tv: 0.3157
# car: 0.9995
# car: 0.9580
# car: 0.9297
# car: 0.8930
# car: 0.5960
# car: 0.4953
# car: 0.4705
# car: 0.3620
# car: 0.3319
# car: 0.9995
# car: 0.9698
# car: 0.9680
# car: 0.5146
# car: 0.4145
# car: 0.3560
# car: 0.9989
# car: 0.9653
# car: 0.9610
# car: 0.7289
# car: 0.5053
# car: 0.4078
# truck: 0.3877
# car: 0.3869
# car: 0.3353
# car: 0.9979
# car: 0.9588
# car: 0.9176
# car: 0.7348
# car: 0.6238
# car: 0.6110
# car: 0.6010
# car: 0.3117
# car: 0.3019
# car: 0.9958
# car: 0.9710
# car: 0.9398
# car: 0.7661
# car: 0.7124
# bus: 0.5775
# car: 0.5742
# car: 0.4560
# car: 0.4329
# car: 0.4295
# truck: 0.4074
# car: 0.3036
# car: 0.9962
# car: 0.9664
# car: 0.8874
# car: 0.7670
# car: 0.6467
# car: 0.5419
# car: 0.4726
# car: 0.9970
# car: 0.9715
# car: 0.7600
# car: 0.6970
# car: 0.5471
# car: 0.5238
# car: 0.4566
# car: 0.4337
# potted plant: 0.6350
# potted plant: 0.7167
# potted plant: 0.7230
# potted plant: 0.5708
# potted plant: 0.5094
# potted plant: 0.4733
# potted plant: 0.4495
# potted plant: 0.4950
# potted plant: 0.3710
# potted plant: 0.5403
# potted plant: 0.5142
# potted plant: 0.4200
# potted plant: 0.3691
# potted plant: 0.4287
# potted plant: 0.4254
# potted plant: 0.3163
# potted plant: 0.4345
# potted plant: 0.3491
# potted plant: 0.3812
# potted plant: 0.4057
# potted plant: 0.4100
# person: 0.3076
# potted plant: 0.3010
# potted plant: 0.3167
# potted plant: 0.3273
# potted plant: 0.3808
# potted plant: 0.3860
# potted plant: 0.3326
# potted plant: 0.3257
# train: 0.3705
# person: 0.3834
# person: 0.3263
# person: 0.4025
# person: 0.4030
# person: 0.6701
# person: 0.3431
# person: 0.3086
# person: 0.6095
# person: 0.3783
# person: 0.3596
# person: 0.6257
# person: 0.3741
# person: 0.3190
# umbrella: 0.3335
# person: 0.3141
# bench: 0.3547
# bench: 0.3584
# bird: 0.3973
# bird: 0.3197
# traffic light: 0.3401
# traffic light: 0.5874
# traffic light: 0.3564
# person: 0.5776
# person: 0.5343
# person: 0.4531
# person: 0.4293
# person: 0.4141
# person: 0.5637
# person: 0.5179
# person: 0.4526
# person: 0.4292
# person: 0.4102
# person: 0.5473
# person: 0.4329
# person: 0.3627
# person: 0.4259
# person: 0.4200
# person: 0.4094
# boat: 0.3574
# person: 0.3513
# person: 0.3380
# person: 0.3374
# person: 0.3358
# person: 0.3344
# person: 0.3317
# person: 0.4289
# person: 0.3524
# person: 0.3376
# person: 0.3349
# person: 0.3338
# person: 0.3289
# boat: 0.3272
# person: 0.3063
# person: 0.3062
# boat: 0.5219
# boat: 0.5661
# boat: 0.8589
# boat: 0.4870
# boat: 0.3795
# boat: 0.6266
# person: 0.4679
# person: 0.4392
# person: 0.4355
# person: 0.3200
# person: 0.9641
# boat: 0.5150
# person: 0.9172
# person: 0.6749
# person: 0.6146
# boat: 0.5234
# person: 0.5075
# person: 0.3975
# person: 0.3888
# person: 0.3186
# person: 0.3132
# person: 0.9695
# person: 0.9247
# person: 0.9100
# person: 0.8962
# person: 0.8774
# person: 0.8716
# person: 0.8220
# person: 0.8082
# person: 0.7807
# person: 0.7640
# person: 0.7628
# person: 0.7609
# person: 0.4819
# person: 0.4569
# person: 0.4524
# person: 0.4227
# person: 0.4101
# person: 0.3212
# person: 0.3086
# person: 0.9679
# person: 0.9671
# person: 0.9563
# person: 0.9550
# person: 0.9490
# person: 0.9455
# person: 0.9330
# person: 0.9153
# person: 0.8922
# person: 0.7247
# person: 0.5487
# person: 0.5318
# person: 0.4325
# person: 0.4029
# person: 0.3432
# person: 0.9702
# person: 0.9670
# person: 0.9626
# person: 0.9554
# person: 0.9426
# person: 0.9421
# person: 0.9351
# person: 0.9107
# person: 0.8833
# person: 0.7526
# person: 0.5982
# person: 0.4259
# person: 0.3748
# person: 0.3158
# person: 0.9847
# person: 0.9776
# person: 0.9660
# person: 0.8910
# person: 0.8482
# person: 0.7727
# person: 0.4144
# person: 0.3960
# person: 0.3611
# person: 0.9869
# person: 0.9862
# person: 0.9592
# person: 0.9474
# person: 0.9463
# person: 0.5078
# person: 0.3933
# boat: 0.3147
# person: 0.8444
# person: 0.7981
# person: 0.7115
# person: 0.6986
# person: 0.5771
# person: 0.5086
# boat: 0.3622
# person: 0.8070
# person: 0.8063
# person: 0.7463
# person: 0.7391
# person: 0.6142
# person: 0.6104
# person: 0.5193
# person: 0.4827
# person: 0.4732
# person: 0.4072
# person: 0.8002
# person: 0.7864
# person: 0.7252
# person: 0.7219
# person: 0.6289
# person: 0.6142
# person: 0.5169
# person: 0.4808
# person: 0.4518
# person: 0.4067
# person: 0.4055
# person: 0.3653
# person: 0.3065
# boat: 0.3009
# person: 0.8726
# person: 0.8526
# person: 0.8186
# person: 0.5767
# boat: 0.4892
# person: 0.3426
# person: 0.9062
# person: 0.8967
# boat: 0.8815
# person: 0.8755
# person: 0.8699
# person: 0.6771
# person: 0.6307
# person: 0.6303
# person: 0.5854
# person: 0.5497
# person: 0.3852
# person: 0.3683
# boat: 0.9288
# boat: 0.9183
# person: 0.4990
# person: 0.4761
# person: 0.4553
# person: 0.4527
# person: 0.4225
# person: 0.4004
# person: 0.3581
# boat: 0.9247
# person: 0.4985
# person: 0.4839
# person: 0.4714
# person: 0.4396
# person: 0.4361
# person: 0.4214
# person: 0.3734
# boat: 0.8620
# person: 0.7549
# person: 0.7301
# person: 0.5970
# person: 0.4775
# person: 0.3982
# boat: 0.8218
# person: 0.7177
# person: 0.6343
# person: 0.5824
# person: 0.3884
# person: 0.3531
# person: 0.3451
# person: 0.3403
# person: 0.3174
# person: 0.9231
# person: 0.8877
# person: 0.6903
# person: 0.6343
# boat: 0.5952
# person: 0.5904
# person: 0.7760
# person: 0.6593
# boat: 0.6504
# person: 0.3363
# person: 0.3040
# person: 0.9131
# person: 0.8826
# person: 0.7050
# boat: 0.6934
# person: 0.4935
# person: 0.4861
# person: 0.4577
# person: 0.9128
# person: 0.8833
# person: 0.7169
# boat: 0.6384
# person: 0.4949
# person: 0.4937
# person: 0.4465
# person: 0.9373
# person: 0.8689
# person: 0.8162
# boat: 0.7674
# person: 0.6969
# person: 0.6770
# person: 0.6037
# person: 0.5928
# person: 0.5742
# person: 0.5677
# person: 0.5162
# person: 0.4963
# person: 0.4748
# person: 0.3336
# person: 0.8879
# boat: 0.8577
# person: 0.8412
# person: 0.8174
# person: 0.5251
# person: 0.3936
# boat: 0.6848
# person: 0.3503
# person: 0.9621
# person: 0.9466
# person: 0.8027
# person: 0.5764
# person: 0.4655
# boat: 0.3919
# person: 0.6876
# person: 0.6632
# person: 0.4122
# person: 0.3465
# person: 0.3282
# boat: 0.3109
# fire hydrant: 0.3219
# person: 0.5686
# boat: 0.5243
# fire hydrant: 0.6867
# car: 0.3132
# car: 0.5694
# fire hydrant: 0.5175
# sink: 0.4469
# car: 0.4273
# person: 0.7960
# car: 0.3720
# fire hydrant: 0.3601
# person: 0.7935
# fire hydrant: 0.3581
# car: 0.3528
# person: 0.9710
# person: 0.8123
# person: 0.9070
# person: 0.7806
# person: 0.9333
# person: 0.8099
# person: 0.7833
# person: 0.6266
# person: 0.4592
# person: 0.3264
# person: 0.3042
# person: 0.9452
# person: 0.9271
# person: 0.4059
# boat: 0.6104
# person: 0.4703
# person: 0.4689
# person: 0.4094
# person: 0.3962
# boat: 0.6170
# person: 0.4776
# person: 0.4156
# person: 0.4099
# person: 0.6983
# boat: 0.6971
# person: 0.4751
# person: 0.3754
# boat: 0.6243
# person: 0.3202
# person: 0.6731
# person: 0.5948
# person: 0.3242
# person: 0.7139
# person: 0.5408
# person: 0.4014
# person: 0.7939
# boat: 0.6626
# person: 0.8802
# boat: 0.6925
# person: 0.9274
# person: 0.9211
# boat: 0.7441
# person: 0.3249
# fire hydrant: 0.5199
# person: 0.3553
# fire hydrant: 0.4663
# boat: 0.6220
# person: 0.9846
# bicycle: 0.9092
# person: 0.8825
# truck: 0.8556
# car: 0.8292
# car: 0.7593
# person: 0.3746
# person: 0.9953
# bicycle: 0.9668
# person: 0.9313
# car: 0.8467
# truck: 0.4877
# truck: 0.3065
# person: 0.9760
# car: 0.9335
# bicycle: 0.8759
# bicycle: 0.8012
# person: 0.7548
# bicycle: 0.5970
# person: 0.9757
# car: 0.9337
# bicycle: 0.8754
# bicycle: 0.7928
# person: 0.7653
# bicycle: 0.5996
# person: 0.9866
# bicycle: 0.9833
# car: 0.9019
# bicycle: 0.7416
# person: 0.4915
# car: 0.3604
# bicycle: 0.9901
# person: 0.9527
# car: 0.9069
# bicycle: 0.7422
# person: 0.4972
# person: 0.3274
# bicycle: 0.9884
# person: 0.9539
# car: 0.9261
# bicycle: 0.4692
# person: 0.3138
# bicycle: 0.9862
# car: 0.9461
# bicycle: 0.6630
# person: 0.6186
# person: 0.5606
# person: 0.4446
# person: 0.9908
# car: 0.9519
# bicycle: 0.9467
# baseball glove: 0.8831
# person: 0.9931
# car: 0.9524
# bicycle: 0.9454
# baseball glove: 0.9039
# person: 0.9983
# bicycle: 0.9877
# car: 0.9661
# baseball glove: 0.3684
# person: 0.9972
# bicycle: 0.9810
# car: 0.9500
# backpack: 0.4057
# person: 0.9990
# bicycle: 0.9872
# car: 0.9352
# baseball glove: 0.4443
# truck: 0.3733
# person: 0.9988
# bicycle: 0.9912
# car: 0.6543
# truck: 0.5721
# truck: 0.5587
# backpack: 0.3064
# person: 0.9996
# bicycle: 0.9861
# truck: 0.5882
# car: 0.5663
# baseball glove: 0.4453
# bench: 0.4343
# truck: 0.4044
# person: 0.9994
# bicycle: 0.9782
# truck: 0.7421
# car: 0.6827
# bench: 0.4582
# truck: 0.3069
# person: 0.9995
# bicycle: 0.9821
# truck: 0.8398
# bench: 0.3660
# bus: 0.9871
# umbrella: 0.9162
# bus: 0.5129
# person: 0.4400
# truck: 0.3805
# car: 0.3080
# bus: 0.9222
# umbrella: 0.8556
# person: 0.3729
# car: 0.3090
# car: 0.9390
# bus: 0.8718
# umbrella: 0.8497
# backpack: 0.7364
# person: 0.4734
# person: 0.3035
# person: 0.3019
# car: 0.9789
# bus: 0.8795
# umbrella: 0.7817
# person: 0.5907
# car: 0.9782
# bus: 0.8993
# umbrella: 0.7483
# person: 0.5899
# bus: 0.9570
# car: 0.9488
# umbrella: 0.8162
# person: 0.4938
# backpack: 0.3574
# person: 0.3287
# person: 0.3196
# car: 0.9667
# umbrella: 0.9506
# person: 0.6114
# bus: 0.5726
# person: 0.3211
# car: 0.9820
# umbrella: 0.9443
# person: 0.8558
# bus: 0.6053
# car: 0.9824
# bus: 0.9068
# umbrella: 0.8898
# person: 0.6364
# car: 0.9820
# umbrella: 0.9238
# bus: 0.6577
# car: 0.9819
# umbrella: 0.9391
# bus: 0.7973
# person: 0.3170
# car: 0.9788
# umbrella: 0.8992
# bus: 0.8716
# bus: 0.4299
# car: 0.9827
# bus: 0.8798
# umbrella: 0.8077
# person: 0.3386
# car: 0.3338
# car: 0.9872
# bus: 0.9426
# umbrella: 0.9411
# car: 0.4607
# backpack: 0.3933
# car: 0.9623
# bus: 0.8778
# umbrella: 0.8396
# person: 0.4090
# car: 0.9754
# umbrella: 0.9470
# bus: 0.8300
# car: 0.9674
# umbrella: 0.9454
# bus: 0.8229
# car: 0.3291
# car: 0.9807
# umbrella: 0.9096
# bus: 0.7754
# person: 0.3280
# car: 0.9857
# bus: 0.9058
# umbrella: 0.8828
# person: 0.3523
# bus: 0.9674
# car: 0.9100
# umbrella: 0.8573
# bus: 0.8478
# train: 0.4114
# bus: 0.9204
# traffic light: 0.5997
# train: 0.3602
# bus: 0.8313
# traffic light: 0.6012
# train: 0.3675
# bus: 0.9143
# traffic light: 0.4403
# train: 0.4363
# bus: 0.8906
# traffic light: 0.7646
# train: 0.5395
# bus: 0.9560
# traffic light: 0.3570
# train: 0.3103
# bus: 0.9108
# train: 0.3022
# bus: 0.8982
# train: 0.5780
# person: 0.4299
# bus: 0.9082
# train: 0.5686
# person: 0.4140
# bus: 0.9491
# traffic light: 0.3171
# bus: 0.9411
# bus: 0.3953
# bus: 0.9073
# bus: 0.8782
# bus: 0.8742
# train: 0.3864
# bus: 0.9748
# bus: 0.9223
# bus: 0.6792
# bus: 0.9746
# bus: 0.5922
# bus: 0.9716
# bus: 0.5788
# bus: 0.9135
# train: 0.4102
# person: 0.3900
# bus: 0.8651
# train: 0.4809
# bed: 0.9087
# No more Frames
# CPU times: user 52min 53s, sys: 10.3 s, total: 53min 4s
# Wall time: 30min 32s
