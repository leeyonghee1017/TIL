# %% [markdown]
# # OpenCV SSD
#
# > ## Video Object Detection
#
# * Pretrained 모델 파일 로드 후 OpenCV 기반 Object Detection 수행

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Video File Download

# %% [markdown]
# * matrix.mp4 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/image/matrix.mp4
# Out:
# --2023-04-08 01:56:06--  https://raw.githubusercontent.com/rusita-ai/pyData/master/image/matrix.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386522 (377K) [application/octet-stream]
# Saving to: ‘matrix.mp4’
#
# matrix.mp4          100%[===================>] 377.46K  --.-KB/s    in 0.03s
#
# 2023-04-08 01:56:06 (10.7 MB/s) - ‘matrix.mp4’ saved [386522/386522]

# %% [markdown]
# * matrix.mp4 확인

# %%
import io
import base64
from IPython.display import HTML

video = io.open('/content/matrix.mp4', 'r+b').read()

encoded = base64.b64encode(video)

HTML(data='''<video width = "70%" controls>
                <source src = "data:video/mp4;base64,{0}" type = "video/mp4"/>
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video width = "70%" controls>
#                 <source src = "data:video/mp4;base64,..." type = "video/mp4"/>
#              </video>

# %% [markdown]
# # II. Video Frame Information
#
# > ## 1) VideoCapture( )
#
# * cv2.CAP_PROP_FRAME_COUNT

# %%
import cv2

video_input_path = '/content/matrix.mp4'

cap = cv2.VideoCapture(video_input_path)
frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print('Frame Count:', frame_cnt)
# Out:
# Frame Count: 134

# %% [markdown]
# > ## 2) VideoWriter( )
#
# * Encoding Codec and FPS and Size

# %%
video_input_path = '/content/matrix.mp4'
video_output_path = '/content/matrix_ssd.mp4'

cap = cv2.VideoCapture(video_input_path)

codec = cv2.VideoWriter_fourcc(*'XVID')

vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
            round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))) 

vid_fps = cap.get(cv2.CAP_PROP_FPS )
    
vid_writer = cv2.VideoWriter(video_output_path, codec, vid_fps, vid_size) 

print('FPS Count:', vid_fps)
print('Video Size:', vid_size)
# Out:
# FPS Count: 30.0
# Video Size: (640, 360)

# %% [markdown]
# # III. Object Detection API Download

# %% [markdown]
# > ## 1) Pretrained Model Download
#
# * https://github.com/opencv/opencv/wiki/TensorFlow-Object-Detection-API
# * http://download.tensorflow.org/models/object_detection/ssd_inception_v2_coco_2017_11_17.tar.gz

# %% [markdown]
# * ssd_inception_v2_coco_2017_11_17.tar.gz 다운로드

# %%
# !wget http://download.tensorflow.org/models/object_detection/ssd_inception_v2_coco_2017_11_17.tar.gz
# Out:
# --2023-04-08 01:56:07--  http://download.tensorflow.org/models/object_detection/ssd_inception_v2_coco_2017_11_17.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.12.128, 2607:f8b0:400c:c08::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.12.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 278126337 (265M) [application/x-tar]
# Saving to: ‘ssd_inception_v2_coco_2017_11_17.tar.gz’
#
# ssd_inception_v2_co 100%[===================>] 265.24M   145MB/s    in 1.8s
#
# 2023-04-08 01:56:09 (145 MB/s) - ‘ssd_inception_v2_coco_2017_11_17.tar.gz’ saved [278126337/278126337]

# %% [markdown]
# * ssd_inception_v2_coco_2017_11_17.tar.gz 압축해제

# %%
# !tar -xvf ssd_inception_v2_coco_2017_11_17.tar.gz
# Out:
# ssd_inception_v2_coco_2017_11_17/
# ssd_inception_v2_coco_2017_11_17/model.ckpt.index
# ssd_inception_v2_coco_2017_11_17/model.ckpt.meta
# ssd_inception_v2_coco_2017_11_17/frozen_inference_graph.pb
# ssd_inception_v2_coco_2017_11_17/model.ckpt.data-00000-of-00001
# ssd_inception_v2_coco_2017_11_17/saved_model/
# ssd_inception_v2_coco_2017_11_17/saved_model/saved_model.pb
# ssd_inception_v2_coco_2017_11_17/saved_model/variables/
# ssd_inception_v2_coco_2017_11_17/checkpoint

# %% [markdown]
# * 결과 확인
#  - frozen_inference_graph.pb

# %%
# !ls -l /content/ssd_inception_v2_coco_2017_11_17
# Out:
# total 201116
# -rw-r----- 1 275875 5000        77 Nov 18  2017 checkpoint
# -rw-r----- 1 275875 5000 101987441 Nov 18  2017 frozen_inference_graph.pb
# -rw-r----- 1 275875 5000 100214372 Nov 18  2017 model.ckpt.data-00000-of-00001
# -rw-r----- 1 275875 5000     18073 Nov 18  2017 model.ckpt.index
# -rw-r----- 1 275875 5000   3701354 Nov 18  2017 model.ckpt.meta
# drwxr-x--- 3 275875 5000      4096 Nov 18  2017 saved_model

# %% [markdown]
# > ## 2) Model Configuration Download
#
# * https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/ssd_inception_v2_coco_2017_11_17.pbtxt

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/ssd_inception_v2_coco_2017_11_17.pbtxt
# Out:
# --2023-04-08 01:56:18--  https://raw.githubusercontent.com/opencv/opencv_extra/master/testdata/dnn/ssd_inception_v2_coco_2017_11_17.pbtxt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117525 (115K) [text/plain]
# Saving to: ‘ssd_inception_v2_coco_2017_11_17.pbtxt’
#
# ssd_inception_v2_co 100%[===================>] 114.77K  --.-KB/s    in 0.02s
#
# 2023-04-08 01:56:18 (5.35 MB/s) - ‘ssd_inception_v2_coco_2017_11_17.pbtxt’ saved [117525/117525]

# %% [markdown]
# # IV. Model and Configuration load
#
# * cv2.dnn.readNetFromTensorflow()

# %%
cv_net = cv2.dnn.readNetFromTensorflow('/content/ssd_inception_v2_coco_2017_11_17/frozen_inference_graph.pb',
                                       '/content/ssd_inception_v2_coco_2017_11_17.pbtxt')

# %% [markdown]
# # V. Class ID Setting
#
# * COCO Dataset

# %% [markdown]
# > ## 1) OpenCV - TensorFlow
#
# * SSD

# %%
labels_to_names = {1:'person',2:'bicycle',3:'car',4:'motorcycle',5:'airplane',6:'bus',7:'train',8:'truck',9:'boat',10:'traffic light',
                   11:'fire hydrant',12:'street sign',13:'stop sign',14:'parking meter',15:'bench',16:'bird',17:'cat',18:'dog',19:'horse',20:'sheep',
                   21:'cow',22:'elephant',23:'bear',24:'zebra',25:'giraffe',26:'hat',27:'backpack',28:'umbrella',29:'shoe',30:'eye glasses',
                   31:'handbag',32:'tie',33:'suitcase',34:'frisbee',35:'skis',36:'snowboard',37:'sports ball',38:'kite',39:'baseball bat',40:'baseball glove',
                   41:'skateboard',42:'surfboard',43:'tennis racket',44:'bottle',45:'plate',46:'wine glass',47:'cup',48:'fork',49:'knife',50:'spoon',
                   51:'bowl',52:'banana',53:'apple',54:'sandwich',55:'orange',56:'broccoli',57:'carrot',58:'hot dog',59:'pizza',60:'donut',
                   61:'cake',62:'chair',63:'couch',64:'potted plant',65:'bed',66:'mirror',67:'dining table',68:'window',69:'desk',70:'toilet',
                   71:'door',72:'tv',73:'laptop',74:'mouse',75:'remote',76:'keyboard',77:'cell phone',78:'microwave',79:'oven',80:'toaster',
                   81:'sink',82:'refrigerator',83:'blender',84:'book',85:'clock',86:'vase',87:'scissors',88:'teddy bear',89:'hair drier',90:'toothbrush',
                   91:'hair brush'}

# %% [markdown]
# # VI. Object Detection
#
# * 약 2분
#
# * 총 Frame 별로 iteration 하면서 Object Detection 수행. 개별 frame별로 단일 이미지 Object Detection과 유사

# %%
# %%time

import time

green_color = (0, 255, 0)
red_color = (0, 0, 255)

while True:

    hasFrame, img_frame = cap.read()
    if not hasFrame:
        print('No more Frames')
        break

    rows = img_frame.shape[0]
    cols = img_frame.shape[1]

    cv_net.setInput(cv2.dnn.blobFromImage(img_frame, swapRB = True))
    
    start= time.time()

    cv_out = cv_net.forward()
    frame_index = 0

    for detection in cv_out[0, 0, :, :]:
        score = float(detection[2])
        class_id = int(detection[1])

        if score > 0.5:
            left = detection[3] * cols
            top = detection[4] * rows
            right = detection[5] * cols
            bottom = detection[6] * rows

            caption = "{}: {:.4f}".format(labels_to_names[class_id], score)

            cv2.rectangle(img_frame, (int(left), int(top)), (int(right), int(bottom)), color = green_color, thickness = 2)
            cv2.putText(img_frame, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, red_color, 1)
    print('Detection Time:', round(time.time() - start, 2), '초')
    vid_writer.write(img_frame)

vid_writer.release()
cap.release()
# Out:
# Detection Time: 1.28 초
# Detection Time: 0.68 초
# Detection Time: 0.7 초
# Detection Time: 0.69 초
# Detection Time: 0.69 초
# Detection Time: 0.65 초
# Detection Time: 0.65 초
# Detection Time: 0.63 초
# Detection Time: 0.69 초
# Detection Time: 0.62 초
# Detection Time: 0.5 초
# Detection Time: 0.66 초
# Detection Time: 0.71 초
# Detection Time: 0.68 초
# Detection Time: 0.79 초
# Detection Time: 0.75 초
# Detection Time: 0.82 초
# Detection Time: 0.79 초
# Detection Time: 0.69 초
# Detection Time: 0.69 초
# Detection Time: 0.66 초
# Detection Time: 0.66 초
# Detection Time: 0.39 초
# Detection Time: 0.4 초
# Detection Time: 0.4 초
# Detection Time: 0.38 초
# Detection Time: 0.39 초
# Detection Time: 0.39 초
# Detection Time: 0.4 초
# Detection Time: 0.39 초
# Detection Time: 0.37 초
# Detection Time: 0.39 초
# Detection Time: 0.38 초
# Detection Time: 0.39 초
# Detection Time: 0.39 초
# Detection Time: 0.38 초
# Detection Time: 0.39 초
# Detection Time: 0.38 초
# Detection Time: 0.38 초
# Detection Time: 0.4 초
# Detection Time: 0.38 초
    cv_net.setInput(cv2.dnn.blobFromImage(img_array, swapRB = True))
    
    start = time.time()
    cv_out = cv_net.forward()
    
    green_color = (0, 255, 0)
    red_color = (0, 0, 255)

    for detection in cv_out[0, 0, :, :]:
        score = float(detection[2])
        class_id = int(detection[1])
        # score_threshold 이상만 추출
        if score > score_threshold:
            left = detection[3] * cols
            top = detection[4] * rows
            right = detection[5] * cols
            bottom = detection[6] * rows

            caption = "{}: {:.4f}".format(labels_to_names[class_id], score)
            print(caption)

            cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color = green_color, thickness = 2)
            cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, red_color, 1)
    if is_print:
        print('Detection Time:',round(time.time() - start, 2), '초')

    return draw_img

# %% [markdown]
# > ## 2) do_deteced_video( ) 정의

# %%
def do_detected_video(cv_net, input_path, output_path, score_threshold, is_print):
    
    cap = cv2.VideoCapture(input_path)

    codec = cv2.VideoWriter_fourcc(*'XVID')

    vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    vid_fps = cap.get(cv2.CAP_PROP_FPS)

    vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size) 

    frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print('Frame Count:', frame_cnt)

    green_color=(0, 255, 0)
    red_color=(0, 0, 255)
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('No more Frames')
            break
        
        img_frame = get_detected_img(cv_net, img_frame, score_threshold = score_threshold, use_copied_array = False, is_print = is_print)
        
        vid_writer.write(img_frame)
    # end of while loop

    vid_writer.release()
    cap.release()

# %% [markdown]
# > ## 3) korea2.mp4 Download

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/image/korea.mp4
# Out:
# --2023-04-08 01:57:23--  https://raw.githubusercontent.com/rusita-ai/pyData/master/image/korea.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6859828 (6.5M) [application/octet-stream]
# Saving to: ‘korea.mp4’
#
# korea.mp4           100%[===================>]   6.54M  --.-KB/s    in 0.08s
#
# 2023-04-08 01:57:23 (79.5 MB/s) - ‘korea.mp4’ saved [6859828/6859828]

# %% [markdown]
# * korea.mp4 확인

# %%
import io
import base64
from IPython.display import HTML

video = io.open('/content/korea.mp4', 'r+b').read()

encoded = base64.b64encode(video)

HTML(data='''<video width = "70%" controls>
                <source src = "data:video/mp4;base64,{0}" type = "video/mp4"/>
             </video>'''.format(encoded.decode('ascii')))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# > ## 4) do_deteced_video( ) 실행
#
# * 약 20분

# %%
# %%time

do_detected_video(cv_net, '/content/korea.mp4', '/content/korea_ssd.mp4', 0.3, False)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# tv: 0.6903
# person: 0.4614
# tv: 0.4145
# person: 0.3380
# person: 0.3059
# tv: 0.8221
# person: 0.4205
# tv: 0.3753
# person: 0.3344
# tv: 0.7832
# person: 0.4371
# person: 0.3578
# person: 0.3359
# tv: 0.3148
# tv: 0.7948
# person: 0.4529
# tv: 0.3341
# person: 0.4362
# person: 0.4263
# person: 0.3863
# tv: 0.3842
# person: 0.3232
# tv: 0.3091
# tv: 0.4792
# person: 0.4368
# person: 0.4391
# person: 0.4175
# tv: 0.3656
# tv: 0.3225
# tv: 0.3028
# person: 0.4931
# person: 0.3845
# fork: 0.3344
# fork: 0.5001
# person: 0.4702
# person: 0.4304
# person: 0.5274
# person: 0.3628
# person: 0.3350
# person: 0.5110
# person: 0.3314
# person: 0.7009
# person: 0.3452
# scissors: 0.5574
# person: 0.4311
# person: 0.4216
# scissors: 0.7192
# person: 0.5492
# person: 0.3410
# scissors: 0.6034
# spoon: 0.3486
# scissors: 0.7197
# person: 0.3029
# scissors: 0.4647
# person: 0.4468
# person: 0.3209
# person: 0.3128
# scissors: 0.6824
# spoon: 0.3103
# toothbrush: 0.4842
# scissors: 0.7493
# scissors: 0.3268
# bed: 0.3334
# person: 0.3077
# person: 0.3603
# person: 0.3338
# person: 0.3049
# person: 0.9639
# person: 0.9659
# person: 0.9658
# person: 0.9672
# person: 0.9653
# person: 0.9664
# person: 0.9656
# person: 0.9737
# person: 0.9736
# person: 0.9738
# person: 0.9737
# person: 0.9735
# person: 0.9729
# person: 0.9803
# person: 0.9807
# person: 0.9808
# person: 0.9813
# person: 0.9810
# person: 0.9810
# person: 0.9814
# person: 0.9809
# person: 0.9801
# person: 0.9806
# person: 0.9806
# person: 0.9805
# person: 0.9807
# person: 0.9799
# bowl: 0.8925
# person: 0.7561
# bowl: 0.6546
# bowl: 0.6348
# person: 0.5886
# bowl: 0.4202
# banana: 0.3963
# bowl: 0.3867
# bowl: 0.8814
# bowl: 0.5716
# clock: 0.4834
# person: 0.4738
# person: 0.4401
# bowl: 0.4037
# bowl: 0.3482
# person: 0.3281
# bowl: 0.8796
# bowl: 0.4988
# bowl: 0.3564
# bowl: 0.3424
# person: 0.3312
# bowl: 0.8496
# person: 0.5837
# bowl: 0.5036
# bowl: 0.3866
# bowl: 0.3608
# banana: 0.3182
# person: 0.3103
# person: 0.9041
# bowl: 0.8593
# person: 0.6389
# bowl: 0.5601
# bowl: 0.3877
# bowl: 0.3437
# bowl: 0.3054
# bowl: 0.8598
# person: 0.8277
# person: 0.6568
# bowl: 0.5472
# bowl: 0.4449
# bowl: 0.3654
# banana: 0.3135
# person: 0.8474
# bowl: 0.8127
# person: 0.6942
# person: 0.6518
# bowl: 0.5035
# bowl: 0.4434
# bowl: 0.4253
# carrot: 0.3850
# banana: 0.3494
# bowl: 0.7668
# bowl: 0.6203
# bowl: 0.4714
# person: 0.4308
# bowl: 0.4288
# bowl: 0.4059
# bowl: 0.4001
# carrot: 0.3546
# banana: 0.3463
# bowl: 0.3402
# person: 0.3186
# person: 0.8853
# bowl: 0.7381
# bowl: 0.6327
# bowl: 0.5196
# bowl: 0.4446
# bowl: 0.4040
# bowl: 0.4014
# cup: 0.3492
# banana: 0.3479
# person: 0.9274
# bowl: 0.7420
# bowl: 0.5216
# bowl: 0.4127
# banana: 0.3640
# bowl: 0.3322
# bowl: 0.3035
# person: 0.9409
# bowl: 0.7762
# bowl: 0.6830
# bowl: 0.4864
# person: 0.6861
# person: 0.3232
# person: 0.8340
# person: 0.7010
# tv: 0.4821
# tv: 0.6397
# tv: 0.5662
# tv: 0.5521
# tv: 0.5390
# person: 0.8107
# person: 0.7267
# tv: 0.4463
# person: 0.7998
# traffic light: 0.6529
# person: 0.4869
# person: 0.3961
# person: 0.8782
# traffic light: 0.6600
# person: 0.5988
# person: 0.3782
# person: 0.9820
# traffic light: 0.6664
# person: 0.4365
# person: 0.9827
# person: 0.5624
# person: 0.4309
# traffic light: 0.3897
# person: 0.9418
# person: 0.8092
# person: 0.5561
# traffic light: 0.3910
# person: 0.9263
# person: 0.8001
# person: 0.7082
# traffic light: 0.3778
# person: 0.9145
# person: 0.9004
# traffic light: 0.3695
# person: 0.9487
# person: 0.9423
# person: 0.3403
# person: 0.9283
# person: 0.8278
# giraffe: 0.4362
# person: 0.4155
# person: 0.9342
# person: 0.8874
# giraffe: 0.3380
# person: 0.3090
# person: 0.9433
# person: 0.6422
# person: 0.3786
# traffic light: 0.3100
# person: 0.9252
# person: 0.6759
# person: 0.5760
# traffic light: 0.3085
# person: 0.8915
# person: 0.6804
# person: 0.6477
# traffic light: 0.3440
# person: 0.9457
# person: 0.8862
# traffic light: 0.3473
# person: 0.9571
# person: 0.9417
# traffic light: 0.4409
# person: 0.9603
# person: 0.9493
# traffic light: 0.3858
# person: 0.8858
# person: 0.8612
# traffic light: 0.3888
# person: 0.7709
# person: 0.7709
# person: 0.9063
# person: 0.5670
# mouse: 0.4463
# person: 0.4134
# person: 0.5986
# person: 0.5675
# person: 0.4109
# person: 0.5741
# person: 0.4467
# person: 0.6102
# person: 0.6782
# person: 0.3313
# person: 0.6011
# person: 0.4491
# surfboard: 0.6210
# person: 0.3418
# person: 0.3059
# surfboard: 0.6048
# surfboard: 0.3645
# surfboard: 0.4315
# bear: 0.3227
# bear: 0.3201
# bird: 0.3124
# bird: 0.3091
# person: 0.3264
# bird: 0.4843
# person: 0.4701
# bird: 0.4444
# airplane: 0.3843
# bird: 0.3388
# bird: 0.4479
# bird: 0.3560
# bird: 0.3016
# bird: 0.5142
# bird: 0.3654
# bird: 0.3206
# bird: 0.5802
# boat: 0.5821
# bird: 0.3357
# bird: 0.3082
# bird: 0.6033
# bird: 0.3943
# bird: 0.4783
# bird: 0.3816
# bird: 0.3602
# person: 0.7681
# bird: 0.3068
# bird: 0.6135
# kite: 0.3100
# bird: 0.5029
# bird: 0.3849
# kite: 0.3400
# bird: 0.5022
# bird: 0.3823
# kite: 0.3379
# kite: 0.4107
# bird: 0.3690
# bird: 0.5030
# bird: 0.3857
# bird: 0.5018
# bird: 0.3832
# bird: 0.4725
# bird: 0.3523
# bird: 0.3331
# bird: 0.5549
# bird: 0.4581
# bird: 0.5991
# bird: 0.5991
# bird: 0.4949
# kite: 0.4242
# bird: 0.5313
# bird: 0.4935
# bird: 0.9113
# bird: 0.8845
# bird: 0.6998
# bird: 0.4472
# bird: 0.4294
# bird: 0.4063
# bird: 0.3473
# bird: 0.9113
# bird: 0.8847
# bird: 0.6999
# boat: 0.6896
# boat: 0.6651
# boat: 0.6556
# boat: 0.6684
# boat: 0.6564
# boat: 0.5961
# boat: 0.6138
# boat: 0.6133
# boat: 0.6585
# boat: 0.6343
# boat: 0.6330
# boat: 0.5961
# boat: 0.5961
# boat: 0.6170
# boat: 0.5916
# boat: 0.5154
# boat: 0.4979
# boat: 0.4979
# boat: 0.4944
# boat: 0.4115
# boat: 0.3054
# boat: 0.4399
# boat: 0.4117
# boat: 0.4117
# boat: 0.4062
# train: 0.3059
# boat: 0.4453
# boat: 0.4413
# boat: 0.5503
# boat: 0.5494
# boat: 0.5110
# boat: 0.5956
# boat: 0.6029
# boat: 0.5973
# boat: 0.5973
# boat: 0.6873
# boat: 0.7860
# boat: 0.8061
# boat: 0.7493
# boat: 0.7493
# boat: 0.7664
# boat: 0.7823
# boat: 0.7724
# boat: 0.7691
# boat: 0.3020
# boat: 0.7578
# boat: 0.7634
# boat: 0.7865
# boat: 0.8184
# boat: 0.8463
# boat: 0.8463
# broccoli: 0.3593
# bear: 0.3248
# person: 0.3691
# broccoli: 0.6738
# bear: 0.4307
# bear: 0.3658
# bear: 0.3243
# person: 0.8904
# person: 0.6380
# person: 0.5002
# person: 0.8106
# person: 0.5364
# person: 0.8171
# person: 0.6390
# person: 0.5207
# person: 0.8130
# person: 0.5002
# person: 0.7962
# person: 0.7224
# person: 0.5228
# person: 0.7900
# person: 0.7195
# person: 0.4914
# person: 0.7945
# person: 0.6468
# person: 0.4905
# person: 0.7572
# person: 0.5651
# person: 0.4945
# person: 0.7637
# person: 0.5594
# person: 0.4949
# person: 0.7615
# person: 0.6039
# person: 0.5008
# person: 0.7587
# person: 0.7190
# person: 0.5046
# person: 0.7023
# person: 0.6622
# person: 0.5220
# person: 0.4840
# person: 0.4459
# person: 0.4068
# person: 0.3018
# person: 0.4857
# person: 0.4371
# person: 0.3514
# person: 0.3237
# person: 0.4903
# person: 0.4560
# person: 0.3510
# person: 0.3382
# person: 0.6300
# person: 0.5775
# person: 0.4383
# person: 0.3025
# person: 0.5872
# person: 0.5173
# person: 0.4189
# person: 0.3097
# person: 0.5764
# person: 0.5599
# person: 0.3841
# person: 0.3781
# person: 0.5327
# person: 0.4339
# person: 0.4187
# tv: 0.3143
# tv: 0.3315
# tv: 0.4124
# car: 0.9764
# person: 0.7613
# car: 0.6081
# person: 0.5626
# person: 0.5245
# car: 0.4962
# person: 0.4329
# person: 0.3957
# person: 0.3817
# person: 0.3419
# car: 0.3369
# car: 0.9645
# car: 0.7122
# person: 0.7043
# person: 0.5720
# person: 0.5526
# car: 0.5394
# person: 0.5372
# person: 0.5088
# person: 0.4838
# person: 0.3600
# person: 0.3251
# car: 0.9650
# car: 0.8742
# person: 0.6540
# person: 0.5833
# car: 0.5664
# person: 0.5426
# person: 0.4937
# person: 0.4384
# person: 0.4344
# person: 0.4021
# person: 0.3628
# car: 0.9654
# car: 0.8542
# person: 0.6586
# person: 0.5817
# car: 0.5668
# person: 0.5234
# person: 0.4735
# person: 0.4490
# person: 0.4418
# person: 0.4221
# person: 0.3765
# person: 0.5772
# person: 0.5544
# person: 0.4567
# person: 0.5772
# person: 0.5544
# person: 0.4567
# person: 0.4606
# person: 0.3951
# person: 0.4450
# person: 0.4418
# person: 0.4412
# person: 0.3095
# person: 0.3545
# person: 0.3491
# person: 0.3342
# boat: 0.5876
# airplane: 0.3143
# boat: 0.5192
# airplane: 0.5078
# person: 0.5217
# airplane: 0.3490
# person: 0.3130
# person: 0.5217
# airplane: 0.3484
# person: 0.3130
# person: 0.8182
# airplane: 0.5399
# airplane: 0.6685
# airplane: 0.7305
# airplane: 0.5750
# person: 0.3748
# person: 0.9068
# person: 0.8242
# person: 0.8053
# person: 0.7171
# person: 0.6846
# person: 0.6505
# airplane: 0.4791
# person: 0.9066
# person: 0.8241
# person: 0.8058
# person: 0.7187
# person: 0.6897
# person: 0.6507
# airplane: 0.3976
# boat: 0.3690
# person: 0.3565
# person: 0.3686
# boat: 0.3561
# airplane: 0.3556
# person: 0.4088
# boat: 0.3836
# airplane: 0.3181
# boat: 0.5498
# airplane: 0.3769
# boat: 0.5850
# person: 0.3005
# boat: 0.4535
# person: 0.3320
# boat: 0.5144
# person: 0.4068
# person: 0.3905
# train: 0.3296
# person: 0.6018
# boat: 0.4916
# person: 0.3733
# person: 0.3661
# person: 0.7948
# person: 0.5304
# boat: 0.4465
# person: 0.3450
# person: 0.9390
# person: 0.9143
# person: 0.9120
# person: 0.8959
# person: 0.8947
# person: 0.8927
# person: 0.8618
# person: 0.8526
# person: 0.7522
# person: 0.7042
# person: 0.6375
# person: 0.5598
# person: 0.5524
# person: 0.4228
# person: 0.3856
# boat: 0.3519
# person: 0.3036
# person: 0.9440
# person: 0.9341
# person: 0.8934
# person: 0.8790
# person: 0.8607
# person: 0.8361
# person: 0.8256
# person: 0.8025
# person: 0.7263
# person: 0.5260
# boat: 0.4254
# person: 0.9440
# person: 0.9341
# person: 0.8934
# person: 0.8790
# person: 0.8607
# person: 0.8361
# person: 0.8256
# person: 0.8025
# person: 0.7263
# person: 0.5260
# boat: 0.4260
# person: 0.9236
# person: 0.8038
# person: 0.7921
# person: 0.7700
# person: 0.7698
# person: 0.7379
# person: 0.7360
# boat: 0.3703
# person: 0.3018
# person: 0.9676
# person: 0.9537
# person: 0.9265
# person: 0.8676
# person: 0.8554
# person: 0.4079
# person: 0.5270
# boat: 0.3936
# person: 0.6629
# person: 0.6503
# person: 0.5240
# person: 0.4836
# person: 0.3179
# person: 0.6629
# person: 0.6503
# person: 0.5240
# person: 0.4836
# person: 0.3179
# boat: 0.3244
# person: 0.9419
# person: 0.9237
# person: 0.7059
# person: 0.8077
# person: 0.8045
# person: 0.6457
# person: 0.6291
# person: 0.5940
# person: 0.4111
# person: 0.4071
# person: 0.3232
# person: 0.6506
# person: 0.5090
# person: 0.3393
# boat: 0.3011
# person: 0.8163
# person: 0.6179
# person: 0.4771
# person: 0.3573
# boat: 0.3187
# person: 0.8164
# person: 0.6163
# person: 0.4772
# person: 0.3561
# boat: 0.3115
# person: 0.3235
# person: 0.3869
# boat: 0.3446
# person: 0.3264
# person: 0.8358
# person: 0.4301
# person: 0.4091
# person: 0.8945
# person: 0.7411
# boat: 0.4840
# person: 0.3088
# person: 0.8133
# person: 0.7499
# person: 0.7378
# boat: 0.3893
# person: 0.3607
# person: 0.8127
# person: 0.7503
# person: 0.7376
# boat: 0.3750
# person: 0.3608
# person: 0.8914
# person: 0.7835
# person: 0.7802
# person: 0.7003
# person: 0.5369
# person: 0.4244
# person: 0.7284
# person: 0.6849
# person: 0.6798
# person: 0.3816
# person: 0.7129
# person: 0.5417
# fire hydrant: 0.3335
# fire hydrant: 0.3000
# person: 0.6761
# person: 0.6222
# umbrella: 0.3027
# fire hydrant: 0.3219
# fire hydrant: 0.4296
# tv: 0.3822
# fire hydrant: 0.4162
# tv: 0.3771
# fire hydrant: 0.3735
# fire hydrant: 0.4644
# fire hydrant: 0.5773
# fire hydrant: 0.5575
# person: 0.8224
# fire hydrant: 0.4014
# sink: 0.3164
# person: 0.8203
# fire hydrant: 0.3759
# sink: 0.3151
# person: 0.8145
# person: 0.6155
# chair: 0.3330
# person: 0.7198
# person: 0.3466
# fire hydrant: 0.3093
# person: 0.7987
# person: 0.5076
# fire hydrant: 0.4293
# fire hydrant: 0.6346
# person: 0.6182
# fire hydrant: 0.5696
# person: 0.4610
# person: 0.3686
# fire hydrant: 0.5527
# person: 0.4610
# person: 0.3685
# person: 0.7827
# fire hydrant: 0.5807
# fire hydrant: 0.4948
# person: 0.7318
# fire hydrant: 0.5712
# bottle: 0.3198
# person: 0.6249
# fire hydrant: 0.4398
# person: 0.5141
# fire hydrant: 0.4903
# person: 0.4071
# person: 0.5102
# fire hydrant: 0.4621
# person: 0.4205
# fire hydrant: 0.5085
# person: 0.4737
# person: 0.3359
# person: 0.4238
# fire hydrant: 0.3935
# fire hydrant: 0.4493
# person: 0.3990
# fire hydrant: 0.4639
# person: 0.3567
# person: 0.8790
# person: 0.7195
# person: 0.4751
# fire hydrant: 0.3757
# person: 0.3379
# person: 0.8790
# person: 0.7195
# person: 0.4751
# fire hydrant: 0.3755
# person: 0.3371
# airplane: 0.7983
# person: 0.9732
# person: 0.9184
# person: 0.8730
# bicycle: 0.8212
# person: 0.5088
# car: 0.3861
# truck: 0.3842
# person: 0.9626
# person: 0.8346
# person: 0.8014
# bicycle: 0.7572
# truck: 0.3894
# car: 0.3178
# person: 0.9692
# person: 0.8223
# bicycle: 0.5987
# person: 0.4678
# person: 0.9692
# person: 0.8221
# bicycle: 0.5975
# person: 0.4678
# person: 0.7463
# bicycle: 0.7181
# bicycle: 0.4934
# bicycle: 0.9078
# person: 0.7450
# bicycle: 0.5915
# person: 0.4285
# bicycle: 0.8659
# bicycle: 0.7159
# person: 0.5329
# car: 0.3870
# car: 0.3432
# person: 0.3320
# bicycle: 0.8369
# bicycle: 0.7881
# person: 0.7655
# bicycle: 0.5487
# car: 0.5175
# person: 0.4487
# car: 0.4376
# person: 0.4347
# person: 0.8527
# bicycle: 0.8237
# person: 0.4380
# person: 0.3923
# car: 0.3871
# bicycle: 0.3064
# person: 0.8529
# bicycle: 0.8160
# person: 0.4343
# person: 0.3919
# car: 0.3891
# bicycle: 0.3035
# person: 0.9630
# bicycle: 0.7957
# person: 0.7923
# car: 0.3338
# car: 0.3227
# person: 0.9630
# bicycle: 0.8635
# person: 0.7630
# truck: 0.4606
# bicycle: 0.4337
# bicycle: 0.3194
# person: 0.9627
# bicycle: 0.8604
# person: 0.6866
# car: 0.5872
# car: 0.4201
# car: 0.4026
# bicycle: 0.3576
# person: 0.9846
# bicycle: 0.8316
# person: 0.7019
# car: 0.5300
# bicycle: 0.5226
# car: 0.3855
# car: 0.3128
# person: 0.9762
# bicycle: 0.8203
# person: 0.7022
# bicycle: 0.5694
# car: 0.5622
# car: 0.3583
# bicycle: 0.3254
# person: 0.9771
# bicycle: 0.8110
# person: 0.7008
# car: 0.5533
# bicycle: 0.5500
# car: 0.3547
# bicycle: 0.3108
# person: 0.9728
# bicycle: 0.8079
# person: 0.6904
# bus: 0.5017
# bicycle: 0.4849
# bus: 0.4307
# umbrella: 0.5046
# umbrella: 0.5149
# car: 0.6888
# umbrella: 0.5151
# car: 0.5051
# car: 0.9897
# umbrella: 0.5582
# car: 0.4525
# car: 0.9898
# umbrella: 0.5734
# car: 0.4525
# car: 0.9840
# umbrella: 0.5040
# car: 0.3559
# car: 0.9837
# person: 0.3590
# bus: 0.3362
# car: 0.9853
# person: 0.4597
# bus: 0.3621
# car: 0.9899
# person: 0.3808
# car: 0.9869
# person: 0.4150
# car: 0.9869
# person: 0.4748
# car: 0.9800
# umbrella: 0.3088
# car: 0.9684
# person: 0.4274
# car: 0.9335
# person: 0.8714
# car: 0.9064
# person: 0.7134
# person: 0.3422
# car: 0.8581
# person: 0.3206
# person: 0.3003
# car: 0.8584
# person: 0.3201
# car: 0.8374
# car: 0.8125
# bus: 0.5175
# car: 0.3332
# bus: 0.4936
# bus: 0.4767
# bus: 0.5193
# bus: 0.4892
# bus: 0.5201
# bus: 0.4900
# bus: 0.5027
# bus: 0.4254
# bus: 0.5294
# bus: 0.3606
# bus: 0.4832
# bus: 0.4617
# bus: 0.5505
# bus: 0.3449
# bus: 0.5410
# bus: 0.3714
# bus: 0.5410
# bus: 0.3714
# bus: 0.5011
# bus: 0.3387
# bus: 0.5854
# bus: 0.5465
# person: 0.3599
# bus: 0.3294
# bus: 0.5728
# bus: 0.3129
# bus: 0.6068
# person: 0.4149
# bus: 0.3593
# bus: 0.6054
# person: 0.4149
# bus: 0.3601
# bus: 0.6215
# bus: 0.3224
# bus: 0.5917
# bed: 0.4644
# person: 0.4598
# bed: 0.4743
# person: 0.4226
# person: 0.5230
# person: 0.5230
# person: 0.6181
# person: 0.6169
# person: 0.5613
# tie: 0.3712
# person: 0.6870
# person: 0.5981
# person: 0.5981
# person: 0.7107
# person: 0.4111
# bed: 0.3387
# bed: 0.6241
# person: 0.5500
# person: 0.3105
# person: 0.4881
# bed: 0.4492
# bed: 0.3573
# bed: 0.6693
# bed: 0.7698
# person: 0.4667
# person: 0.3814
# bed: 0.7696
# person: 0.4667
# person: 0.3803
# person: 0.8553
# bed: 0.8092
# bed: 0.4227
# person: 0.3692
# bed: 0.7660
# person: 0.5622
# bed: 0.4643
# person: 0.3880
# person: 0.3690
# bed: 0.7550
# person: 0.6241
# tie: 0.4910
# bed: 0.3669
# person: 0.3664
# bed: 0.7284
# tie: 0.5613
# person: 0.3971
# tie: 0.3969
# person: 0.3674
# person: 0.3675
# person: 0.4581
# bed: 0.4452
# bed: 0.3294
# bed: 0.4144
# bed: 0.3469
# tv: 0.3566
# tv: 0.5138
# tv: 0.3343
# tv: 0.3237
# sports ball: 0.5736
# person: 0.4314
# frisbee: 0.6159
# sports ball: 0.5588
# person: 0.3808
# person: 0.6809
# person: 0.6926
# person: 0.7157
# person: 0.7716
# person: 0.6456
# person: 0.8101
# person: 0.3776
# person: 0.6908
# person: 0.5848
# person: 0.3808
# person: 0.7719
# person: 0.4920
# person: 0.7443
# person: 0.4497
# person: 0.7101
# person: 0.3941
# person: 0.6755
# person: 0.4301
# person: 0.6509
# person: 0.3745
# person: 0.5454
# person: 0.3806
# person: 0.6609
# person: 0.3613
# person: 0.6400
# person: 0.3692
# person: 0.6338
# person: 0.7117
# person: 0.5319
# person: 0.5808
# person: 0.7028
# person: 0.6990
# person: 0.3062
# person: 0.7236
# person: 0.6717
# person: 0.6434
# person: 0.6903
# person: 0.5142
# person: 0.4120
# person: 0.3089
# clock: 0.5201
# clock: 0.4143
# clock: 0.3133
# person: 0.3529
# person: 0.3768
# clock: 0.4820
# person: 0.6525
# person: 0.8004
# person: 0.6333
# person: 0.9147
# person: 0.7826
# person: 0.9155
# person: 0.7751
# person: 0.5692
# person: 0.3623
# person: 0.3455
# person: 0.3048
# person: 0.7244
# fire hydrant: 0.3094
# fire hydrant: 0.3375
# person: 0.9917
# person: 0.8722
# person: 0.6376
# person: 0.9913
# person: 0.8490
# person: 0.6272
# person: 0.8036
# person: 0.7849
# train: 0.5508
# train: 0.3014
# train: 0.4171
# train: 0.5278
# train: 0.5803
# microwave: 0.4075
# train: 0.3277
# train: 0.3432
# person: 0.8678
# person: 0.6772
# boat: 0.4855
# person: 0.6454
# person: 0.6399
# boat: 0.6190
# person: 0.5273
# person: 0.5206
# person: 0.6529
# person: 0.6428
# boat: 0.6295
# person: 0.5347
# person: 0.5297
# person: 0.8926
# boat: 0.7650
# person: 0.7471
# person: 0.5982
# potted plant: 0.5540
# person: 0.8375
# person: 0.8015
# boat: 0.6344
# person: 0.4626
# person: 0.3250
# boat: 0.9590
# boat: 0.9773
# person: 0.7556
# person: 0.4331
# boat: 0.3281
# boat: 0.9232
# person: 0.8244
# person: 0.7590
# person: 0.7252
# person: 0.3583
# boat: 0.3398
# boat: 0.9211
# person: 0.8241
# person: 0.7674
# person: 0.7245
# boat: 0.4273
# person: 0.3643
# person: 0.8454
# person: 0.5743
# boat: 0.3131
# person: 0.8917
# person: 0.8606
# boat: 0.6097
# person: 0.4760
# person: 0.7429
# person: 0.6998
# person: 0.4297
# microwave: 0.3875
# bench: 0.6950
# keyboard: 0.5433
# keyboard: 0.4729
# bench: 0.3291
# bench: 0.3397
# bench: 0.3843
# traffic light: 0.3092
# person: 0.3841
# tv: 0.3471
# tv: 0.3463
# boat: 0.6559
# boat: 0.5538
# boat: 0.8362
# laptop: 0.3390
# boat: 0.8341
# boat: 0.8466
# boat: 0.8686
# boat: 0.8545
# boat: 0.8499
# laptop: 0.3321
# boat: 0.8636
# laptop: 0.3275
# boat: 0.8695
# boat: 0.3060
# boat: 0.8518
# laptop: 0.3275
# boat: 0.3205
# boat: 0.8625
# boat: 0.3056
# boat: 0.8172
# boat: 0.3264
# boat: 0.8301
# boat: 0.3401
# boat: 0.7610
# boat: 0.3237
# boat: 0.7359
# boat: 0.7185
# boat: 0.7510
# boat: 0.7266
# boat: 0.7093
# boat: 0.7093
# boat: 0.7149
# boat: 0.7321
# boat: 0.7187
# car: 0.9899
# traffic light: 0.8830
# truck: 0.6913
# person: 0.6822
# car: 0.5983
# tv: 0.5600
# traffic light: 0.4824
# traffic light: 0.4675
# person: 0.4424
# traffic light: 0.3617
# person: 0.3467
# person: 0.3325
# person: 0.3212
# car: 0.9926
# traffic light: 0.8603
# person: 0.6922
# tv: 0.6491
# traffic light: 0.4870
# car: 0.4345
# traffic light: 0.3963
# traffic light: 0.3710
# person: 0.3395
# car: 0.9911
# traffic light: 0.8759
# tv: 0.8413
# person: 0.6297
# traffic light: 0.4624
# person: 0.4330
# car: 0.4306
# person: 0.4236
# person: 0.4002
# traffic light: 0.3880
# truck: 0.3873
# traffic light: 0.3594
# car: 0.9911
# traffic light: 0.8738
# tv: 0.8406
# person: 0.6287
# traffic light: 0.4505
# person: 0.4340
# car: 0.4301
# person: 0.4235
# truck: 0.4182
# person: 0.3996
# traffic light: 0.3886
# traffic light: 0.3673
# car: 0.9879
# traffic light: 0.8749
# tv: 0.8391
# person: 0.7396
# car: 0.4625
# car: 0.4498
# traffic light: 0.4333
# traffic light: 0.3720
# traffic light: 0.3678
# car: 0.9871
# tv: 0.8124
# traffic light: 0.7919
# traffic light: 0.5043
# person: 0.4497
# traffic light: 0.4209
# car: 0.3671
# person: 0.3591
# traffic light: 0.3532
# truck: 0.3524
# car: 0.9878
# tv: 0.7817
# car: 0.7406
# traffic light: 0.7237
# traffic light: 0.6103
# person: 0.4718
# car: 0.3820
# traffic light: 0.3441
# traffic light: 0.3203
# car: 0.9875
# car: 0.8016
# traffic light: 0.7940
# tv: 0.6318
# car: 0.5517
# traffic light: 0.5210
# truck: 0.4995
# traffic light: 0.3725
# traffic light: 0.3240
# person: 0.3122
# car: 0.9871
# tv: 0.8538
# traffic light: 0.8316
# truck: 0.6601
# car: 0.5929
# traffic light: 0.5341
# traffic light: 0.3710
# person: 0.3451
# car: 0.3100
# traffic light: 0.3031
# car: 0.9874
# traffic light: 0.8292
# tv: 0.8028
# truck: 0.6643
# car: 0.6015
# traffic light: 0.5532
# traffic light: 0.3896
# person: 0.3709
# car: 0.9843
# traffic light: 0.8199
# truck: 0.7992
# car: 0.6859
# car: 0.6352
# traffic light: 0.5917
# tv: 0.4851
# traffic light: 0.4211
# car: 0.3128
# car: 0.9816
# tv: 0.8012
# traffic light: 0.8009
# car: 0.5858
# traffic light: 0.5792
# traffic light: 0.4359
# car: 0.3546
# car: 0.9832
# traffic light: 0.7984
# tv: 0.6941
# traffic light: 0.5924
# car: 0.4903
# traffic light: 0.4205
# car: 0.3621
# car: 0.9866
# traffic light: 0.7751
# tv: 0.6681
# traffic light: 0.6466
# car: 0.4608
# traffic light: 0.3424
# car: 0.9672
# traffic light: 0.8308
# tv: 0.6344
# traffic light: 0.6055
# car: 0.4440
# car: 0.3464
# traffic light: 0.3205
# car: 0.9675
# traffic light: 0.8291
# traffic light: 0.6457
# car: 0.4435
# tv: 0.4209
# person: 0.3488
# car: 0.3408
# traffic light: 0.3038
# car: 0.9405
# traffic light: 0.8121
# car: 0.6823
# traffic light: 0.5712
# car: 0.3784
# person: 0.3617
# tv: 0.3559
# traffic light: 0.3059
# car: 0.9411
# traffic light: 0.7616
# car: 0.7326
# traffic light: 0.6668
# tv: 0.4835
# car: 0.4820
# car: 0.4218
# person: 0.3585
# car: 0.3400
# traffic light: 0.7015
# traffic light: 0.6497
# car: 0.6428
# car: 0.4157
# bus: 0.3023
# car: 0.8597
# traffic light: 0.7364
# tv: 0.6807
# traffic light: 0.6356
# person: 0.3663
# person: 0.3187
# bus: 0.3114
# car: 0.8802
# traffic light: 0.7744
# traffic light: 0.6438
# car: 0.6371
# person: 0.4589
# car: 0.4126
# person: 0.3296
# car: 0.3205
# car: 0.3142
# car: 0.8804
# traffic light: 0.7713
# car: 0.6392
# traffic light: 0.6375
# person: 0.4572
# car: 0.4120
# car: 0.3209
# car: 0.3142
# car: 0.8427
# traffic light: 0.7156
# traffic light: 0.6766
# car: 0.5272
# person: 0.4922
# car: 0.4882
# tv: 0.3952
# car: 0.8652
# traffic light: 0.7596
# traffic light: 0.7125
# car: 0.6939
# car: 0.4574
# person: 0.4277
# car: 0.4038
# tv: 0.3507
# traffic light: 0.7955
# traffic light: 0.7819
# car: 0.7353
# car: 0.4538
# person: 0.4382
# car: 0.4258
# car: 0.4225
# car: 0.3443
# person: 0.3077
# traffic light: 0.8144
# traffic light: 0.7378
# car: 0.6553
# car: 0.6460
# car: 0.5858
# person: 0.4244
# traffic light: 0.7990
# car: 0.7471
# traffic light: 0.7335
# car: 0.4491
# person: 0.4478
# car: 0.4158
# person: 0.3405
# person: 0.3335
# traffic light: 0.8071
# car: 0.7416
# traffic light: 0.7285
# car: 0.4423
# car: 0.4408
# person: 0.3315
# person: 0.3213
# person: 0.3155
# traffic light: 0.8704
# traffic light: 0.8008
# car: 0.7549
# car: 0.5438
# person: 0.5012
# person: 0.4477
# car: 0.3013
# car: 0.9331
# traffic light: 0.8790
# traffic light: 0.8656
# person: 0.4719
# traffic light: 0.3954
# car: 0.3797
# truck: 0.3420
# car: 0.3282
# car: 0.9384
# traffic light: 0.8959
# traffic light: 0.8489
# person: 0.5287
# car: 0.4639
# person: 0.3721
# car: 0.3140
# car: 0.9311
# traffic light: 0.9177
# traffic light: 0.8694
# car: 0.6466
# car: 0.5677
# traffic light: 0.3853
# person: 0.3742
# person: 0.3233
# person: 0.3142
# car: 0.9673
# car: 0.9147
# traffic light: 0.9136
# traffic light: 0.8699
# car: 0.6039
# person: 0.4727
# person: 0.4460
# traffic light: 0.3703
# car: 0.9673
# car: 0.9147
# traffic light: 0.9134
# traffic light: 0.8699
# car: 0.6039
# person: 0.4725
# person: 0.4460
# traffic light: 0.3700
# car: 0.9677
# traffic light: 0.9211
# car: 0.8472
# traffic light: 0.8159
# car: 0.5825
# person: 0.4238
# person: 0.3774
# car: 0.3117
# car: 0.9890
# traffic light: 0.9116
# car: 0.8871
# traffic light: 0.7996
# person: 0.6168
# car: 0.5950
# car: 0.4147
# car: 0.4048
# person: 0.3666
# car: 0.3606
# person: 0.3494
# traffic light: 0.3317
# person: 0.3189
# car: 0.9845
# traffic light: 0.9310
# car: 0.8865
# traffic light: 0.7636
# car: 0.7058
# person: 0.6808
# car: 0.4865
# car: 0.4835
# person: 0.4677
# car: 0.3842
# person: 0.3443
# traffic light: 0.3205
# traffic light: 0.3015
# car: 0.9845
# traffic light: 0.9346
# car: 0.8729
# traffic light: 0.8313
# person: 0.7520
# car: 0.7357
# car: 0.4921
# person: 0.4615
# person: 0.4484
# traffic light: 0.4391
# person: 0.4364
# person: 0.4064
# person: 0.3912
# tv: 0.3618
# traffic light: 0.3290
# person: 0.9861
# person: 0.9442
# person: 0.7371
# person: 0.7302
# person: 0.6979
# person: 0.6423
# person: 0.3977
# person: 0.3064
# person: 0.3015
# person: 0.9729
# person: 0.9599
# person: 0.8288
# person: 0.6884
# person: 0.6515
# person: 0.9704
# person: 0.9157
# person: 0.5759
# person: 0.5160
# person: 0.3378
# person: 0.3071
# person: 0.9761
# person: 0.9489
# person: 0.3206
# person: 0.3119
# person: 0.9185
# person: 0.8905
# person: 0.7172
# person: 0.9607
# person: 0.9510
# person: 0.4517
# sports ball: 0.3086
# person: 0.9700
# person: 0.7026
# person: 0.5230
# cow: 0.4492
# person: 0.4485
# cow: 0.4006
# person: 0.9630
# person: 0.7375
# person: 0.3561
# person: 0.3255
# person: 0.3078
# person: 0.3006
# person: 0.9679
# person: 0.7304
# person: 0.3512
# person: 0.3359
# person: 0.3095
# person: 0.9772
# person: 0.5935
# person: 0.9694
# person: 0.7237
# person: 0.5098
# person: 0.4762
# person: 0.3174
# person: 0.9769
# person: 0.6447
# person: 0.4925
# person: 0.3509
# person: 0.9831
# person: 0.4617
# person: 0.4476
# person: 0.9803
# person: 0.8526
# person: 0.9751
# person: 0.6075
# person: 0.4936
# person: 0.9861
# person: 0.4897
# person: 0.4229
# person: 0.3395
# person: 0.9814
# person: 0.7471
# sports ball: 0.5475
# person: 0.3722
# person: 0.3333
# person: 0.9737
# person: 0.8359
# sports ball: 0.3987
# person: 0.9867
# person: 0.6525
# person: 0.4552
# sports ball: 0.4254
# person: 0.3621
# person: 0.3041
# person: 0.9842
# person: 0.7984
# person: 0.7454
# person: 0.6834
# sports ball: 0.3015
# person: 0.9835
# person: 0.9142
# person: 0.9078
# person: 0.8167
# sports ball: 0.3979
# baseball bat: 0.3713
# person: 0.3027
# person: 0.9746
# person: 0.8873
# person: 0.7491
# sports ball: 0.7450
# person: 0.5411
# person: 0.4618
# baseball bat: 0.3707
# person: 0.9589
# person: 0.8767
# sports ball: 0.8182
# person: 0.6118
# person: 0.5343
# person: 0.9321
# person: 0.9068
# person: 0.8105
# sports ball: 0.6514
# baseball bat: 0.3369
# person: 0.3061
# person: 0.9072
# person: 0.9045
# person: 0.7845
# sports ball: 0.6307
# person: 0.3522
# person: 0.9078
# person: 0.8553
# person: 0.8010
# person: 0.7335
# sports ball: 0.6453
# person: 0.4435
# sports ball: 0.3308
# person: 0.9064
# person: 0.8823
# person: 0.8618
# person: 0.6967
# sports ball: 0.5856
# person: 0.9055
# person: 0.8568
# person: 0.8466
# person: 0.8106
# sports ball: 0.3002
# person: 0.9037
# person: 0.8718
# person: 0.8569
# person: 0.8475
# person: 0.3082
# person: 0.9265
# person: 0.8831
# person: 0.8812
# person: 0.7832
# person: 0.9162
# person: 0.9064
# person: 0.8315
# person: 0.7818
# person: 0.3803
# sports ball: 0.3197
# person: 0.9191
# person: 0.8755
# person: 0.8115
# person: 0.7554
# sports ball: 0.5414
# person: 0.9316
# person: 0.9011
# person: 0.7276
# sports ball: 0.5890
# person: 0.4946
# person: 0.9405
# person: 0.9220
# person: 0.8100
# person: 0.6168
# person: 0.3908
# sports ball: 0.3739
# traffic light: 0.3165
# person: 0.8352
# person: 0.8087
# person: 0.8041
# person: 0.5418
# person: 0.3948
# person: 0.9508
# person: 0.8904
# person: 0.6770
# person: 0.6720
# person: 0.3766
# person: 0.3640
# person: 0.9426
# person: 0.8895
# person: 0.8469
# person: 0.5503
# person: 0.3174
# person: 0.3040
# person: 0.9322
# person: 0.9150
# person: 0.7802
# person: 0.7220
# sports ball: 0.4206
# person: 0.3912
# person: 0.9520
# person: 0.9112
# person: 0.8729
# person: 0.4932
# sports ball: 0.4048
# person: 0.3350
# person: 0.9245
# person: 0.9152
# person: 0.8742
# person: 0.6070
# sports ball: 0.5318
# person: 0.3007
# person: 0.9113
# person: 0.8114
# person: 0.7895
# horse: 0.6145
# dog: 0.5320
# person: 0.3287
# person: 0.9333
# person: 0.9270
# person: 0.8687
# horse: 0.6751
# dog: 0.4963
# sports ball: 0.4690
# person: 0.3088
# person: 0.9171
# person: 0.8687
# person: 0.8084
# dog: 0.4121
# cow: 0.3347
# horse: 0.3161
# person: 0.8508
# person: 0.8420
# person: 0.7634
# person: 0.5435
# sports ball: 0.5283
# person: 0.4040
# person: 0.9460
# person: 0.8023
# person: 0.7613
# person: 0.6925
# sports ball: 0.5515
# person: 0.9063
# person: 0.8392
# person: 0.8207
# person: 0.7327
# person: 0.4689
# sports ball: 0.3189
# person: 0.8482
# person: 0.8212
# person: 0.7830
# person: 0.7608
# sports ball: 0.3191
# person: 0.8986
# person: 0.8829
# person: 0.8142
# person: 0.7365
# person: 0.3618
# person: 0.9366
# person: 0.7028
# person: 0.6959
# person: 0.6782
# sports ball: 0.5633
# person: 0.4159
# person: 0.3096
# person: 0.9381
# person: 0.8953
# person: 0.8736
# person: 0.7470
# sports ball: 0.3106
# person: 0.9204
# person: 0.8579
# person: 0.7977
# person: 0.4517
# person: 0.4467
# person: 0.9441
# person: 0.8916
# person: 0.7830
# person: 0.5595
# person: 0.9214
# person: 0.8276
# person: 0.7372
# person: 0.4385
# person: 0.3178
# person: 0.8657
# person: 0.8531
# person: 0.8375
# person: 0.6162
# person: 0.4386
# person: 0.8807
# person: 0.6764
# person: 0.5424
# person: 0.5402
# person: 0.3773
# person: 0.3025
# person: 0.7364
# person: 0.6831
# person: 0.6815
# person: 0.5447
# baseball glove: 0.4489
# person: 0.3209
# traffic light: 0.3071
# person: 0.8239
# person: 0.8039
# person: 0.7785
# baseball glove: 0.6365
# person: 0.5025
# person: 0.3906
# person: 0.3811
# person: 0.3694
# baseball glove: 0.3052
# person: 0.6865
# person: 0.6600
# person: 0.6445
# person: 0.6362
# person: 0.3163
# person: 0.9614
# person: 0.9371
# person: 0.9659
# person: 0.9292
# car: 0.4058
# person: 0.9631
# person: 0.9297
# car: 0.5693
# person: 0.9649
# person: 0.9480
# person: 0.9699
# person: 0.9451
# person: 0.9215
# person: 0.9136
# person: 0.3144
# person: 0.9020
# person: 0.3822
# person: 0.9396
# person: 0.4102
# person: 0.9150
# person: 0.4973
# person: 0.3983
# person: 0.8397
# person: 0.7381
# person: 0.4106
# person: 0.3894
# person: 0.9245
# person: 0.6846
# person: 0.3980
# person: 0.3335
# person: 0.3144
# person: 0.9162
# person: 0.8802
# person: 0.4654
# person: 0.4279
# person: 0.8664
# person: 0.4535
# person: 0.8093
# person: 0.4066
# person: 0.4805
# person: 0.3554
# person: 0.4375
# person: 0.5381
# person: 0.3423
# person: 0.8531
# person: 0.3847
# person: 0.8500
# person: 0.3652
# person: 0.3163
# person: 0.8569
# person: 0.3516
# person: 0.3122
# person: 0.9127
# person: 0.5444
# person: 0.4041
# person: 0.3694
# person: 0.8935
# person: 0.4883
# person: 0.4220
# person: 0.3402
# person: 0.8954
# person: 0.6474
# person: 0.3908
# person: 0.7342
# person: 0.7083
# person: 0.3780
# person: 0.3295
# tv: 0.3096
# person: 0.6999
# person: 0.6121
# person: 0.4271
# person: 0.4050
# person: 0.5896
# person: 0.4732
# tv: 0.4446
# person: 0.3169
# person: 0.3129
# person: 0.4886
# person: 0.3815
# person: 0.3389
# person: 0.3331
# person: 0.3152
# person: 0.4867
# person: 0.3727
# person: 0.3607
# person: 0.5646
# person: 0.3872
# person: 0.3569
# person: 0.5336
# person: 0.4988
# person: 0.3477
# person: 0.6490
# person: 0.4170
# person: 0.3599
# person: 0.8835
# person: 0.3448
# person: 0.7098
# person: 0.3100
# person: 0.8003
# person: 0.6973
# tv: 0.3602
# tv: 0.3014
# person: 0.7615
# tv: 0.4247
# person: 0.8358
# tv: 0.4857
# tv: 0.3698
# person: 0.8707
# tv: 0.5827
# person: 0.8834
# person: 0.7993
# tv: 0.6485
# person: 0.3986
# person: 0.9426
# person: 0.8923
# tv: 0.5239
# person: 0.9795
# person: 0.9189
# person: 0.7417
# person: 0.7392
# person: 0.5980
# person: 0.5782
# person: 0.5036
# person: 0.4786
# person: 0.4523
# person: 0.4059
# person: 0.3815
# person: 0.3458
# person: 0.3350
# person: 0.3198
# person: 0.3180
# person: 0.3168
# person: 0.9724
# person: 0.8773
# tennis racket: 0.7037
# person: 0.7028
# person: 0.6559
# person: 0.6401
# person: 0.5197
# person: 0.4385
# person: 0.4177
# person: 0.3943
# person: 0.3731
# person: 0.3212
# person: 0.3057
# person: 0.3007
# person: 0.9728
# person: 0.8767
# tennis racket: 0.7068
# person: 0.7054
# person: 0.6572
# person: 0.6461
# person: 0.5340
# person: 0.4473
# person: 0.4089
# person: 0.3949
# person: 0.3706
# person: 0.3309
# person: 0.3097
# person: 0.3044
# person: 0.9535
# person: 0.7299
# person: 0.6136
# person: 0.5339
# person: 0.4640
# person: 0.4404
# person: 0.4324
# person: 0.3654
# person: 0.3477
# person: 0.3427
# person: 0.3266
# tennis racket: 0.3110
# person: 0.9677
# person: 0.9494
# person: 0.5358
# person: 0.4889
# person: 0.4552
# person: 0.4477
# person: 0.4454
# person: 0.4206
# person: 0.3464
# tennis racket: 0.3380
# person: 0.3050
# person: 0.3047
# person: 0.3000
# person: 0.9363
# person: 0.8903
# person: 0.5271
# person: 0.4971
# person: 0.3800
# person: 0.3743
# person: 0.3713
# person: 0.3090
# person: 0.8131
# person: 0.6908
# person: 0.6440
# tennis racket: 0.6129
# person: 0.4992
# tennis racket: 0.4650
# person: 0.3930
# tennis racket: 0.3268
# person: 0.3259
# person: 0.3033
# person: 0.9084
# person: 0.7808
# person: 0.5941
# person: 0.5569
# person: 0.4191
# person: 0.3596
# person: 0.3136
# person: 0.3055
# person: 0.8311
# person: 0.6806
# person: 0.6502
# person: 0.4820
# person: 0.4635
# person: 0.3688
# person: 0.3253
# person: 0.3156
# person: 0.8671
# person: 0.7235
# person: 0.6527
# person: 0.5031
# person: 0.4280
# person: 0.4047
# person: 0.3281
# person: 0.9426
# person: 0.4089
# person: 0.3313
# person: 0.3230
# tennis racket: 0.3109
# person: 0.3062
# person: 0.3009
# person: 0.7834
# person: 0.5734
# person: 0.5351
# tennis racket: 0.4340
# tennis racket: 0.3704
# tennis racket: 0.3301
# person: 0.3094
# person: 0.3011
# person: 0.5436
# person: 0.3938
# person: 0.3754
# person: 0.3523
# person: 0.3512
# person: 0.3236
# person: 0.3094
# person: 0.3027
# person: 0.9526
# person: 0.6444
# tennis racket: 0.3052
# person: 0.9731
# person: 0.7520
# person: 0.4818
# person: 0.3294
# person: 0.3231
# person: 0.3131
# person: 0.9731
# person: 0.7521
# person: 0.4818
# person: 0.3294
# person: 0.3231
# person: 0.3129
# person: 0.9826
# person: 0.8387
# person: 0.4745
# person: 0.3934
# person: 0.3035
# person: 0.9692
# person: 0.8533
# person: 0.4713
# person: 0.4426
# person: 0.3790
# person: 0.3773
# person: 0.3688
# person: 0.3247
# person: 0.3012
# person: 0.3011
# person: 0.9750
# person: 0.8250
# person: 0.5875
# person: 0.5285
# person: 0.4658
# person: 0.3687
# person: 0.3478
# person: 0.3334
# person: 0.3250
# person: 0.3033
# person: 0.3018
# person: 0.3001
# person: 0.9592
# person: 0.8758
# person: 0.4157
# person: 0.3944
# person: 0.3709
# person: 0.3215
# person: 0.3069
# person: 0.9335
# person: 0.7115
# person: 0.4512
# person: 0.4214
# person: 0.3157
# person: 0.9315
# person: 0.7067
# person: 0.4503
# person: 0.4214
# person: 0.3167
# person: 0.9729
# person: 0.7638
# person: 0.5625
# person: 0.4361
# person: 0.4290
# person: 0.3021
# person: 0.9663
# person: 0.5606
# person: 0.4921
# person: 0.4208
# person: 0.3370
# person: 0.3327
# person: 0.3021
# person: 0.9640
# person: 0.5012
# person: 0.4097
# person: 0.3872
# person: 0.3699
# person: 0.3540
# person: 0.3204
# person: 0.3188
# chair: 0.3170
# person: 0.3064
# person: 0.5678
# person: 0.5224
# person: 0.4227
# person: 0.4047
# person: 0.3332
# person: 0.3289
# person: 0.3127
# person: 0.9289
# person: 0.5194
# person: 0.4662
# person: 0.4218
# person: 0.3600
# person: 0.3506
# person: 0.3500
# person: 0.3409
# person: 0.3086
# person: 0.9280
# person: 0.5029
# person: 0.4673
# person: 0.4583
# person: 0.3614
# person: 0.3493
# person: 0.3464
# person: 0.3397
# person: 0.3312
# person: 0.3124
# person: 0.8853
# person: 0.6424
# person: 0.5630
# person: 0.4634
# person: 0.3982
# person: 0.3720
# person: 0.3564
# person: 0.3337
# person: 0.3193
# person: 0.4081
# person: 0.3809
# person: 0.3580
# person: 0.3525
# person: 0.3474
# person: 0.3362
# person: 0.3294
# person: 0.3217
# person: 0.3158
# person: 0.8686
# person: 0.4618
# person: 0.4537
# person: 0.3502
# person: 0.3264
# person: 0.8753
# person: 0.4379
# person: 0.3858
# person: 0.3450
# person: 0.3335
# person: 0.3171
# person: 0.3106
# person: 0.3049
# person: 0.8809
# person: 0.4236
# person: 0.4150
# person: 0.3996
# person: 0.3844
# person: 0.3564
# person: 0.3474
# person: 0.3056
# person: 0.8927
# person: 0.4654
# person: 0.4146
# person: 0.3977
# person: 0.3972
# person: 0.3736
# person: 0.3433
# person: 0.3030
# person: 0.8457
# person: 0.4029
# person: 0.3432
# person: 0.3427
# person: 0.3220
# person: 0.8816
# person: 0.4608
# person: 0.3814
# person: 0.3294
# person: 0.3094
# person: 0.9011
# person: 0.4106
# person: 0.3693
# person: 0.3606
# person: 0.3521
# person: 0.3197
# person: 0.9719
# person: 0.7631
# person: 0.4624
# person: 0.3748
# person: 0.3693
# person: 0.3496
# person: 0.3222
# person: 0.3166
# person: 0.3018
# person: 0.9773
# person: 0.8652
# person: 0.5336
# person: 0.4652
# person: 0.3278
# person: 0.3116
# person: 0.9787
# person: 0.8752
# person: 0.5497
# person: 0.4662
# person: 0.3089
# person: 0.9742
# person: 0.8852
# person: 0.4405
# person: 0.3885
# person: 0.3881
# person: 0.3288
# person: 0.3284
# person: 0.9624
# person: 0.8545
# tennis racket: 0.6533
# person: 0.4951
# person: 0.4424
# person: 0.3324
# person: 0.3313
# person: 0.9765
# person: 0.9245
# tennis racket: 0.6993
# person: 0.6331
# person: 0.4554
# person: 0.3931
# person: 0.3880
# person: 0.3689
# person: 0.3435
# person: 0.3231
# person: 0.3120
# person: 0.3055
# person: 0.9613
# person: 0.9463
# person: 0.5545
# person: 0.5147
# tennis racket: 0.4638
# person: 0.4458
# person: 0.4286
# person: 0.4119
# person: 0.3870
# person: 0.3469
# person: 0.3051
# person: 0.9422
# person: 0.7371
# person: 0.5481
# person: 0.5402
# person: 0.5024
# person: 0.4467
# person: 0.4464
# person: 0.3709
# person: 0.3622
# person: 0.3498
# person: 0.3408
# person: 0.3032
# person: 0.9422
# person: 0.7372
# person: 0.5481
# person: 0.5402
# person: 0.5024
# person: 0.4467
# person: 0.4464
# person: 0.3703
# person: 0.3622
# person: 0.3498
# person: 0.3408
# person: 0.3032
# person: 0.9390
# person: 0.5433
# person: 0.4769
# person: 0.4198
# person: 0.4120
# person: 0.3695
# person: 0.3653
# person: 0.3637
# person: 0.3626
# person: 0.3127
# person: 0.3103
# person: 0.9466
# person: 0.8326
# person: 0.4678
# person: 0.4504
# person: 0.4232
# person: 0.4119
# person: 0.3845
# person: 0.3583
# person: 0.3149
# person: 0.9162
# person: 0.5180
# person: 0.4299
# person: 0.4214
# person: 0.4170
# person: 0.4015
# person: 0.3882
# person: 0.3487
# person: 0.3397
# person: 0.3162
# person: 0.3147
# person: 0.9596
# person: 0.7628
# person: 0.6078
# person: 0.4731
# person: 0.4098
# person: 0.4077
# person: 0.3313
# person: 0.3168
# person: 0.3068
# person: 0.3032
# person: 0.9607
# person: 0.8013
# person: 0.5512
# person: 0.4595
# person: 0.4156
# person: 0.4143
# person: 0.3900
# person: 0.3638
# person: 0.3492
# person: 0.3159
# person: 0.3101
# person: 0.9617
# person: 0.8105
# person: 0.5660
# person: 0.4257
# ...
# person: 0.5954
# person: 0.5714
# person: 0.4473
# person: 0.4127
# person: 0.4057
# person: 0.3893
# person: 0.3756
# person: 0.3396
# person: 0.3175
# person: 0.3072
# person: 0.5826
# person: 0.5788
# person: 0.4460
# person: 0.4147
# person: 0.3808
# person: 0.3723
# person: 0.3373
# person: 0.3281
# person: 0.3185
# person: 0.3073
# person: 0.5966
# person: 0.4978
# person: 0.4316
# person: 0.3349
# person: 0.3299
# person: 0.3280
# person: 0.3239
# person: 0.3185
# person: 0.3116
# person: 0.3109
# person: 0.5589
# person: 0.4352
# person: 0.4247
# person: 0.4144
# person: 0.4090
# person: 0.3469
# person: 0.3220
# person: 0.3087
# person: 0.5569
# person: 0.5476
# person: 0.5047
# person: 0.4373
# person: 0.3784
# person: 0.3712
# person: 0.3402
# person: 0.3152
# person: 0.5779
# person: 0.5197
# person: 0.4921
# person: 0.4307
# person: 0.3977
# person: 0.3967
# person: 0.3778
# person: 0.3119
# person: 0.3047
# person: 0.3009
# person: 0.4406
# person: 0.4233
# person: 0.3667
# person: 0.3464
# person: 0.3429
# person: 0.3259
# person: 0.3234
# person: 0.3134
# person: 0.4406
# person: 0.4233
# person: 0.3667
# person: 0.3464
# person: 0.3429
# person: 0.3259
# person: 0.3234
# person: 0.3134
# person: 0.8038
# person: 0.6902
# tv: 0.6522
# person: 0.5032
# person: 0.4133
# person: 0.3281
# person: 0.7731
# person: 0.6996
# person: 0.4462
# person: 0.4053
# tv: 0.3625
# person: 0.3264
# person: 0.7399
# person: 0.6906
# person: 0.4088
# person: 0.3827
# tv: 0.3363
# person: 0.3248
# person: 0.7376
# person: 0.6967
# baseball bat: 0.4138
# person: 0.4034
# person: 0.3984
# person: 0.3299
# person: 0.7471
# person: 0.6826
# baseball bat: 0.4137
# person: 0.4094
# person: 0.4010
# person: 0.3269
# person: 0.7180
# person: 0.6932
# person: 0.6179
# person: 0.4040
# person: 0.3371
# person: 0.3338
# person: 0.8650
# person: 0.8024
# person: 0.5557
# person: 0.4352
# person: 0.4349
# person: 0.8055
# person: 0.7853
# person: 0.4701
# person: 0.4504
# person: 0.4232
# frisbee: 0.3309
# person: 0.7940
# person: 0.7737
# person: 0.4548
# person: 0.4469
# frisbee: 0.4248
# person: 0.4235
# person: 0.8263
# person: 0.7399
# person: 0.4412
# person: 0.4221
# person: 0.4147
# frisbee: 0.3511
# person: 0.8298
# person: 0.7435
# person: 0.4427
# person: 0.4271
# person: 0.4169
# frisbee: 0.3499
# person: 0.7746
# person: 0.7374
# frisbee: 0.4359
# person: 0.4338
# person: 0.4208
# person: 0.3662
# person: 0.7956
# person: 0.7542
# person: 0.4650
# person: 0.4367
# person: 0.4211
# person: 0.8157
# person: 0.7980
# person: 0.5226
# person: 0.4482
# person: 0.4213
# person: 0.8071
# person: 0.7793
# person: 0.4773
# person: 0.4487
# person: 0.4233
# person: 0.8112
# person: 0.7691
# person: 0.4729
# person: 0.4519
# person: 0.4234
# person: 0.8108
# person: 0.7682
# person: 0.4720
# person: 0.4525
# person: 0.4232
# person: 0.7911
# person: 0.7536
# person: 0.4350
# person: 0.4208
# person: 0.4196
# person: 0.7930
# person: 0.7820
# person: 0.4403
# person: 0.4253
# person: 0.4221
# person: 0.7844
# person: 0.7780
# person: 0.4842
# person: 0.4399
# person: 0.4234
# person: 0.7768
# person: 0.7625
# person: 0.4997
# person: 0.4243
# person: 0.4151
# person: 0.7828
# person: 0.7635
# person: 0.4553
# person: 0.4252
# person: 0.4251
# person: 0.7877
# person: 0.7476
# person: 0.4624
# person: 0.4248
# person: 0.4068
# person: 0.6068
# person: 0.5350
# person: 0.5208
# person: 0.5898
# person: 0.5295
# person: 0.5193
# person: 0.6279
# person: 0.5399
# person: 0.8187
# person: 0.5196
# person: 0.5017
# person: 0.4625
# person: 0.9306
# person: 0.6488
# person: 0.5485
# person: 0.5230
# person: 0.9469
# person: 0.7787
# person: 0.7506
# person: 0.3866
# person: 0.9136
# person: 0.6882
# person: 0.6506
# person: 0.6399
# person: 0.9114
# person: 0.6968
# person: 0.6435
# person: 0.6289
# person: 0.7715
# person: 0.7094
# person: 0.5972
# tennis racket: 0.5845
# baseball bat: 0.3460
# person: 0.3354
# person: 0.8165
# person: 0.7153
# person: 0.6078
# person: 0.4450
# tennis racket: 0.3937
# person: 0.8608
# person: 0.6853
# person: 0.6298
# person: 0.5738
# tennis racket: 0.4179
# person: 0.9564
# person: 0.7851
# person: 0.7342
# person: 0.3669
# baseball bat: 0.3024
# person: 0.9568
# person: 0.8287
# person: 0.7179
# person: 0.5790
# person: 0.9539
# person: 0.8234
# person: 0.6949
# person: 0.5307
# person: 0.9457
# person: 0.7995
# person: 0.6729
# person: 0.5278
# person: 0.9449
# person: 0.8035
# person: 0.5865
# person: 0.3969
# person: 0.9422
# person: 0.7977
# person: 0.6340
# person: 0.5570
# person: 0.9560
# person: 0.8468
# person: 0.5677
# person: 0.4727
# person: 0.9552
# person: 0.8326
# person: 0.6301
# person: 0.5030
# tennis racket: 0.3563
# person: 0.9547
# person: 0.8323
# person: 0.6288
# person: 0.4981
# tennis racket: 0.3493
# person: 0.9368
# person: 0.8006
# person: 0.5692
# person: 0.3937
# baseball bat: 0.3638
# baseball glove: 0.3127
# person: 0.9188
# person: 0.7285
# person: 0.5954
# tennis racket: 0.4692
# person: 0.3719
# person: 0.9308
# person: 0.7586
# person: 0.5256
# tennis racket: 0.4599
# person: 0.4394
# person: 0.9224
# person: 0.7396
# person: 0.4908
# person: 0.4270
# tennis racket: 0.3534
# person: 0.9233
# person: 0.7209
# person: 0.5944
# tennis racket: 0.4362
# person: 0.3318
# person: 0.9214
# person: 0.7172
# person: 0.6349
# tennis racket: 0.4291
# person: 0.3099
# person: 0.9176
# person: 0.6843
# person: 0.6795
# person: 0.6016
# tennis racket: 0.4793
# person: 0.9127
# person: 0.6353
# person: 0.6265
# tennis racket: 0.4575
# person: 0.4007
# person: 0.9267
# person: 0.6666
# person: 0.5836
# person: 0.8917
# person: 0.7562
# person: 0.6192
# person: 0.5410
# person: 0.8857
# person: 0.7171
# person: 0.6816
# person: 0.5434
# person: 0.8850
# person: 0.6828
# person: 0.6798
# person: 0.5562
# person: 0.8895
# person: 0.7330
# person: 0.7075
# person: 0.6018
# person: 0.8854
# person: 0.7914
# person: 0.7182
# person: 0.6884
# person: 0.8827
# person: 0.7818
# person: 0.6871
# person: 0.6600
# person: 0.8837
# person: 0.7267
# person: 0.7030
# person: 0.6804
# person: 0.9019
# person: 0.7554
# person: 0.7116
# person: 0.5169
# person: 0.9033
# person: 0.7554
# person: 0.7157
# person: 0.5172
# person: 0.8957
# person: 0.7019
# person: 0.6936
# person: 0.5117
# person: 0.8849
# person: 0.7397
# person: 0.6748
# person: 0.5546
# tennis racket: 0.5062
# frisbee: 0.4562
# frisbee: 0.3037
# frisbee: 0.4562
# frisbee: 0.4562
# frisbee: 0.4583
# frisbee: 0.4562
# frisbee: 0.4553
# frisbee: 0.4476
# frisbee: 0.4457
# frisbee: 0.4474
# frisbee: 0.4619
# frisbee: 0.4604
# frisbee: 0.4691
# frisbee: 0.4642
# frisbee: 0.4683
# frisbee: 0.4723
# frisbee: 0.4659
# frisbee: 0.4638
# frisbee: 0.4819
# frisbee: 0.5135
# frisbee: 0.5188
# frisbee: 0.5209
# frisbee: 0.5008
# person: 0.6676
# person: 0.6481
# person: 0.3757
# person: 0.3588
# person: 0.3572
# person: 0.3563
# person: 0.3499
# person: 0.6435
# person: 0.5741
# person: 0.5353
# person: 0.4002
# person: 0.3930
# person: 0.3587
# person: 0.3478
# person: 0.6845
# person: 0.6619
# person: 0.5502
# person: 0.4504
# person: 0.3778
# person: 0.3715
# person: 0.3692
# person: 0.3465
# person: 0.3143
# person: 0.3023
# person: 0.7289
# person: 0.6852
# person: 0.5255
# person: 0.3999
# person: 0.3611
# person: 0.3538
# person: 0.3321
# person: 0.3124
# person: 0.7491
# person: 0.6879
# person: 0.4594
# person: 0.4586
# person: 0.3717
# person: 0.3452
# person: 0.3382
# person: 0.3126
# person: 0.7370
# person: 0.6479
# person: 0.5193
# person: 0.4750
# bottle: 0.4522
# person: 0.3960
# person: 0.3522
# person: 0.3515
# person: 0.3189
# person: 0.7224
# person: 0.7062
# person: 0.4080
# person: 0.3797
# bottle: 0.3658
# person: 0.3508
# person: 0.3504
# person: 0.3462
# person: 0.3004
# person: 0.3001
# person: 0.7096
# person: 0.6513
# bottle: 0.5291
# person: 0.4242
# person: 0.4080
# person: 0.3951
# person: 0.3213
# person: 0.3199
# person: 0.3122
# person: 0.6726
# person: 0.6505
# bottle: 0.6084
# person: 0.5174
# person: 0.3696
# person: 0.3695
# person: 0.3354
# person: 0.3315
# person: 0.3298
# person: 0.3267
# person: 0.3240
# bottle: 0.7409
# person: 0.6641
# person: 0.6525
# person: 0.4730
# person: 0.4100
# person: 0.3742
# person: 0.3210
# person: 0.3038
# bottle: 0.6912
# person: 0.6273
# person: 0.6188
# person: 0.4509
# person: 0.3622
# person: 0.3312
# person: 0.3029
# bottle: 0.7586
# person: 0.6210
# person: 0.5855
# person: 0.3968
# person: 0.3870
# person: 0.3422
# person: 0.3303
# person: 0.3258
# person: 0.3162
# person: 0.6850
# person: 0.5903
# person: 0.4607
# bottle: 0.4365
# person: 0.4332
# person: 0.3692
# person: 0.3140
# person: 0.3059
# person: 0.6991
# person: 0.6026
# person: 0.5195
# person: 0.4763
# person: 0.3644
# person: 0.3588
# person: 0.3199
# person: 0.7146
# person: 0.6117
# person: 0.5938
# person: 0.5309
# person: 0.4115
# person: 0.4080
# person: 0.3547
# person: 0.3353
# person: 0.3001
# person: 0.6782
# person: 0.5934
# person: 0.5016
# person: 0.4275
# person: 0.4134
# person: 0.3516
# person: 0.3441
# person: 0.3191
# person: 0.3138
# person: 0.3133
# person: 0.6965
# person: 0.5636
# person: 0.5337
# person: 0.3985
# person: 0.3884
# person: 0.3868
# person: 0.3751
# person: 0.3724
# person: 0.3456
# person: 0.3060
# person: 0.6912
# person: 0.6031
# person: 0.5165
# person: 0.4788
# person: 0.4529
# person: 0.4381
# person: 0.4053
# person: 0.3888
# person: 0.3837
# person: 0.3570
# person: 0.3550
# person: 0.3395
# person: 0.6815
# person: 0.6371
# person: 0.5576
# person: 0.5224
# person: 0.4757
# person: 0.4675
# person: 0.4311
# person: 0.4126
# person: 0.4035
# person: 0.3838
# person: 0.3227
# person: 0.3112
# person: 0.6532
# person: 0.6222
# person: 0.5293
# person: 0.5268
# person: 0.4732
# person: 0.4542
# person: 0.4408
# person: 0.4242
# person: 0.3976
# person: 0.3634
# person: 0.3244
# person: 0.6920
# person: 0.6509
# person: 0.5959
# person: 0.5392
# person: 0.5304
# person: 0.4760
# person: 0.4601
# person: 0.4578
# person: 0.4157
# person: 0.3798
# person: 0.3261
# person: 0.3105
# person: 0.6923
# person: 0.6082
# person: 0.5898
# person: 0.5641
# person: 0.5443
# person: 0.5110
# person: 0.4847
# person: 0.4416
# person: 0.4115
# person: 0.4049
# person: 0.3072
# person: 0.6560
# person: 0.5718
# person: 0.5611
# person: 0.5454
# person: 0.5195
# person: 0.4928
# person: 0.4578
# person: 0.4485
# person: 0.3885
# person: 0.3665
# person: 0.3461
# person: 0.7022
# person: 0.5342
# person: 0.5169
# person: 0.4994
# person: 0.4607
# person: 0.4465
# person: 0.4230
# person: 0.4075
# person: 0.3972
# person: 0.3623
# person: 0.3209
# person: 0.6519
# person: 0.5208
# person: 0.5120
# person: 0.4362
# person: 0.4249
# person: 0.4182
# person: 0.3969
# person: 0.3606
# person: 0.3574
# bottle: 0.3570
# person: 0.3471
# person: 0.3466
# person: 0.3389
# person: 0.6136
# person: 0.5457
# person: 0.4873
# person: 0.4853
# person: 0.4398
# person: 0.4240
# person: 0.3442
# person: 0.3268
# person: 0.3255
# person: 0.3254
# person: 0.3194
# bottle: 0.3052
# person: 0.6888
# person: 0.5824
# person: 0.5304
# person: 0.5032
# person: 0.4455
# person: 0.3960
# person: 0.3828
# person: 0.3753
# person: 0.3668
# person: 0.3249
# person: 0.3243
# person: 0.3053
# person: 0.6933
# person: 0.6212
# person: 0.5192
# person: 0.4765
# person: 0.4589
# person: 0.4180
# person: 0.3816
# person: 0.3591
# person: 0.3426
# person: 0.3177
# person: 0.3054
# person: 0.3047
# person: 0.3003
# person: 0.7423
# person: 0.6166
# person: 0.5044
# person: 0.4409
# person: 0.4010
# person: 0.3320
# person: 0.3217
# person: 0.7006
# person: 0.6654
# person: 0.5319
# person: 0.3807
# bottle: 0.3394
# person: 0.3269
# person: 0.3158
# person: 0.3067
# person: 0.3047
# person: 0.3007
# person: 0.7238
# person: 0.6632
# person: 0.5272
# person: 0.4076
# person: 0.3567
# person: 0.3213
# person: 0.3067
# person: 0.7020
# person: 0.6126
# person: 0.6106
# person: 0.3936
# person: 0.3037
# person: 0.3034
# person: 0.3025
# person: 0.7322
# person: 0.6594
# person: 0.5902
# person: 0.4554
# person: 0.4030
# person: 0.3504
# person: 0.3479
# person: 0.3309
# person: 0.7021
# person: 0.4958
# person: 0.4675
# person: 0.4593
# person: 0.4480
# person: 0.4436
# person: 0.3524
# person: 0.3380
# person: 0.3217
# person: 0.7133
# person: 0.5848
# person: 0.4355
# person: 0.4020
# person: 0.3575
# person: 0.3313
# person: 0.3190
# person: 0.3159
# person: 0.3021
# person: 0.7623
# person: 0.5669
# person: 0.5153
# person: 0.4881
# person: 0.4179
# person: 0.3287
# person: 0.3215
# person: 0.7015
# person: 0.5070
# person: 0.4987
# person: 0.4879
# person: 0.4764
# person: 0.4453
# person: 0.3703
# person: 0.3415
# person: 0.3271
# person: 0.6993
# person: 0.6124
# person: 0.4692
# person: 0.4687
# person: 0.4579
# person: 0.4465
# person: 0.4162
# person: 0.3658
# person: 0.3165
# person: 0.6745
# person: 0.6205
# person: 0.4449
# person: 0.4166
# person: 0.3712
# person: 0.3645
# person: 0.3621
# person: 0.7409
# person: 0.5964
# person: 0.4696
# person: 0.4633
# person: 0.3884
# person: 0.3810
# person: 0.3072
# person: 0.3054
# person: 0.6835
# person: 0.5843
# person: 0.5280
# person: 0.4793
# person: 0.4118
# person: 0.3981
# person: 0.3765
# person: 0.3521
# person: 0.3389
# person: 0.6654
# person: 0.4544
# person: 0.4301
# person: 0.3781
# person: 0.3433
# person: 0.3420
# person: 0.3418
# person: 0.3416
# person: 0.9232
# person: 0.4755
# person: 0.9469
# person: 0.4303
# person: 0.9670
# person: 0.4465
# person: 0.9567
# person: 0.3818
# person: 0.9569
# person: 0.3824
# person: 0.9413
# person: 0.4072
# person: 0.9501
# person: 0.4503
# person: 0.3271
# person: 0.9393
# person: 0.7692
# person: 0.9183
# person: 0.7967
# person: 0.9210
# person: 0.7192
# person: 0.3350
# person: 0.9202
# person: 0.7205
# person: 0.3349
# person: 0.8793
# person: 0.7181
# person: 0.3438
# person: 0.3078
# person: 0.9051
# person: 0.7480
# person: 0.3412
# person: 0.3205
# person: 0.9261
# person: 0.8134
# person: 0.3218
# person: 0.8965
# person: 0.8590
# person: 0.3372
# person: 0.3132
# person: 0.9140
# person: 0.9100
# person: 0.3270
# person: 0.3235
# person: 0.9170
# person: 0.8749
# person: 0.3435
# person: 0.3353
# person: 0.3202
# person: 0.3153
# person: 0.9984
# person: 0.9970
# person: 0.7494
# person: 0.9971
# person: 0.9961
# person: 0.7913
# person: 0.9971
# person: 0.9961
# person: 0.7917
# person: 0.9975
# person: 0.9971
# person: 0.5234
# person: 0.9977
# person: 0.9960
# person: 0.9930
# person: 0.8767
# person: 0.9963
# person: 0.9906
# baseball bat: 0.4090
# person: 0.9710
# person: 0.9203
# person: 0.9980
# person: 0.9096
# baseball bat: 0.3414
# person: 0.9980
# person: 0.9102
# baseball bat: 0.3414
# person: 0.9943
# person: 0.9704
# person: 0.9492
# bird: 0.5251
# person: 0.9761
# person: 0.6582
# person: 0.3102
# person: 0.9911
# person: 0.9598
# person: 0.9911
# person: 0.9599
# person: 0.9933
# person: 0.9814
# person: 0.9863
# person: 0.9778
# person: 0.9544
# bird: 0.8943
# car: 0.3328
# person: 0.9837
# person: 0.9699
# car: 0.3855
# person: 0.9948
# person: 0.9934
# car: 0.3374
# person: 0.9944
# person: 0.9936
# car: 0.3318
# person: 0.9968
# person: 0.9911
# car: 0.3911
# person: 0.9931
# person: 0.9840
# car: 0.3707
# person: 0.9967
# person: 0.9895
# car: 0.3361
# person: 0.8672
# person: 0.6977
# person: 0.6857
# person: 0.6532
# person: 0.4747
# person: 0.4658
# person: 0.4168
# person: 0.3919
# person: 0.3134
# person: 0.3073
# person: 0.3067
# person: 0.9229
# person: 0.9066
# person: 0.6871
# person: 0.4419
# person: 0.4185
# person: 0.4088
# person: 0.3247
# person: 0.3124
# person: 0.9034
# person: 0.8623
# person: 0.4867
# person: 0.4073
# person: 0.3396
# person: 0.3233
# person: 0.3226
# person: 0.8957
# person: 0.8190
# person: 0.3766
# person: 0.3006
# person: 0.9407
# person: 0.4785
# person: 0.3941
# person: 0.3555
# person: 0.3269
# person: 0.9406
# person: 0.4789
# person: 0.3932
# person: 0.3559
# person: 0.3273
# person: 0.9198
# person: 0.3876
# person: 0.3128
# person: 0.8309
# person: 0.5955
# person: 0.3664
# person: 0.8255
# person: 0.5513
# person: 0.7521
# person: 0.6963
# person: 0.8649
# person: 0.8221
# person: 0.3448
# person: 0.3022
# person: 0.8649
# person: 0.8221
# person: 0.3448
# person: 0.3022
# person: 0.8416
# person: 0.7249
# person: 0.8419
# person: 0.7274
# person: 0.7711
# person: 0.6417
# person: 0.8543
# person: 0.5944
# person: 0.8556
# person: 0.5753
# person: 0.4344
# person: 0.4197
# person: 0.4138
# person: 0.4079
# person: 0.3364
# person: 0.8557
# person: 0.5753
# person: 0.4342
# person: 0.4197
# person: 0.4130
# person: 0.4081
# person: 0.3364
# person: 0.8699
# person: 0.4637
# person: 0.4437
# person: 0.4334
# person: 0.4005
# person: 0.3833
# person: 0.3647
# person: 0.9030
# person: 0.7375
# person: 0.4290
# person: 0.3467
# person: 0.3327
# person: 0.6882
# person: 0.5364
# person: 0.4668
# person: 0.4303
# mouse: 0.7942
# mouse: 0.4653
# mouse: 0.4501
# mouse: 0.5482
# sports ball: 0.3233
# tie: 0.4046
# sports ball: 0.3266
# stop sign: 0.5112
# mouse: 0.8882
# mouse: 0.6097
# mouse: 0.4107
# laptop: 0.3072
# mouse: 0.8423
# mouse: 0.6117
# cake: 0.4100
# mouse: 0.9513
# mouse: 0.8746
# laptop: 0.3217
# laptop: 0.6755
# bed: 0.3198
# clock: 0.5664
# kite: 0.8773
# kite: 0.7211
# stop sign: 0.5765
# stop sign: 0.6531
# donut: 0.3055
# airplane: 0.4059
# stop sign: 0.3194
# stop sign: 0.3231
# stop sign: 0.4289
# stop sign: 0.4408
# stop sign: 0.3305
# stop sign: 0.3973
# stop sign: 0.3386
# stop sign: 0.4112
# stop sign: 0.3246
# stop sign: 0.3586
# stop sign: 0.5057
# stop sign: 0.4938
# stop sign: 0.4051
# stop sign: 0.4892
# stop sign: 0.3564
# stop sign: 0.3559
# airplane: 0.4900
# airplane: 0.4471
# scissors: 0.3075
# scissors: 0.8325
# scissors: 0.4585
# airplane: 0.4366
# kite: 0.5661
# scissors: 0.3521
# scissors: 0.4280
# kite: 0.4194
# mouse: 0.6588
# No more Frames
# CPU times: user 30min 25s, sys: 48.4 s, total: 31min 14s
# Wall time: 18min 37s

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
