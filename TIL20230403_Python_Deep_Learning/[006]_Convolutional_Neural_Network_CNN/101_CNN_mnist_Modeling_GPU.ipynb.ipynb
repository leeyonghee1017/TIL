# %% [markdown]
# # MNIST - Categorical Classification
# > # Convolutional Neural Network

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.11.0'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization

# %% [markdown]
# * 범위: 0 ~ 1

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) Reshape
#
#  * (60000, 28, 28) to (60000, 28, 28, 1)

# %%
X_train = X_train.reshape((60000, 28, 28, 1))
X_test = X_test.reshape((10000, 28, 28, 1))

# %% [markdown]
# > ## 3) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 4) train_test_split( )
#
# * Train(48,000) vs. Validation(12,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((48000, 28, 28, 1), (48000, 10), (12000, 28, 28, 1), (12000, 10))

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction Layer

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters = 32, kernel_size = (3, 3),
                        strides = (1, 1), padding = 'valid',
                        activation = 'relu', input_shape = (28, 28, 1)))
model.add(layers.MaxPool2D(pool_size = (2, 2)))
model.add(layers.Conv2D(filters = 32, kernel_size = (3, 3),
                        strides = (1, 1), padding = 'valid',
                        activation = 'relu'))
model.add(layers.MaxPool2D(pool_size = (2, 2)))
model.add(layers.Conv2D(filters = 32, kernel_size = (3, 3),
                        strides = (1, 1), padding = 'valid',
                        activation = 'relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 32)          9248
#
# =================================================================
# Total params: 18,816
# Trainable params: 18,816
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Classification Layer

# %%
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 32)          9248
#
#  flatten (Flatten)           (None, 288)               0
#
#  dropout (Dropout)           (None, 288)               0
#
#  dense (Dense)               (None, 64)                18496
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 37,962
# Trainable params: 37,962
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 375/375 [==============================] - 16s 8ms/step - loss: 0.4530 - accuracy: 0.8566 - val_loss: 0.1254 - val_accuracy: 0.9635
# Epoch 2/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1515 - accuracy: 0.9524 - val_loss: 0.0790 - val_accuracy: 0.9768
# Epoch 3/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1062 - accuracy: 0.9672 - val_loss: 0.0625 - val_accuracy: 0.9818
# Epoch 4/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0854 - accuracy: 0.9730 - val_loss: 0.0603 - val_accuracy: 0.9827
# Epoch 5/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0726 - accuracy: 0.9768 - val_loss: 0.0515 - val_accuracy: 0.9848
# Epoch 6/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0626 - accuracy: 0.9804 - val_loss: 0.0454 - val_accuracy: 0.9869
# Epoch 7/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0590 - accuracy: 0.9820 - val_loss: 0.0416 - val_accuracy: 0.9878
# Epoch 8/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0551 - accuracy: 0.9830 - val_loss: 0.0431 - val_accuracy: 0.9885
# Epoch 9/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0494 - accuracy: 0.9841 - val_loss: 0.0381 - val_accuracy: 0.9898
# Epoch 10/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0453 - accuracy: 0.9856 - val_loss: 0.0408 - val_accuracy: 0.9892
# Epoch 11/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0437 - accuracy: 0.9869 - val_loss: 0.0371 - val_accuracy: 0.9902
# Epoch 12/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0411 - accuracy: 0.9871 - val_loss: 0.0384 - val_accuracy: 0.9893
# Epoch 13/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0377 - accuracy: 0.9880 - val_loss: 0.0358 - val_accuracy: 0.9902
# Epoch 14/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 0.0404 - val_accuracy: 0.9896
# Epoch 15/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0356 - accuracy: 0.9889 - val_loss: 0.0360 - val_accuracy: 0.9904
# Epoch 16/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0331 - accuracy: 0.9894 - val_loss: 0.0370 - val_accuracy: 0.9908
# Epoch 17/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0333 - accuracy: 0.9890 - val_loss: 0.0350 - val_accuracy: 0.9914
# Epoch 18/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0321 - accuracy: 0.9901 - val_loss: 0.0403 - val_accuracy: 0.9898
# Epoch 19/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 0.0357 - val_accuracy: 0.9911
# Epoch 20/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0299 - accuracy: 0.9909 - val_loss: 0.0351 - val_accuracy: 0.9912
# Epoch 21/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0282 - accuracy: 0.9906 - val_loss: 0.0356 - val_accuracy: 0.9910
# Epoch 22/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0277 - accuracy: 0.9911 - val_loss: 0.0343 - val_accuracy: 0.9912
# Epoch 23/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0254 - accuracy: 0.9916 - val_loss: 0.0355 - val_accuracy: 0.9911
# Epoch 24/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0336 - val_accuracy: 0.9913
# Epoch 25/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0259 - accuracy: 0.9912 - val_loss: 0.0337 - val_accuracy: 0.9919
# Epoch 26/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0241 - accuracy: 0.9921 - val_loss: 0.0392 - val_accuracy: 0.9914
# Epoch 27/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0244 - accuracy: 0.9921 - val_loss: 0.0422 - val_accuracy: 0.9912
# Epoch 28/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.0393 - val_accuracy: 0.9906
# Epoch 29/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0218 - accuracy: 0.9924 - val_loss: 0.0352 - val_accuracy: 0.9916
# Epoch 30/100
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0227 - accuracy: 0.9926 - val_loss: 0.0353 - val_accuracy: 0.9911
# Epoch 31/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0218 - accuracy: 0.9933 - val_loss: 0.0413 - val_accuracy: 0.9910
# Epoch 32/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.0372 - val_accuracy: 0.9910
# Epoch 33/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0375 - val_accuracy: 0.9916
# Epoch 34/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0404 - val_accuracy: 0.9911
# Epoch 35/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0206 - accuracy: 0.9930 - val_loss: 0.0443 - val_accuracy: 0.9911
# Epoch 36/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0193 - accuracy: 0.9935 - val_loss: 0.0372 - val_accuracy: 0.9911
# Epoch 37/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0197 - accuracy: 0.9933 - val_loss: 0.0375 - val_accuracy: 0.9915
# Epoch 38/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 0.0367 - val_accuracy: 0.9911
# Epoch 39/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0430 - val_accuracy: 0.9913
# Epoch 40/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0183 - accuracy: 0.9940 - val_loss: 0.0390 - val_accuracy: 0.9922
# Epoch 41/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.0387 - val_accuracy: 0.9924
# Epoch 42/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 0.0355 - val_accuracy: 0.9915
# Epoch 43/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.0403 - val_accuracy: 0.9916
# Epoch 44/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.0421 - val_accuracy: 0.9919
# Epoch 45/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0177 - accuracy: 0.9941 - val_loss: 0.0360 - val_accuracy: 0.9919
# Epoch 46/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.0541 - val_accuracy: 0.9895
# Epoch 47/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0175 - accuracy: 0.9948 - val_loss: 0.0366 - val_accuracy: 0.9920
# Epoch 48/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0165 - accuracy: 0.9945 - val_loss: 0.0379 - val_accuracy: 0.9921
# Epoch 49/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.0419 - val_accuracy: 0.9912
# Epoch 50/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0474 - val_accuracy: 0.9909
# Epoch 51/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.0374 - val_accuracy: 0.9921
# Epoch 52/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 0.0387 - val_accuracy: 0.9916
# Epoch 53/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0484 - val_accuracy: 0.9923
# Epoch 54/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.0467 - val_accuracy: 0.9918
# Epoch 55/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0431 - val_accuracy: 0.9930
# Epoch 56/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.0380 - val_accuracy: 0.9921
# Epoch 57/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0456 - val_accuracy: 0.9921
# Epoch 58/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.0468 - val_accuracy: 0.9919
# Epoch 59/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0134 - accuracy: 0.9958 - val_loss: 0.0445 - val_accuracy: 0.9923
# Epoch 60/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0412 - val_accuracy: 0.9929
# Epoch 61/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0536 - val_accuracy: 0.9893
# Epoch 62/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.0418 - val_accuracy: 0.9918
# Epoch 63/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0434 - val_accuracy: 0.9920
# Epoch 64/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0129 - accuracy: 0.9960 - val_loss: 0.0476 - val_accuracy: 0.9927
# Epoch 65/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 0.0472 - val_accuracy: 0.9918
# Epoch 66/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0422 - val_accuracy: 0.9927
# Epoch 67/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.0534 - val_accuracy: 0.9904
# Epoch 68/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9961 - val_loss: 0.0407 - val_accuracy: 0.9927
# Epoch 69/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0465 - val_accuracy: 0.9918
# Epoch 70/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.0499 - val_accuracy: 0.9915
# Epoch 71/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.0511 - val_accuracy: 0.9913
# Epoch 72/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0478 - val_accuracy: 0.9923
# Epoch 73/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0503 - val_accuracy: 0.9928
# Epoch 74/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0124 - accuracy: 0.9959 - val_loss: 0.0478 - val_accuracy: 0.9923
# Epoch 75/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0433 - val_accuracy: 0.9927
# Epoch 76/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0129 - accuracy: 0.9956 - val_loss: 0.0413 - val_accuracy: 0.9927
# Epoch 77/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.0468 - val_accuracy: 0.9922
# Epoch 78/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0507 - val_accuracy: 0.9924
# Epoch 79/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.0556 - val_accuracy: 0.9923
# Epoch 80/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.0547 - val_accuracy: 0.9915
# Epoch 81/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.0515 - val_accuracy: 0.9912
# Epoch 82/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0486 - val_accuracy: 0.9923
# Epoch 83/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0558 - val_accuracy: 0.9916
# Epoch 84/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0118 - accuracy: 0.9959 - val_loss: 0.0452 - val_accuracy: 0.9924
# Epoch 85/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0458 - val_accuracy: 0.9925
# Epoch 86/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0494 - val_accuracy: 0.9915
# Epoch 87/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0490 - val_accuracy: 0.9920
# Epoch 88/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0585 - val_accuracy: 0.9908
# Epoch 89/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0410 - val_accuracy: 0.9916
# Epoch 90/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0564 - val_accuracy: 0.9914
# Epoch 91/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.0516 - val_accuracy: 0.9923
# Epoch 92/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0453 - val_accuracy: 0.9916
# Epoch 93/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.0554 - val_accuracy: 0.9909
# Epoch 94/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0101 - accuracy: 0.9965 - val_loss: 0.0491 - val_accuracy: 0.9916
# Epoch 95/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0534 - val_accuracy: 0.9914
# Epoch 96/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0467 - val_accuracy: 0.9917
# Epoch 97/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0528 - val_accuracy: 0.9912
# Epoch 98/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0118 - accuracy: 0.9960 - val_loss: 0.0484 - val_accuracy: 0.9918
# Epoch 99/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0475 - val_accuracy: 0.9923
# Epoch 100/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.0581 - val_accuracy: 0.9921
# CPU times: user 3min 38s, sys: 17.8 s, total: 3min 55s
# Wall time: 3min 47s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_mnist.history['loss'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_mnist.history['accuracy'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.03491
# Accuracy = 0.99410

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
