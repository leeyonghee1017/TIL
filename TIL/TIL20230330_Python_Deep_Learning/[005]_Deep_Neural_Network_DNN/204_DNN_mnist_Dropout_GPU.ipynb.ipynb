# %% [markdown]
# # MNIST - Categorical Classification
# > # Dropout

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization and Reshape

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 3) train_test_split( )
#
# * Train(48,000) vs. Validation(12,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 2개의 Hidden Layers & 768개의 Nodes
#  - Model Capacity는 기존과 동일
#  - Dropout Layers 적용

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dropout(0.5))
mnist.add(layers.Dense(256, activation = 'relu'))
mnist.add(layers.Dropout(0.3))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 375/375 [==============================] - 11s 8ms/step - loss: 0.3642 - accuracy: 0.8881 - val_loss: 0.1497 - val_accuracy: 0.9544
# Epoch 2/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1740 - accuracy: 0.9476 - val_loss: 0.1239 - val_accuracy: 0.9638
# Epoch 3/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1306 - accuracy: 0.9596 - val_loss: 0.1146 - val_accuracy: 0.9657
# Epoch 4/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1120 - accuracy: 0.9665 - val_loss: 0.0964 - val_accuracy: 0.9735
# Epoch 5/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1006 - accuracy: 0.9690 - val_loss: 0.0962 - val_accuracy: 0.9728
# Epoch 6/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0904 - accuracy: 0.9725 - val_loss: 0.0959 - val_accuracy: 0.9746
# Epoch 7/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0813 - accuracy: 0.9754 - val_loss: 0.0861 - val_accuracy: 0.9771
# Epoch 8/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0740 - accuracy: 0.9772 - val_loss: 0.0880 - val_accuracy: 0.9761
# Epoch 9/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0708 - accuracy: 0.9789 - val_loss: 0.0856 - val_accuracy: 0.9787
# Epoch 10/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0683 - accuracy: 0.9794 - val_loss: 0.0862 - val_accuracy: 0.9777
# Epoch 11/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0617 - accuracy: 0.9814 - val_loss: 0.0849 - val_accuracy: 0.9797
# Epoch 12/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0585 - accuracy: 0.9818 - val_loss: 0.0854 - val_accuracy: 0.9808
# Epoch 13/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0546 - accuracy: 0.9840 - val_loss: 0.0906 - val_accuracy: 0.9793
# Epoch 14/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0524 - accuracy: 0.9837 - val_loss: 0.0874 - val_accuracy: 0.9794
# Epoch 15/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0509 - accuracy: 0.9847 - val_loss: 0.0956 - val_accuracy: 0.9786
# Epoch 16/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0481 - accuracy: 0.9856 - val_loss: 0.0885 - val_accuracy: 0.9812
# Epoch 17/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0473 - accuracy: 0.9861 - val_loss: 0.0881 - val_accuracy: 0.9818
# Epoch 18/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0448 - accuracy: 0.9867 - val_loss: 0.0892 - val_accuracy: 0.9812
# Epoch 19/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0450 - accuracy: 0.9864 - val_loss: 0.0926 - val_accuracy: 0.9814
# Epoch 20/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0410 - accuracy: 0.9874 - val_loss: 0.0939 - val_accuracy: 0.9800
# Epoch 21/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0403 - accuracy: 0.9873 - val_loss: 0.1013 - val_accuracy: 0.9802
# Epoch 22/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0396 - accuracy: 0.9883 - val_loss: 0.0987 - val_accuracy: 0.9811
# Epoch 23/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0383 - accuracy: 0.9885 - val_loss: 0.0972 - val_accuracy: 0.9818
# Epoch 24/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0390 - accuracy: 0.9887 - val_loss: 0.0997 - val_accuracy: 0.9808
# Epoch 25/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0367 - accuracy: 0.9890 - val_loss: 0.0947 - val_accuracy: 0.9814
# Epoch 26/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0353 - accuracy: 0.9897 - val_loss: 0.1011 - val_accuracy: 0.9815
# Epoch 27/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0362 - accuracy: 0.9895 - val_loss: 0.1061 - val_accuracy: 0.9808
# Epoch 28/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.1000 - val_accuracy: 0.9808
# Epoch 29/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0345 - accuracy: 0.9896 - val_loss: 0.1039 - val_accuracy: 0.9815
# Epoch 30/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0348 - accuracy: 0.9898 - val_loss: 0.1053 - val_accuracy: 0.9810
# Epoch 31/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0316 - accuracy: 0.9904 - val_loss: 0.1004 - val_accuracy: 0.9811
# Epoch 32/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0307 - accuracy: 0.9912 - val_loss: 0.0928 - val_accuracy: 0.9823
# Epoch 33/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0302 - accuracy: 0.9908 - val_loss: 0.0984 - val_accuracy: 0.9812
# Epoch 34/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0290 - accuracy: 0.9911 - val_loss: 0.1070 - val_accuracy: 0.9821
# Epoch 35/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0287 - accuracy: 0.9917 - val_loss: 0.1075 - val_accuracy: 0.9823
# Epoch 36/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0281 - accuracy: 0.9914 - val_loss: 0.1063 - val_accuracy: 0.9820
# Epoch 37/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0279 - accuracy: 0.9918 - val_loss: 0.1110 - val_accuracy: 0.9831
# Epoch 38/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0252 - accuracy: 0.9921 - val_loss: 0.1065 - val_accuracy: 0.9829
# Epoch 39/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0273 - accuracy: 0.9919 - val_loss: 0.1103 - val_accuracy: 0.9820
# Epoch 40/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0251 - accuracy: 0.9922 - val_loss: 0.1145 - val_accuracy: 0.9814
# Epoch 41/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0267 - accuracy: 0.9922 - val_loss: 0.1173 - val_accuracy: 0.9821
# Epoch 42/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0255 - accuracy: 0.9925 - val_loss: 0.1166 - val_accuracy: 0.9817
# Epoch 43/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0267 - accuracy: 0.9919 - val_loss: 0.1157 - val_accuracy: 0.9832
# Epoch 44/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0270 - accuracy: 0.9923 - val_loss: 0.1116 - val_accuracy: 0.9824
# Epoch 45/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0272 - accuracy: 0.9921 - val_loss: 0.1168 - val_accuracy: 0.9822
# Epoch 46/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0248 - accuracy: 0.9929 - val_loss: 0.1187 - val_accuracy: 0.9822
# Epoch 47/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0240 - accuracy: 0.9934 - val_loss: 0.1135 - val_accuracy: 0.9826
# Epoch 48/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0234 - accuracy: 0.9929 - val_loss: 0.1146 - val_accuracy: 0.9822
# Epoch 49/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0251 - accuracy: 0.9929 - val_loss: 0.1241 - val_accuracy: 0.9821
# Epoch 50/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0243 - accuracy: 0.9929 - val_loss: 0.1196 - val_accuracy: 0.9822
# Epoch 51/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0239 - accuracy: 0.9933 - val_loss: 0.1226 - val_accuracy: 0.9824
# Epoch 52/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0227 - accuracy: 0.9935 - val_loss: 0.1263 - val_accuracy: 0.9812
# Epoch 53/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0231 - accuracy: 0.9934 - val_loss: 0.1297 - val_accuracy: 0.9820
# Epoch 54/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0243 - accuracy: 0.9931 - val_loss: 0.1260 - val_accuracy: 0.9817
# Epoch 55/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0212 - accuracy: 0.9940 - val_loss: 0.1306 - val_accuracy: 0.9820
# Epoch 56/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0206 - accuracy: 0.9939 - val_loss: 0.1309 - val_accuracy: 0.9822
# Epoch 57/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0191 - accuracy: 0.9948 - val_loss: 0.1242 - val_accuracy: 0.9823
# Epoch 58/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0216 - accuracy: 0.9935 - val_loss: 0.1287 - val_accuracy: 0.9828
# Epoch 59/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0220 - accuracy: 0.9940 - val_loss: 0.1316 - val_accuracy: 0.9817
# Epoch 60/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0198 - accuracy: 0.9946 - val_loss: 0.1395 - val_accuracy: 0.9816
# Epoch 61/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0210 - accuracy: 0.9936 - val_loss: 0.1266 - val_accuracy: 0.9834
# Epoch 62/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0207 - accuracy: 0.9940 - val_loss: 0.1306 - val_accuracy: 0.9827
# Epoch 63/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0218 - accuracy: 0.9940 - val_loss: 0.1286 - val_accuracy: 0.9828
# Epoch 64/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0223 - accuracy: 0.9930 - val_loss: 0.1302 - val_accuracy: 0.9827
# Epoch 65/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.1327 - val_accuracy: 0.9818
# Epoch 66/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.1284 - val_accuracy: 0.9816
# Epoch 67/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.1342 - val_accuracy: 0.9826
# Epoch 68/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.1392 - val_accuracy: 0.9819
# Epoch 69/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.1416 - val_accuracy: 0.9829
# Epoch 70/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0193 - accuracy: 0.9945 - val_loss: 0.1388 - val_accuracy: 0.9815
# Epoch 71/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0193 - accuracy: 0.9948 - val_loss: 0.1318 - val_accuracy: 0.9843
# Epoch 72/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.1377 - val_accuracy: 0.9833
# Epoch 73/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.1380 - val_accuracy: 0.9833
# Epoch 74/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0180 - accuracy: 0.9951 - val_loss: 0.1371 - val_accuracy: 0.9836
# Epoch 75/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0179 - accuracy: 0.9949 - val_loss: 0.1318 - val_accuracy: 0.9838
# Epoch 76/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.1409 - val_accuracy: 0.9826
# Epoch 77/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0171 - accuracy: 0.9951 - val_loss: 0.1539 - val_accuracy: 0.9822
# Epoch 78/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0187 - accuracy: 0.9949 - val_loss: 0.1368 - val_accuracy: 0.9840
# Epoch 79/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.1434 - val_accuracy: 0.9833
# Epoch 80/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0198 - accuracy: 0.9947 - val_loss: 0.1409 - val_accuracy: 0.9842
# Epoch 81/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.1427 - val_accuracy: 0.9835
# Epoch 82/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0184 - accuracy: 0.9954 - val_loss: 0.1360 - val_accuracy: 0.9833
# Epoch 83/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0177 - accuracy: 0.9953 - val_loss: 0.1328 - val_accuracy: 0.9843
# Epoch 84/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.1435 - val_accuracy: 0.9834
# Epoch 85/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0189 - accuracy: 0.9951 - val_loss: 0.1556 - val_accuracy: 0.9817
# Epoch 86/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.1357 - val_accuracy: 0.9843
# Epoch 87/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0158 - accuracy: 0.9956 - val_loss: 0.1470 - val_accuracy: 0.9838
# Epoch 88/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.1395 - val_accuracy: 0.9846
# Epoch 89/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0156 - accuracy: 0.9951 - val_loss: 0.1457 - val_accuracy: 0.9830
# Epoch 90/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0184 - accuracy: 0.9953 - val_loss: 0.1406 - val_accuracy: 0.9835
# Epoch 91/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.1407 - val_accuracy: 0.9832
# Epoch 92/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.1419 - val_accuracy: 0.9822
# Epoch 93/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.1435 - val_accuracy: 0.9835
# Epoch 94/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.1415 - val_accuracy: 0.9833
# Epoch 95/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0148 - accuracy: 0.9960 - val_loss: 0.1459 - val_accuracy: 0.9837
# Epoch 96/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 0.1498 - val_accuracy: 0.9830
# Epoch 97/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0139 - accuracy: 0.9959 - val_loss: 0.1489 - val_accuracy: 0.9837
# Epoch 98/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.1607 - val_accuracy: 0.9815
# Epoch 99/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0164 - accuracy: 0.9955 - val_loss: 0.1537 - val_accuracy: 0.9827
# Epoch 100/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0139 - accuracy: 0.9959 - val_loss: 0.1480 - val_accuracy: 0.9839
# CPU times: user 2min 34s, sys: 15.9 s, total: 2min 50s
# Wall time: 2min 43s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_mnist.history['loss'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 0.35)
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_mnist.history['accuracy'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.11444
# Accuracy = 0.98580

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
