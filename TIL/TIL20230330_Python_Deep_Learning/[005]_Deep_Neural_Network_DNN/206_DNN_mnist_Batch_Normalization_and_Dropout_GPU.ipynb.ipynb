# %% [markdown]
# # MNIST - Categorical Classification
# > # Batch Normalization & Dropout

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization and Reshape

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 3) train_test_split( )
#
# * Train(48,000) vs. Validation(12,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  * 활성화 함수의 입력값을 정규화 과정을 수행하여 전달
#  * Gradient Vanishing 문제 해결 및 더 큰 Learning Rate를 사용 가능

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, input_shape=(28 * 28,)))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dropout(0.5))
mnist.add(layers.Dense(256))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dropout(0.3))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 538,890
# Trainable params: 537,354
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 4분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 375/375 [==============================] - 11s 6ms/step - loss: 0.3295 - accuracy: 0.8988 - val_loss: 0.1591 - val_accuracy: 0.9525
# Epoch 2/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1760 - accuracy: 0.9460 - val_loss: 0.1304 - val_accuracy: 0.9618
# Epoch 3/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1389 - accuracy: 0.9574 - val_loss: 0.1159 - val_accuracy: 0.9661
# Epoch 4/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1207 - accuracy: 0.9641 - val_loss: 0.1019 - val_accuracy: 0.9718
# Epoch 5/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1082 - accuracy: 0.9673 - val_loss: 0.1061 - val_accuracy: 0.9707
# Epoch 6/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0980 - accuracy: 0.9702 - val_loss: 0.0956 - val_accuracy: 0.9753
# Epoch 7/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0905 - accuracy: 0.9722 - val_loss: 0.0864 - val_accuracy: 0.9775
# Epoch 8/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0850 - accuracy: 0.9739 - val_loss: 0.0876 - val_accuracy: 0.9763
# Epoch 9/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0787 - accuracy: 0.9762 - val_loss: 0.0889 - val_accuracy: 0.9781
# Epoch 10/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0759 - accuracy: 0.9773 - val_loss: 0.0855 - val_accuracy: 0.9792
# Epoch 11/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0682 - accuracy: 0.9788 - val_loss: 0.0861 - val_accuracy: 0.9792
# Epoch 12/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0679 - accuracy: 0.9796 - val_loss: 0.0866 - val_accuracy: 0.9789
# Epoch 13/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0667 - accuracy: 0.9791 - val_loss: 0.0862 - val_accuracy: 0.9806
# Epoch 14/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0631 - accuracy: 0.9808 - val_loss: 0.0928 - val_accuracy: 0.9786
# Epoch 15/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0595 - accuracy: 0.9816 - val_loss: 0.0930 - val_accuracy: 0.9781
# Epoch 16/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0592 - accuracy: 0.9820 - val_loss: 0.0854 - val_accuracy: 0.9808
# Epoch 17/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0537 - accuracy: 0.9834 - val_loss: 0.0941 - val_accuracy: 0.9795
# Epoch 18/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0563 - accuracy: 0.9828 - val_loss: 0.0940 - val_accuracy: 0.9787
# Epoch 19/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0492 - accuracy: 0.9848 - val_loss: 0.0908 - val_accuracy: 0.9802
# Epoch 20/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0506 - accuracy: 0.9845 - val_loss: 0.0866 - val_accuracy: 0.9805
# Epoch 21/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0523 - accuracy: 0.9850 - val_loss: 0.0884 - val_accuracy: 0.9814
# Epoch 22/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0481 - accuracy: 0.9848 - val_loss: 0.0929 - val_accuracy: 0.9801
# Epoch 23/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0482 - accuracy: 0.9851 - val_loss: 0.0961 - val_accuracy: 0.9805
# Epoch 24/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0450 - accuracy: 0.9865 - val_loss: 0.1005 - val_accuracy: 0.9806
# Epoch 25/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0466 - accuracy: 0.9862 - val_loss: 0.0939 - val_accuracy: 0.9822
# Epoch 26/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0421 - accuracy: 0.9874 - val_loss: 0.0906 - val_accuracy: 0.9805
# Epoch 27/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0416 - accuracy: 0.9877 - val_loss: 0.0963 - val_accuracy: 0.9816
# Epoch 28/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0414 - accuracy: 0.9877 - val_loss: 0.0956 - val_accuracy: 0.9811
# Epoch 29/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0402 - accuracy: 0.9878 - val_loss: 0.0970 - val_accuracy: 0.9822
# Epoch 30/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0415 - accuracy: 0.9879 - val_loss: 0.0989 - val_accuracy: 0.9808
# Epoch 31/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0380 - accuracy: 0.9891 - val_loss: 0.1007 - val_accuracy: 0.9797
# Epoch 32/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0384 - accuracy: 0.9886 - val_loss: 0.1011 - val_accuracy: 0.9809
# Epoch 33/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0381 - accuracy: 0.9884 - val_loss: 0.1085 - val_accuracy: 0.9805
# Epoch 34/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0362 - accuracy: 0.9890 - val_loss: 0.1040 - val_accuracy: 0.9818
# Epoch 35/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0338 - accuracy: 0.9897 - val_loss: 0.1009 - val_accuracy: 0.9821
# Epoch 36/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0374 - accuracy: 0.9887 - val_loss: 0.0993 - val_accuracy: 0.9817
# Epoch 37/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0354 - accuracy: 0.9890 - val_loss: 0.1079 - val_accuracy: 0.9811
# Epoch 38/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0345 - accuracy: 0.9898 - val_loss: 0.1037 - val_accuracy: 0.9821
# Epoch 39/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0354 - accuracy: 0.9892 - val_loss: 0.0997 - val_accuracy: 0.9810
# Epoch 40/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0332 - accuracy: 0.9898 - val_loss: 0.1172 - val_accuracy: 0.9809
# Epoch 41/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9899 - val_loss: 0.1083 - val_accuracy: 0.9815
# Epoch 42/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0362 - accuracy: 0.9893 - val_loss: 0.1046 - val_accuracy: 0.9822
# Epoch 43/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0323 - accuracy: 0.9908 - val_loss: 0.1049 - val_accuracy: 0.9827
# Epoch 44/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0328 - accuracy: 0.9909 - val_loss: 0.1110 - val_accuracy: 0.9817
# Epoch 45/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0338 - accuracy: 0.9906 - val_loss: 0.1057 - val_accuracy: 0.9818
# Epoch 46/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0335 - accuracy: 0.9903 - val_loss: 0.1081 - val_accuracy: 0.9822
# Epoch 47/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0341 - accuracy: 0.9903 - val_loss: 0.1105 - val_accuracy: 0.9822
# Epoch 48/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0289 - accuracy: 0.9908 - val_loss: 0.1182 - val_accuracy: 0.9808
# Epoch 49/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0335 - accuracy: 0.9909 - val_loss: 0.1134 - val_accuracy: 0.9820
# Epoch 50/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0295 - accuracy: 0.9915 - val_loss: 0.1188 - val_accuracy: 0.9815
# Epoch 51/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0338 - accuracy: 0.9898 - val_loss: 0.1096 - val_accuracy: 0.9832
# Epoch 52/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0314 - accuracy: 0.9914 - val_loss: 0.1157 - val_accuracy: 0.9817
# Epoch 53/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0290 - accuracy: 0.9919 - val_loss: 0.1094 - val_accuracy: 0.9815
# Epoch 54/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0320 - accuracy: 0.9905 - val_loss: 0.1095 - val_accuracy: 0.9834
# Epoch 55/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0288 - accuracy: 0.9916 - val_loss: 0.1125 - val_accuracy: 0.9822
# Epoch 56/100
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0276 - accuracy: 0.9918 - val_loss: 0.1068 - val_accuracy: 0.9826
# Epoch 57/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0304 - accuracy: 0.9912 - val_loss: 0.1090 - val_accuracy: 0.9828
# Epoch 58/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0280 - accuracy: 0.9918 - val_loss: 0.1132 - val_accuracy: 0.9829
# Epoch 59/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.1125 - val_accuracy: 0.9825
# Epoch 60/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0265 - accuracy: 0.9924 - val_loss: 0.1128 - val_accuracy: 0.9827
# Epoch 61/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0298 - accuracy: 0.9917 - val_loss: 0.1180 - val_accuracy: 0.9819
# Epoch 62/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.1157 - val_accuracy: 0.9820
# Epoch 63/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0303 - accuracy: 0.9917 - val_loss: 0.1163 - val_accuracy: 0.9833
# Epoch 64/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0273 - accuracy: 0.9925 - val_loss: 0.1159 - val_accuracy: 0.9823
# Epoch 65/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0256 - accuracy: 0.9927 - val_loss: 0.1146 - val_accuracy: 0.9819
# Epoch 66/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0265 - accuracy: 0.9925 - val_loss: 0.1180 - val_accuracy: 0.9830
# Epoch 67/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0245 - accuracy: 0.9927 - val_loss: 0.1143 - val_accuracy: 0.9827
# Epoch 68/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0264 - accuracy: 0.9926 - val_loss: 0.1159 - val_accuracy: 0.9828
# Epoch 69/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0269 - accuracy: 0.9925 - val_loss: 0.1191 - val_accuracy: 0.9823
# Epoch 70/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0268 - accuracy: 0.9929 - val_loss: 0.1140 - val_accuracy: 0.9826
# Epoch 71/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.1221 - val_accuracy: 0.9825
# Epoch 72/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0255 - accuracy: 0.9923 - val_loss: 0.1188 - val_accuracy: 0.9829
# Epoch 73/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0240 - accuracy: 0.9928 - val_loss: 0.1214 - val_accuracy: 0.9828
# Epoch 74/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0242 - accuracy: 0.9933 - val_loss: 0.1170 - val_accuracy: 0.9827
# Epoch 75/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0271 - accuracy: 0.9921 - val_loss: 0.1233 - val_accuracy: 0.9815
# Epoch 76/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.1212 - val_accuracy: 0.9824
# Epoch 77/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0228 - accuracy: 0.9937 - val_loss: 0.1225 - val_accuracy: 0.9822
# Epoch 78/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0249 - accuracy: 0.9933 - val_loss: 0.1221 - val_accuracy: 0.9827
# Epoch 79/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0248 - accuracy: 0.9927 - val_loss: 0.1220 - val_accuracy: 0.9817
# Epoch 80/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0264 - accuracy: 0.9922 - val_loss: 0.1179 - val_accuracy: 0.9825
# Epoch 81/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0221 - accuracy: 0.9937 - val_loss: 0.1214 - val_accuracy: 0.9824
# Epoch 82/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0263 - accuracy: 0.9927 - val_loss: 0.1211 - val_accuracy: 0.9818
# Epoch 83/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0233 - accuracy: 0.9933 - val_loss: 0.1220 - val_accuracy: 0.9822
# Epoch 84/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.1238 - val_accuracy: 0.9827
# Epoch 85/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0232 - accuracy: 0.9931 - val_loss: 0.1221 - val_accuracy: 0.9822
# Epoch 86/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0256 - accuracy: 0.9931 - val_loss: 0.1225 - val_accuracy: 0.9823
# Epoch 87/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0235 - accuracy: 0.9936 - val_loss: 0.1262 - val_accuracy: 0.9822
# Epoch 88/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0232 - accuracy: 0.9935 - val_loss: 0.1267 - val_accuracy: 0.9822
# Epoch 89/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0225 - accuracy: 0.9936 - val_loss: 0.1273 - val_accuracy: 0.9831
# Epoch 90/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0255 - accuracy: 0.9931 - val_loss: 0.1298 - val_accuracy: 0.9822
# Epoch 91/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0203 - accuracy: 0.9944 - val_loss: 0.1211 - val_accuracy: 0.9828
# Epoch 92/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0246 - accuracy: 0.9934 - val_loss: 0.1245 - val_accuracy: 0.9827
# Epoch 93/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0226 - accuracy: 0.9938 - val_loss: 0.1299 - val_accuracy: 0.9828
# Epoch 94/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0243 - accuracy: 0.9937 - val_loss: 0.1241 - val_accuracy: 0.9822
# Epoch 95/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0234 - accuracy: 0.9935 - val_loss: 0.1202 - val_accuracy: 0.9827
# Epoch 96/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0249 - accuracy: 0.9931 - val_loss: 0.1212 - val_accuracy: 0.9830
# Epoch 97/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0245 - accuracy: 0.9936 - val_loss: 0.1250 - val_accuracy: 0.9828
# Epoch 98/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0213 - accuracy: 0.9944 - val_loss: 0.1209 - val_accuracy: 0.9822
# Epoch 99/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0222 - accuracy: 0.9936 - val_loss: 0.1183 - val_accuracy: 0.9827
# Epoch 100/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0227 - accuracy: 0.9935 - val_loss: 0.1216 - val_accuracy: 0.9833
# CPU times: user 3min 4s, sys: 16.7 s, total: 3min 20s
# Wall time: 3min 11s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_mnist.history['loss'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 0.35)
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_mnist.history['accuracy'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.09059
# Accuracy = 0.98520

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
