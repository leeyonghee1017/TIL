# %% [markdown]
# # MNIST - Categorical Classification
# > # Batch Normalization

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization and Reshape

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 3) train_test_split( )
#
# * Train(48,000) vs. Validation(12,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  * 활성화 함수의 입력값을 정규화 과정을 수행하여 전달
#  * Gradient Vanishing 문제 해결 및 더 큰 Learning Rate를 사용 가능

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, input_shape=(28 * 28,)))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(256))
mnist.add(layers.BatchNormalization())
mnist.add(layers.Activation('relu'))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_1 (Activation)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 538,890
# Trainable params: 537,354
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 4분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 375/375 [==============================] - 11s 8ms/step - loss: 0.1801 - accuracy: 0.9462 - val_loss: 0.1470 - val_accuracy: 0.9557
# Epoch 2/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0717 - accuracy: 0.9783 - val_loss: 0.0973 - val_accuracy: 0.9719
# Epoch 3/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0435 - accuracy: 0.9865 - val_loss: 0.1099 - val_accuracy: 0.9678
# Epoch 4/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0289 - accuracy: 0.9913 - val_loss: 0.1066 - val_accuracy: 0.9715
# Epoch 5/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 0.0877 - val_accuracy: 0.9752
# Epoch 6/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.0975 - val_accuracy: 0.9747
# Epoch 7/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0125 - accuracy: 0.9959 - val_loss: 0.0982 - val_accuracy: 0.9768
# Epoch 8/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0100 - accuracy: 0.9969 - val_loss: 0.1013 - val_accuracy: 0.9765
# Epoch 9/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.1012 - val_accuracy: 0.9778
# Epoch 10/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0941 - val_accuracy: 0.9793
# Epoch 11/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.1012 - val_accuracy: 0.9781
# Epoch 12/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0976 - val_accuracy: 0.9797
# Epoch 13/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0970 - val_accuracy: 0.9794
# Epoch 14/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0921 - val_accuracy: 0.9820
# Epoch 15/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1024 - val_accuracy: 0.9804
# Epoch 16/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1017 - val_accuracy: 0.9803
# Epoch 17/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0981 - val_accuracy: 0.9810
# Epoch 18/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.6591e-04 - accuracy: 0.9999 - val_loss: 0.0905 - val_accuracy: 0.9827
# Epoch 19/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.2271e-04 - accuracy: 0.9998 - val_loss: 0.0964 - val_accuracy: 0.9816
# Epoch 20/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.0902e-04 - accuracy: 0.9998 - val_loss: 0.1018 - val_accuracy: 0.9826
# Epoch 21/100
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1023 - val_accuracy: 0.9819
# Epoch 22/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0991 - val_accuracy: 0.9831
# Epoch 23/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.1004 - val_accuracy: 0.9818
# Epoch 24/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.1017 - val_accuracy: 0.9822
# Epoch 25/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.1617e-04 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9826
# Epoch 26/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.0215e-04 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9831
# Epoch 27/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.8081e-04 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9833
# Epoch 28/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.6776e-04 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9836
# Epoch 29/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.3611e-04 - accuracy: 0.9999 - val_loss: 0.0989 - val_accuracy: 0.9831
# Epoch 30/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.8574e-04 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 0.9832
# Epoch 31/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.6706e-04 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 0.9837
# Epoch 32/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0751e-04 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 0.9840
# Epoch 33/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1640e-04 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9841
# Epoch 34/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.9081e-05 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9845
# Epoch 35/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.7868e-05 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 0.9843
# Epoch 36/100
# 375/375 [==============================] - 2s 6ms/step - loss: 3.0351e-05 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9843
# Epoch 37/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.5153e-05 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9840
# Epoch 38/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.4195e-05 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9839
# Epoch 39/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.8631e-05 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9847
# Epoch 40/100
# 375/375 [==============================] - 2s 6ms/step - loss: 2.8162e-05 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9837
# Epoch 41/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.2667e-05 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 0.9841
# Epoch 42/100
# 375/375 [==============================] - 2s 5ms/step - loss: 6.6331e-05 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9837
# Epoch 43/100
# 375/375 [==============================] - 2s 6ms/step - loss: 1.9980e-05 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9841
# Epoch 44/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.1980e-05 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9839
# Epoch 45/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.0297e-05 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 0.9844
# Epoch 46/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.8307e-05 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9842
# Epoch 47/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6323e-05 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9843
# Epoch 48/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.5977e-05 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 0.9841
# Epoch 49/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2851e-05 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 0.9843
# Epoch 50/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.2983e-05 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9844
# Epoch 51/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2703e-05 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9843
# Epoch 52/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.7669e-05 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 0.9843
# Epoch 53/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.3128e-05 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9839
# Epoch 54/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0182e-05 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 0.9839
# Epoch 55/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.7426e-06 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9838
# Epoch 56/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1711e-05 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9840
# Epoch 57/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1390e-05 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9843
# Epoch 58/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1300e-05 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9842
# Epoch 59/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0552e-05 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 0.9838
# Epoch 60/100
# 375/375 [==============================] - 3s 7ms/step - loss: 1.4359e-05 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9842
# Epoch 61/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.8556e-05 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9843
# Epoch 62/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.3317e-05 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 0.9842
# Epoch 63/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.8831e-05 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9841
# Epoch 64/100
# 375/375 [==============================] - 2s 6ms/step - loss: 1.0072e-05 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9843
# Epoch 65/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0837e-05 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 0.9836
# Epoch 66/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.9099e-06 - accuracy: 1.0000 - val_loss: 0.1025 - val_accuracy: 0.9838
# Epoch 67/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.5305e-06 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 0.9838
# Epoch 68/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.0886e-06 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9840
# Epoch 69/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2313e-05 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9840
# Epoch 70/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.1367e-06 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 0.9839
# Epoch 71/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0276e-05 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 0.9839
# Epoch 72/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.5675e-04 - accuracy: 0.9999 - val_loss: 0.1049 - val_accuracy: 0.9836
# Epoch 73/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.9518e-05 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9836
# Epoch 74/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.6830e-05 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9840
# Epoch 75/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1901e-05 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9838
# Epoch 76/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.0843e-05 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 0.9837
# Epoch 77/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.2019e-05 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9839
# Epoch 78/100
# 375/375 [==============================] - 2s 5ms/step - loss: 9.7289e-05 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9833
# Epoch 79/100
# 375/375 [==============================] - 2s 6ms/step - loss: 1.1092e-05 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9840
# Epoch 80/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.8432e-06 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9839
# Epoch 81/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.0475e-06 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9839
# Epoch 82/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.0042e-06 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9837
# Epoch 83/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.9974e-06 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9839
# Epoch 84/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.0244e-05 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 0.9841
# Epoch 85/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.6166e-06 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.9840
# Epoch 86/100
# 375/375 [==============================] - 2s 6ms/step - loss: 7.4060e-06 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9839
# Epoch 87/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.6939e-06 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9839
# Epoch 88/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.1822e-06 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 0.9843
# Epoch 89/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.5489e-06 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9842
# Epoch 90/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.6918e-06 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9837
# Epoch 91/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.1597e-05 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 0.9836
# Epoch 92/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.7021e-06 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9836
# Epoch 93/100
# 375/375 [==============================] - 2s 6ms/step - loss: 7.5333e-06 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9838
# Epoch 94/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.6976e-06 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9835
# Epoch 95/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.8358e-06 - accuracy: 1.0000 - val_loss: 0.1046 - val_accuracy: 0.9837
# Epoch 96/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.3315e-06 - accuracy: 1.0000 - val_loss: 0.1046 - val_accuracy: 0.9841
# Epoch 97/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.1572e-06 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9838
# Epoch 98/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.8116e-06 - accuracy: 1.0000 - val_loss: 0.1044 - val_accuracy: 0.9839
# Epoch 99/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.3149e-06 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9837
# Epoch 100/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.8222e-06 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9841
# CPU times: user 2min 52s, sys: 16.6 s, total: 3min 9s
# Wall time: 3min 25s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_mnist.history['loss'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 0.35)
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_mnist.history['accuracy'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.08236
# Accuracy = 0.98520

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
