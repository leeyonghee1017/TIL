# %% [markdown]
# # MNIST - Categorical Classification
# > # Model Capacity

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization and Reshape

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 3) train_test_split( )
#
# * Train(48,000) vs. Validation(12,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 1개의 Hidden Layer & 256개의 Nodes
#  - Model Capacity 낮게 조정

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(256, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               200960
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 375/375 [==============================] - 9s 7ms/step - loss: 0.3215 - accuracy: 0.9101 - val_loss: 0.2009 - val_accuracy: 0.9412
# Epoch 2/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1472 - accuracy: 0.9574 - val_loss: 0.1400 - val_accuracy: 0.9588
# Epoch 3/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1003 - accuracy: 0.9709 - val_loss: 0.1166 - val_accuracy: 0.9659
# Epoch 4/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0751 - accuracy: 0.9782 - val_loss: 0.1025 - val_accuracy: 0.9694
# Epoch 5/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0588 - accuracy: 0.9827 - val_loss: 0.0925 - val_accuracy: 0.9727
# Epoch 6/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0465 - accuracy: 0.9864 - val_loss: 0.0916 - val_accuracy: 0.9740
# Epoch 7/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0375 - accuracy: 0.9891 - val_loss: 0.0882 - val_accuracy: 0.9752
# Epoch 8/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0301 - accuracy: 0.9916 - val_loss: 0.0856 - val_accuracy: 0.9753
# Epoch 9/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0243 - accuracy: 0.9933 - val_loss: 0.0842 - val_accuracy: 0.9778
# Epoch 10/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0198 - accuracy: 0.9949 - val_loss: 0.0836 - val_accuracy: 0.9762
# Epoch 11/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0160 - accuracy: 0.9960 - val_loss: 0.0897 - val_accuracy: 0.9763
# Epoch 12/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 0.9971 - val_loss: 0.0868 - val_accuracy: 0.9774
# Epoch 13/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.9978 - val_loss: 0.0863 - val_accuracy: 0.9780
# Epoch 14/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0078 - accuracy: 0.9984 - val_loss: 0.0940 - val_accuracy: 0.9758
# Epoch 15/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.1037 - val_accuracy: 0.9744
# Epoch 16/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0047 - accuracy: 0.9993 - val_loss: 0.0956 - val_accuracy: 0.9762
# Epoch 17/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.1006 - val_accuracy: 0.9763
# Epoch 18/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.0983 - val_accuracy: 0.9778
# Epoch 19/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.0979 - val_accuracy: 0.9780
# Epoch 20/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.1070 - val_accuracy: 0.9764
# Epoch 21/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9782
# Epoch 22/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.0630e-04 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9781
# Epoch 23/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.2218e-04 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9784
# Epoch 24/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.3310e-04 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9785
# Epoch 25/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.3749e-04 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 0.9790
# Epoch 26/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.8010e-04 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 0.9783
# Epoch 27/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.4897e-04 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 0.9783
# Epoch 28/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.1952e-04 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 0.9784
# Epoch 29/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.8282e-04 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9784
# Epoch 30/100
# 375/375 [==============================] - 1s 4ms/step - loss: 2.6086e-04 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 0.9793
# Epoch 31/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.4415e-04 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9792
# Epoch 32/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.2626e-04 - accuracy: 1.0000 - val_loss: 0.1085 - val_accuracy: 0.9787
# Epoch 33/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.1172e-04 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 0.9790
# Epoch 34/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.0062e-04 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 0.9788
# Epoch 35/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.8931e-04 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9787
# Epoch 36/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7938e-04 - accuracy: 1.0000 - val_loss: 0.1114 - val_accuracy: 0.9787
# Epoch 37/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7175e-04 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9791
# Epoch 38/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.6169e-04 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 0.9788
# Epoch 39/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.5567e-04 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9787
# Epoch 40/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4816e-04 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9785
# Epoch 41/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4187e-04 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9787
# Epoch 42/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3645e-04 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 0.9791
# Epoch 43/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3053e-04 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 0.9788
# Epoch 44/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2493e-04 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 0.9787
# Epoch 45/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2071e-04 - accuracy: 1.0000 - val_loss: 0.1148 - val_accuracy: 0.9787
# Epoch 46/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1765e-04 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 0.9787
# Epoch 47/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1296e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9786
# Epoch 48/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0933e-04 - accuracy: 1.0000 - val_loss: 0.1156 - val_accuracy: 0.9785
# Epoch 49/100
# 375/375 [==============================] - 1s 4ms/step - loss: 1.0594e-04 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9787
# Epoch 50/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0274e-04 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9787
# Epoch 51/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.9687e-05 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 0.9788
# Epoch 52/100
# 375/375 [==============================] - 1s 4ms/step - loss: 9.6682e-05 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 0.9790
# Epoch 53/100
# 375/375 [==============================] - 2s 5ms/step - loss: 9.3696e-05 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9789
# Epoch 54/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.1463e-05 - accuracy: 1.0000 - val_loss: 0.1177 - val_accuracy: 0.9789
# Epoch 55/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.8720e-05 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9788
# Epoch 56/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.6324e-05 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9789
# Epoch 57/100
# 375/375 [==============================] - 1s 4ms/step - loss: 8.4246e-05 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 0.9787
# Epoch 58/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.2273e-05 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.9787
# Epoch 59/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.0296e-05 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9791
# Epoch 60/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.8206e-05 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9789
# Epoch 61/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.6435e-05 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9786
# Epoch 62/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.4790e-05 - accuracy: 1.0000 - val_loss: 0.1197 - val_accuracy: 0.9787
# Epoch 63/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.3073e-05 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 0.9788
# Epoch 64/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.1408e-05 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9790
# Epoch 65/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.9964e-05 - accuracy: 1.0000 - val_loss: 0.1205 - val_accuracy: 0.9788
# Epoch 66/100
# 375/375 [==============================] - 1s 4ms/step - loss: 6.8303e-05 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 0.9788
# Epoch 67/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.6948e-05 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 0.9788
# Epoch 68/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.5632e-05 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 0.9790
# Epoch 69/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.4446e-05 - accuracy: 1.0000 - val_loss: 0.1212 - val_accuracy: 0.9789
# Epoch 70/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.2983e-05 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9790
# Epoch 71/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.1990e-05 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 0.9787
# Epoch 72/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.0528e-05 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9789
# Epoch 73/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.9609e-05 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 0.9791
# Epoch 74/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.8262e-05 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9788
# Epoch 75/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.7507e-05 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9787
# Epoch 76/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.6490e-05 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9787
# Epoch 77/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.5454e-05 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9791
# Epoch 78/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.4394e-05 - accuracy: 1.0000 - val_loss: 0.1233 - val_accuracy: 0.9790
# Epoch 79/100
# 375/375 [==============================] - 1s 4ms/step - loss: 5.3705e-05 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9786
# Epoch 80/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.2662e-05 - accuracy: 1.0000 - val_loss: 0.1236 - val_accuracy: 0.9788
# Epoch 81/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.1844e-05 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9789
# Epoch 82/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.1050e-05 - accuracy: 1.0000 - val_loss: 0.1238 - val_accuracy: 0.9789
# Epoch 83/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.0296e-05 - accuracy: 1.0000 - val_loss: 0.1241 - val_accuracy: 0.9789
# Epoch 84/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.9385e-05 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9792
# Epoch 85/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.8723e-05 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9789
# Epoch 86/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.7913e-05 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9791
# Epoch 87/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.7128e-05 - accuracy: 1.0000 - val_loss: 0.1245 - val_accuracy: 0.9792
# Epoch 88/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.6562e-05 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9786
# Epoch 89/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.5864e-05 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 0.9789
# Epoch 90/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.5249e-05 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9791
# Epoch 91/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.4625e-05 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.9790
# Epoch 92/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.3950e-05 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9787
# Epoch 93/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.3346e-05 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9790
# Epoch 94/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.2786e-05 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 0.9788
# Epoch 95/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.2241e-05 - accuracy: 1.0000 - val_loss: 0.1259 - val_accuracy: 0.9789
# Epoch 96/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.1580e-05 - accuracy: 1.0000 - val_loss: 0.1260 - val_accuracy: 0.9790
# Epoch 97/100
# 375/375 [==============================] - 1s 4ms/step - loss: 4.1107e-05 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9787
# Epoch 98/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.0444e-05 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9788
# Epoch 99/100
# 375/375 [==============================] - 1s 4ms/step - loss: 3.9919e-05 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9790
# Epoch 100/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.9503e-05 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 0.9790
# CPU times: user 2min 13s, sys: 15.2 s, total: 2min 28s
# Wall time: 2min 19s

# %% [markdown]
# > ## 4) 학습 결과 시각화 - Overfitting

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_mnist.history['loss'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim(0, 0.35)
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_mnist.history['accuracy'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.09906
# Accuracy = 0.97990

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
