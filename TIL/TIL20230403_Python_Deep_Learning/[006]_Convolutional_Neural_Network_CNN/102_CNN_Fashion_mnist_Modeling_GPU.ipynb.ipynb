# %% [markdown]
# # Fashion MNIST - Categorical Classification
# > # Convolutional Neural Network

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.11.0'

# %% [markdown]
# # I. Fashion MNIST Data_Set Load

# %%
from tensorflow.keras.datasets import fashion_mnist

(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization

# %% [markdown]
# * 범위: 0 ~ 1

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) Reshape
#
#  * (60000, 28, 28) to (60000, 28, 28, 1)

# %%
X_train = X_train.reshape((60000, 28, 28, 1))
X_test = X_test.reshape((10000, 28, 28, 1))

# %% [markdown]
# > ## 3) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 4) train_test_split( )
#
# * Train(48,000) vs. Validation(12,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((48000, 28, 28, 1), (48000, 10), (12000, 28, 28, 1), (12000, 10))

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction Layer

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters = 32, kernel_size = (3, 3),
                        strides = (1, 1), padding = 'valid',
                        activation = 'relu', input_shape = (28, 28, 1)))
model.add(layers.MaxPool2D(pool_size = (2, 2)))
model.add(layers.Conv2D(filters = 64, kernel_size = (3, 3),
                        strides = (1, 1), padding = 'valid',
                        activation = 'relu'))
model.add(layers.MaxPool2D(pool_size = (2, 2)))
model.add(layers.Conv2D(filters = 64, kernel_size = (3, 3),
                        strides = (1, 1), padding = 'valid',
                        activation = 'relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
# =================================================================
# Total params: 55,744
# Trainable params: 55,744
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Classification Layer

# %%
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dropout (Dropout)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 50,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/50
# 375/375 [==============================] - 17s 8ms/step - loss: 0.7264 - accuracy: 0.7297 - val_loss: 0.4558 - val_accuracy: 0.8317
# Epoch 2/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.4444 - accuracy: 0.8371 - val_loss: 0.3731 - val_accuracy: 0.8657
# Epoch 3/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3894 - accuracy: 0.8579 - val_loss: 0.3342 - val_accuracy: 0.8817
# Epoch 4/50
# 375/375 [==============================] - 2s 7ms/step - loss: 0.3542 - accuracy: 0.8703 - val_loss: 0.3061 - val_accuracy: 0.8893
# Epoch 5/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3247 - accuracy: 0.8810 - val_loss: 0.2916 - val_accuracy: 0.8921
# Epoch 6/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3093 - accuracy: 0.8860 - val_loss: 0.2820 - val_accuracy: 0.8967
# Epoch 7/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2945 - accuracy: 0.8924 - val_loss: 0.2642 - val_accuracy: 0.9016
# Epoch 8/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2827 - accuracy: 0.8963 - val_loss: 0.2627 - val_accuracy: 0.9024
# Epoch 9/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2688 - accuracy: 0.9020 - val_loss: 0.2535 - val_accuracy: 0.9057
# Epoch 10/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2614 - accuracy: 0.9029 - val_loss: 0.2508 - val_accuracy: 0.9078
# Epoch 11/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2532 - accuracy: 0.9066 - val_loss: 0.2496 - val_accuracy: 0.9080
# Epoch 12/50
# 375/375 [==============================] - 3s 8ms/step - loss: 0.2438 - accuracy: 0.9099 - val_loss: 0.2337 - val_accuracy: 0.9158
# Epoch 13/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2332 - accuracy: 0.9137 - val_loss: 0.2342 - val_accuracy: 0.9139
# Epoch 14/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2273 - accuracy: 0.9168 - val_loss: 0.2395 - val_accuracy: 0.9122
# Epoch 15/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2225 - accuracy: 0.9174 - val_loss: 0.2318 - val_accuracy: 0.9168
# Epoch 16/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2166 - accuracy: 0.9180 - val_loss: 0.2283 - val_accuracy: 0.9156
# Epoch 17/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2129 - accuracy: 0.9212 - val_loss: 0.2188 - val_accuracy: 0.9203
# Epoch 18/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2068 - accuracy: 0.9235 - val_loss: 0.2471 - val_accuracy: 0.9080
# Epoch 19/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1988 - accuracy: 0.9251 - val_loss: 0.2379 - val_accuracy: 0.9122
# Epoch 20/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1971 - accuracy: 0.9251 - val_loss: 0.2259 - val_accuracy: 0.9186
# Epoch 21/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1900 - accuracy: 0.9294 - val_loss: 0.2251 - val_accuracy: 0.9182
# Epoch 22/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1866 - accuracy: 0.9301 - val_loss: 0.2358 - val_accuracy: 0.9178
# Epoch 23/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1831 - accuracy: 0.9298 - val_loss: 0.2261 - val_accuracy: 0.9184
# Epoch 24/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1781 - accuracy: 0.9322 - val_loss: 0.2250 - val_accuracy: 0.9210
# Epoch 25/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1740 - accuracy: 0.9345 - val_loss: 0.2199 - val_accuracy: 0.9213
# Epoch 26/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1709 - accuracy: 0.9349 - val_loss: 0.2238 - val_accuracy: 0.9229
# Epoch 27/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1666 - accuracy: 0.9370 - val_loss: 0.2222 - val_accuracy: 0.9236
# Epoch 28/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1671 - accuracy: 0.9362 - val_loss: 0.2235 - val_accuracy: 0.9220
# Epoch 29/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1616 - accuracy: 0.9385 - val_loss: 0.2223 - val_accuracy: 0.9239
# Epoch 30/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1600 - accuracy: 0.9395 - val_loss: 0.2275 - val_accuracy: 0.9220
# Epoch 31/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1547 - accuracy: 0.9413 - val_loss: 0.2366 - val_accuracy: 0.9232
# Epoch 32/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1557 - accuracy: 0.9420 - val_loss: 0.2244 - val_accuracy: 0.9226
# Epoch 33/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1513 - accuracy: 0.9420 - val_loss: 0.2248 - val_accuracy: 0.9224
# Epoch 34/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1455 - accuracy: 0.9456 - val_loss: 0.2378 - val_accuracy: 0.9208
# Epoch 35/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1445 - accuracy: 0.9451 - val_loss: 0.2297 - val_accuracy: 0.9214
# Epoch 36/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1442 - accuracy: 0.9449 - val_loss: 0.2362 - val_accuracy: 0.9195
# Epoch 37/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1407 - accuracy: 0.9459 - val_loss: 0.2329 - val_accuracy: 0.9199
# Epoch 38/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1385 - accuracy: 0.9463 - val_loss: 0.2373 - val_accuracy: 0.9199
# Epoch 39/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1342 - accuracy: 0.9483 - val_loss: 0.2320 - val_accuracy: 0.9225
# Epoch 40/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1333 - accuracy: 0.9494 - val_loss: 0.2288 - val_accuracy: 0.9201
# Epoch 41/50
# 375/375 [==============================] - 3s 9ms/step - loss: 0.1331 - accuracy: 0.9503 - val_loss: 0.2460 - val_accuracy: 0.9206
# Epoch 42/50
# 375/375 [==============================] - 2s 6ms/step - loss: 0.1298 - accuracy: 0.9502 - val_loss: 0.2342 - val_accuracy: 0.9245
# Epoch 43/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1269 - accuracy: 0.9516 - val_loss: 0.2472 - val_accuracy: 0.9217
# Epoch 44/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1290 - accuracy: 0.9513 - val_loss: 0.2491 - val_accuracy: 0.9202
# Epoch 45/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1256 - accuracy: 0.9518 - val_loss: 0.2517 - val_accuracy: 0.9183
# Epoch 46/50
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1228 - accuracy: 0.9532 - val_loss: 0.2280 - val_accuracy: 0.9266
# Epoch 47/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1200 - accuracy: 0.9543 - val_loss: 0.2376 - val_accuracy: 0.9226
# Epoch 48/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1232 - accuracy: 0.9520 - val_loss: 0.2347 - val_accuracy: 0.9214
# Epoch 49/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1197 - accuracy: 0.9553 - val_loss: 0.2404 - val_accuracy: 0.9245
# Epoch 50/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1188 - accuracy: 0.9546 - val_loss: 0.2437 - val_accuracy: 0.9248
# CPU times: user 1min 51s, sys: 9.31 s, total: 2min 1s
# Wall time: 2min 3s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_mnist.history['loss'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_mnist.history['accuracy'], 'b-')
plt.plot(epochs, Hist_mnist.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.28335
# Accuracy = 0.91370

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
