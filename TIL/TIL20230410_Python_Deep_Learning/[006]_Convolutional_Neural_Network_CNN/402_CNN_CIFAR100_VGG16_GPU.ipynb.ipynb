# %% [markdown]
# # CIFAR100 - Categorical Classification
# > # VGG16

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.11.0'

# %% [markdown]
# # I. CIFAR100 Data_Set Load

# %%
from tensorflow.keras.datasets import cifar100

(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode = 'fine')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 3s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((50000,  32, 32, 3))
X_test = X_test.reshape((10000,  32, 32, 3))

# %% [markdown]
# * Scaling

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

X_train = preprocess_input(X_train)
X_test = preprocess_input(X_test)

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 3) train_test_split( )
#
# * Train(40,000) vs. Validation(10,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((40000, 32, 32, 3), (40000, 100), (10000, 32, 32, 3), (10000, 100))

# %% [markdown]
# # III. Import VGG16 Model

# %% [markdown]
# > ## 1) conv_base

# %%
from tensorflow.keras.applications import VGG16

conv_base = VGG16(weights = 'imagenet',
                  include_top = False,
                  input_shape = (32, 32, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step

# %% [markdown]
# # IV. Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(conv_base)

model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1024, activation = 'relu'))
model.add(layers.Dense(100, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 1, 512)         14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 100)               102500
#
# =================================================================
# Total params: 15,342,500
# Trainable params: 15,342,500
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
from tensorflow.keras import optimizers

model.compile(loss = 'categorical_crossentropy',
              optimizer = optimizers.Adam(learning_rate = 0.00005),
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 6분

# %%
# %%time

Hist_model = model.fit(X_train, y_train,
                       epochs = 15,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/15
# 313/313 [==============================] - 34s 62ms/step - loss: 4.7425 - accuracy: 0.0163 - val_loss: 4.3345 - val_accuracy: 0.0473
# Epoch 2/15
# 313/313 [==============================] - 17s 53ms/step - loss: 4.2757 - accuracy: 0.0378 - val_loss: 3.8514 - val_accuracy: 0.1078
# Epoch 3/15
# 313/313 [==============================] - 17s 54ms/step - loss: 3.8473 - accuracy: 0.0978 - val_loss: 3.1366 - val_accuracy: 0.2322
# Epoch 4/15
# 313/313 [==============================] - 18s 56ms/step - loss: 3.2856 - accuracy: 0.1983 - val_loss: 2.6421 - val_accuracy: 0.3394
# Epoch 5/15
# 313/313 [==============================] - 17s 55ms/step - loss: 2.7760 - accuracy: 0.2997 - val_loss: 2.2752 - val_accuracy: 0.4145
# Epoch 6/15
# 313/313 [==============================] - 17s 56ms/step - loss: 2.3151 - accuracy: 0.3957 - val_loss: 2.0334 - val_accuracy: 0.4670
# Epoch 7/15
# 313/313 [==============================] - 18s 56ms/step - loss: 1.9404 - accuracy: 0.4817 - val_loss: 1.8918 - val_accuracy: 0.5047
# Epoch 8/15
# 313/313 [==============================] - 18s 56ms/step - loss: 1.6444 - accuracy: 0.5493 - val_loss: 1.8154 - val_accuracy: 0.5313
# Epoch 9/15
# 313/313 [==============================] - 18s 56ms/step - loss: 1.3837 - accuracy: 0.6138 - val_loss: 1.8039 - val_accuracy: 0.5459
# Epoch 10/15
# 313/313 [==============================] - 18s 57ms/step - loss: 1.1644 - accuracy: 0.6676 - val_loss: 1.7540 - val_accuracy: 0.5642
# Epoch 11/15
# 313/313 [==============================] - 18s 56ms/step - loss: 0.9473 - accuracy: 0.7233 - val_loss: 1.8697 - val_accuracy: 0.5652
# Epoch 12/15
# 313/313 [==============================] - 18s 57ms/step - loss: 0.7709 - accuracy: 0.7709 - val_loss: 1.8548 - val_accuracy: 0.5741
# Epoch 13/15
# 313/313 [==============================] - 18s 56ms/step - loss: 0.6169 - accuracy: 0.8151 - val_loss: 2.0162 - val_accuracy: 0.5789
# Epoch 14/15
# 313/313 [==============================] - 18s 57ms/step - loss: 0.5044 - accuracy: 0.8470 - val_loss: 2.0596 - val_accuracy: 0.5840
# Epoch 15/15
# 313/313 [==============================] - 18s 57ms/step - loss: 0.4014 - accuracy: 0.8762 - val_loss: 2.1932 - val_accuracy: 0.5809
# CPU times: user 3min 30s, sys: 8.17 s, total: 3min 38s
# Wall time: 4min 39s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_model.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_model.history['loss'], 'b-')
plt.plot(epochs, Hist_model.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_model.history['accuracy'], 'b-')
plt.plot(epochs, Hist_model.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 2.20210
# Accuracy = 0.57850

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
