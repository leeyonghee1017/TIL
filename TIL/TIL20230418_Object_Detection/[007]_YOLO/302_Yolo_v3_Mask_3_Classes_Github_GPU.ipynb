# %% [markdown]
# # YOLO_v3 Custom Dataset (3 Classes)
#
# * https://github.com/AlexeyAB/darknet#custom-object-detection

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. GPU & CUDA & cuDNN

# %% [markdown]
# >## 1) GPU Type

# %%
# !nvidia-smi
# Out:
# Sun Apr  9 00:58:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    14W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# >## 2) CUDA Version

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %% [markdown]
# > ## 3) cuDNN Library Version

# %%
# !cat /usr/include/x86_64-linux-gnu/cudnn_v*.h | grep CUDNN_MAJOR -A 2
# Out:
# #define CUDNN_MAJOR 8
# #define CUDNN_MINOR 7
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# /* cannot use constexpr here since this is a C-only file */

# %% [markdown]
# # II. Custom Data_Set
#
# * 3 Classes

# %% [markdown]
# >##  1) wget From Github
#
# * 'maskdataset_3C.tar' 파일 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tara{a,b,c,d,e}
# Out:
# --2023-04-09 00:58:36--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.taraa
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.taraa’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   328MB/s    in 0.3s
#
# 2023-04-09 00:58:43 (328 MB/s) - ‘maskdataset_3C.taraa’ saved [94371840/94371840]
#
# --2023-04-09 00:58:43--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarab
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarab’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   234MB/s    in 0.4s
#
# 2023-04-09 00:58:49 (234 MB/s) - ‘maskdataset_3C.tarab’ saved [94371840/94371840]
#
# --2023-04-09 00:58:49--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarac
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarac’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   418MB/s    in 0.2s
#
# 2023-04-09 00:58:54 (418 MB/s) - ‘maskdataset_3C.tarac’ saved [94371840/94371840]
#
# --2023-04-09 00:58:54--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarad
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 94371840 (90M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarad’
#
# maskdataset_3C.tara 100%[===================>]  90.00M   357MB/s    in 0.3s
#
# 2023-04-09 00:59:01 (357 MB/s) - ‘maskdataset_3C.tarad’ saved [94371840/94371840]
#
# --2023-04-09 00:59:01--  https://raw.githubusercontent.com/rusita-ai/pyData/master/maskdataset_3C.tarae
# Reusing existing connection to raw.githubusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 40448000 (39M) [application/octet-stream]
# Saving to: ‘maskdataset_3C.tarae’
#
# maskdataset_3C.tara 100%[===================>]  38.57M  --.-KB/s    in 0.1s
#
# 2023-04-09 00:59:04 (268 MB/s) - ‘maskdataset_3C.tarae’ saved [40448000/40448000]
#
# FINISHED --2023-04-09 00:59:04--
# Total wall clock time: 28s
# Downloaded: 5 files, 399M in 1.3s (314 MB/s)

# %% [markdown]
# * 현재 작업 경로

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# * 다운로드 결과 확인

# %%
# !ls -l
# Out:
# total 408144
# -rw-r--r-- 1 root root 94371840 Apr  9 00:58 maskdataset_3C.taraa
# -rw-r--r-- 1 root root 94371840 Apr  9 00:58 maskdataset_3C.tarab
# -rw-r--r-- 1 root root 94371840 Apr  9 00:58 maskdataset_3C.tarac
# -rw-r--r-- 1 root root 94371840 Apr  9 00:59 maskdataset_3C.tarad
# -rw-r--r-- 1 root root 40448000 Apr  9 00:59 maskdataset_3C.tarae
# drwxr-xr-x 1 root root     4096 Apr  6 13:39 sample_data

# %% [markdown]
# >## 2) Unzip

# %%
# !cat maskdataset_3C.tar* | tar xf -

# %% [markdown]
# > ## 3) 결과 확인

# %%
# !ls -l '/content/yolo_custom_modeling'
# Out:
# total 12
# -rw-r--r-- 1 root root 2523 Feb  1 15:06 creating-files-data-and-name.py
# -rw-r--r-- 1 root root 3024 Feb  2 02:16 creating-train-and-test-txt-files.py
# drwxr-xr-x 5 root root 4096 Feb  2 02:15 dataset

# %% [markdown]
# > ## 4) 'custom_data' & 'darknet' 설치경로 설정

# %%
# %cd /content/yolo_custom_modeling
# Out:
# /content/yolo_custom_modeling

# %% [markdown]
# # III. Train vs. Test Split

# %% [markdown]
# * 현재 작업 경로

# %%
# !pwd
# Out:
# /content/yolo_custom_modeling

# %% [markdown]
# >## 1) classes.txt 생성

# %%
classes_text = """mask
w_mask
no_mask"""

with open("/content/yolo_custom_modeling/dataset/classes.txt", 'w') as file:
    file.write(classes_text)

# %% [markdown]
# * 생성 확인

# %%
# %cat /content/yolo_custom_modeling/dataset/classes.txt
# Out:
# mask
# w_mask
# no_mask

# %% [markdown]
# >## 2) Image & Label 리스트 지정

# %% [markdown]
# * 'images' & 'labels' 디렉토리 확인

# %%
from glob import glob

img_list = glob('/content/yolo_custom_modeling/dataset/images/*.png')
txt_list = glob('/content/yolo_custom_modeling/dataset/labels/*.txt')

print('IMG_LIST : ', len(img_list))
print('TXT_LIST : ', len(txt_list))
# Out:
# IMG_LIST :  843
# TXT_LIST :  843

# %% [markdown]
# * Label 파일을 'images' 디렉토리로 이동
#
#  - 약 2분

# %%
for a in txt_list:
  # !mv {a} /content/yolo_custom_modeling/dataset/images

# %% [markdown]
# * 이동결과 확인

# %%
img_list = glob('/content/yolo_custom_modeling/dataset/images/*.*')
txt_list = glob('/content/yolo_custom_modeling/dataset/labels/*.txt')

print('IMG_LIST : ', len(img_list))
print('TXT_LIST : ', len(txt_list))
# Out:
# IMG_LIST :  1686
# TXT_LIST :  0

# %% [markdown]
# > ## 3) 'labelled_data.data' 파일 생성

# %% [markdown]
# * creating-files-data-and-name.py

# %%
# !python creating-files-data-and-name.py

# %% [markdown]
# * 생성 확인

# %%
# !ls -l /content/yolo_custom_modeling/dataset/labelled_data.data
# Out:
# -rw-r--r-- 1 root root 107 Apr  9 01:00 /content/yolo_custom_modeling/dataset/labelled_data.data

# %% [markdown]
# > ## 4) Train & Test Data 목록 생성
#
# * creating-train-and-test-txt-files.py
#  - 7:3

# %%
# !python creating-train-and-test-txt-files.py

# %% [markdown]
# * 생성 확인

# %%
# !ls -l dataset/*.txt
# Out:
# -rw-r--r-- 1 root root    19 Apr  9 00:59 dataset/classes.txt
# -rw-r--r-- 1 root root  8785 Apr  9 01:00 dataset/test.txt
# -rw-r--r-- 1 root root 20610 Apr  9 01:00 dataset/train.txt

# %% [markdown]
# # IV. 'darknet' Setting

# %% [markdown]
# > ## 1) 'darknet' Clone

# %% [markdown]
# * 현재 작업 경로

# %%
# !pwd
# Out:
# /content/yolo_custom_modeling

# %% [markdown]
# * darknet Clone

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15514, done.
# remote: Total 15514 (delta 0), reused 0 (delta 0), pack-reused 15514
# Receiving objects: 100% (15514/15514), 14.16 MiB | 12.40 MiB/s, done.
# Resolving deltas: 100% (10413/10413), done.

# %% [markdown]
# * Clone 확인

# %%
# %ls -l
# Out:
# total 16
# -rw-r--r--  1 root root 2523 Feb  1 15:06 creating-files-data-and-name.py
# -rw-r--r--  1 root root 3024 Feb  2 02:16 creating-train-and-test-txt-files.py
# drwxr-xr-x 14 root root 4096 Apr  9 01:00 darknet/
# drwxr-xr-x  5 root root 4096 Apr  9 01:00 dataset/

# %% [markdown]
# > ## 2) 'Makefile' Configuration

# %% [markdown]
# * darknet 디렉토리로 이동

# %%
# %cd darknet/
# Out:
# /content/yolo_custom_modeling/darknet

# %% [markdown]
# * Makefile 확인

# %%
# !ls -l Makefile
# Out:
# -rw-r--r-- 1 root root 5961 Apr  9 01:00 Makefile

# %% [markdown]
# * Makefile 수정

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %% [markdown]
# > ## 3) 'darknet' Installation

# %% [markdown]
# * Makefile 실행
#  -  약 2분

# %%
# %%time

# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  1147 |             if (iteration_old == 0)
#       |             ^~
# ./src/image_opencv.cpp:1150:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#  1150 |          if (iteration_old != 0){
#       |          ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1444:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1444 |         char buff[100];
#       |              ^~~~
# ./src/image_opencv.cpp:1420:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#  1420 |     int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1424:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#  1424 |     int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1428:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#  1428 |     int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1431:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#  1431 |     int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#       |         ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:511:95: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#   511 |                 sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#       |                                                                                             ~~^           ~~~~~~
#       |                                                                                               |           |
#       |                                                                                               |           int
#       |                                                                                               long unsigned int
#       |                                                                                             %u
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   867 |         for (int i = 0; i < v.size(); ++i) {
#       |                         ~~^~~~~~~~~~
# ./src/http_stream.cpp:875:33: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   875 |     for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#       |                          ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:894:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   894 |     for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#       |                         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:930:28: warning: comparison of integer expressions of different signedness: ‘std::deque<std::vector<detection_t> >::size_type’ {aka ‘long unsigned int’} and ‘int’ [-Wsign-compare]
#   930 |     if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#       |         ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2044:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#  2044 |     const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#       |               ^~~~~
# ./src/gemm.c:2043:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#  2043 |     const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1061:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#  1061 |     while (c = *str++)
#       |            ^
# In file included from /usr/include/string.h:495,
#                  from include/darknet.h:14,
#                  from ./src/utils.h:3,
#                  from ./src/utils.c:4:
# In function ‘strncpy’,
#     inlined from ‘copy_string’ at ./src/utils.c:531:5:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:106:10: warning: ‘__builtin_strncpy’ specified bound depends on the length of the source argument [-Wstringop-overflow=]
#   106 |   return __builtin___strncpy_chk (__dest, __src, __len, __bos (__dest));
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/utils.c: In function ‘copy_string’:
# ./src/utils.c:531:22: note: length computed here
#   531 |     strncpy(copy, s, strlen(s)+1);
#       |                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:230:20: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum <anonymous>’ [-Wenum-compare]
#   230 |         if (status != CUDNN_STATUS_SUCCESS)
#       |                    ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:264:18: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum cudaError_enum’ [-Wenum-compare]
#   264 |       if (status != CUDA_SUCCESS)
#       |                  ^~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:395:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#   395 |         printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#       |                                      ~~^
#       |                                        |
#       |                                        unsigned int
#       |                                      %Ilu
#   396 |             size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#       |             ~~~~~~~~~~~~~~~~~~
#       |                  |
#       |                  long unsigned int
# ./src/dark_cuda.c:395:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t’ {aka ‘const long unsigned int’} [-Wformat=]
#   395 |         printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#       |                                                              ~~^
#       |                                                                |
#       |                                                                unsigned int
#       |                                                              %Ilu
#   396 |             size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#       |                                 ~~~~~~~~~~~~~
#       |                                 |
#       |                                 size_t {aka const long unsigned int}
# ./src/dark_cuda.c:395:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#   395 |         printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#       |                                                                                ~~^
#       |                                                                                  |
#       |                                                                                  unsigned int
#       |                                                                                %Ilu
#   396 |             size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#       |                                                ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       |                                                                  |
#       |                                                                  long unsigned int
# ./src/dark_cuda.c:405:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#   405 |                 printf(" Allocated %d pinned block \n", pinned_block_size);
#       |                                    ~^                   ~~~~~~~~~~~~~~~~~
#       |                                     |                   |
#       |                                     int                 long unsigned int
#       |                                    %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:426:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   426 |             printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#       |                                          ~^                      ~~~~~~~~~~~~~~~
#       |                                           |                      |
#       |                                           int                    size_t {aka long unsigned int}
#       |                                          %ld
# ./src/dark_cuda.c:441:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#   441 |             printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#       |                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#       |                                                                |              |
#       |                                                                int            long unsigned int
#       |                                                               %ld
# ./src/dark_cuda.c:447:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#   447 |             printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#       |                                                              ~^         ~~~~~~~~~~~~~~~~~~~~
#       |                                                               |              |
#       |                                                               int            long unsigned int
#       |                                                              %ld
# At top level:
# ./src/dark_cuda.c:287:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#   287 | static cublasHandle_t switchBlasHandle[16];
#       |                       ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:286:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#   286 | static int switchBlasInit[16] = { 0 };
#       |            ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1342:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#  1342 |                         size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#       |                                ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#    79 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#   310 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#   207 |                 int out_index = id;
#       |                     ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   597 |         printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#       |                                                          ~^                      ~
#       |                                                           |                      |
#       |                                                           int                    size_t {aka long unsigned int}
#       |                                                          %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   597 |         printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#       |                                                                  ~^                 ~
#       |                                                                   |                 |
#       |                                                                   int               size_t {aka long unsigned int}
#       |                                                                  %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   597 |         printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#       |                                                                          ~^            ~
#       |                                                                           |            |
#       |                                                                           int          size_t {aka long unsigned int}
#       |                                                                          %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   611 |         printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#       |                                                                   ~^                      ~
#       |                                                                    |                      |
#       |                                                                    int                    size_t {aka long unsigned int}
#       |                                                                   %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   611 |         printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#       |                                                                           ~^                 ~
#       |                                                                            |                 |
#       |                                                                            int               size_t {aka long unsigned int}
#       |                                                                           %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   611 |         printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#       |                                                                                   ~^            ~
#       |                                                                                    |            |
#       |                                                                                    int          size_t {aka long unsigned int}
#       |                                                                                   %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   651 |         fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#       |                                                                              ~^              ~
#       |                                                                               |              |
#       |                                                                               int            size_t {aka long unsigned int}
#       |                                                                              %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   651 |         fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#       |                                                                                      ~^         ~
#       |                                                                                       |         |
#       |                                                                                       int       size_t {aka long unsigned int}
#       |                                                                                      %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:785:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   785 |         fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#       |                                                                              ~^              ~
#       |                                                                               |              |
#       |                                                                               int            size_t {aka long unsigned int}
#       |                                                                              %ld
# ./src/blas.c:785:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   785 |         fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#       |                                                                                      ~^         ~
#       |                                                                                       |         |
#       |                                                                                       int       size_t {aka long unsigned int}
#       |                                                                                      %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:203:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t’ {aka ‘const long unsigned int’} [-Wformat=]
#   203 |     fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#       |                                                                                                   ~~^                                                     ~~~~
#       |                                                                                                     |                                                     |
#       |                                                                                                     int                                                   size_t {aka const long unsigned int}
#       |                                                                                                   %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:244:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#   244 |                     float max_truth = 0;
#       |                           ^~~~~~~~~
# ./src/softmax_layer.c:423:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘const long unsigned int’} [-Wformat=]
#   423 |             printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#       |                                                                      ~^                             ~~~~~~~~~~
#       |                                                                       |                             |
#       |                                                                       int                           size_t {aka const long unsigned int}
#       |                                                                      %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1297:24: warning: unused variable ‘x’ [-Wunused-variable]
#  1297 |                 int k, x, y;
#       |                        ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#  1090 |     float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#       |                                           ^~~~~~~
# ./src/data.c: In function ‘fill_truth_detection’:
# ./src/data.c:440:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   440 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:440:27: note: assuming directive output of 8 bytes
#   440 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:867,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:36:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    36 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    37 |       __bos (__s), __fmt, __va_arg_pack ());
#       |       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:447:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   447 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:447:27: note: assuming directive output of 8 bytes
#   447 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:867,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:36:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    36 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    37 |       __bos (__s), __fmt, __va_arg_pack ());
#       |       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:432:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   432 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                                 ^~                                                          ~~~~~~~~~
# ./src/data.c:432:27: note: assuming directive output of 8 bytes
#   432 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:432:27: note: assuming directive output of 8 bytes
# In file included from /usr/include/stdio.h:867,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:36:10: note: ‘__builtin___sprintf_chk’ output between 61 and 4784 bytes into a destination of size 256
#    36 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    37 |       __bos (__s), __fmt, __va_arg_pack ());
#       |       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:424:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = 0 or y = 0\" >> bad_label.list", labelpath);
#       |                                 ^~                                                          ~~~~~~~~~
# In file included from /usr/include/stdio.h:867,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:36:10: note: ‘__builtin___sprintf_chk’ output between 59 and 4154 bytes into a destination of size 256
#    36 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    37 |       __bos (__s), __fmt, __va_arg_pack ());
#       |       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:410:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   410 |             sprintf(buff, "echo %s \"Wrong annotation: class_id = %d. But class_id should be [from 0 to %d]\" >> bad_label.list", labelpath, id, (classes-1));
#       |                                 ^~                                                                                                ~~~~~~~~~
# In file included from /usr/include/stdio.h:867,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:36:10: note: ‘__builtin___sprintf_chk’ output between 95 and 4210 bytes into a destination of size 256
#    36 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    37 |       __bos (__s), __fmt, __va_arg_pack ());
#       |       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#   435 |         int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#       |             ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:660:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   660 |         if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#       |                                          ^~~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:96,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5202:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5202 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#   346 |     float one = 1;    // alpha[0], beta[0]
#       |           ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#   344 |     float * c = l.output_gpu;
#       |             ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#   343 |     float * b = l.weights_gpu;
#       |             ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#   342 |     float * a = state.input;
#       |             ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#   341 |     int n = l.outputs;
#       |         ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#   340 |     int k = l.inputs;
#       |         ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#   339 |     int m = l.batch;
#       |         ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1777:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#  1777 |         if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#       |                                          ^~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:96,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:5202:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5202 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1909:9: warning: unused variable ‘i’ [-Wunused-variable]
#  1909 |     int i;
#       |         ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:438:40: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   438 |         classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#       |                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:
# /usr/include/stdlib.h:542:14: note: in a call to allocation function ‘calloc’ declared here
#   542 | extern void *calloc (size_t __nmemb, size_t __size)
#       |              ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#   154 |     switch(iou_kind) {
#       |     ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#   898 |                     float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#   897 |                     float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#   248 |     char *base = "results/comp4_det_test_";
#       |           ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:395:72: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#   395 |             (iteration >= (iter_save + 1000) || iteration % 1000 == 0) && net.max_batches < 10000)
#       |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:588:21: warning: statement with no effect [-Wunused-value]
#   588 |                     for (k; buf[k + n] != '\0'; k++)
#       |                     ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:709:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#   709 |         int mkd2 = make_directory(buff2, 0777);
#       |             ^~~~
# ./src/detector.c:707:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#   707 |         int mkd = make_directory(buff, 0777);
#       |             ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1326:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#  1326 |                 double cur_prob = 0;
#       |                        ^~~~~~~~
# ./src/detector.c:1347:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#  1347 |         float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#       |               ^~~~~~~~~~~~
# ./src/detector.c:1346:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#  1346 |         float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#       |               ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1890:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#  1890 |             float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#       |                   ^~~~~~~~
# ...
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/activation_kernels.cu(263): warning #177-D: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning #177-D: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning #177-D: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning #177-D: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning #177-D: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/im2col_kernels.cu(1354): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1354): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1361): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1364): warning #20199-D: unrecognized #pragma in device code
#
# ./src/im2col_kernels.cu(1389): warning #20199-D: unrecognized #pragma in device code
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/blas_kernels.cu(1086): warning #177-D: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning #550-D: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning #177-D: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning #177-D: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning #550-D: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning #177-D: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning #177-D: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning #550-D: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning #177-D: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning #177-D: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning #550-D: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning #177-D: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning #177-D: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning #550-D: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning #177-D: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#  1130 |     int step = 0;
#       |     ^~~~
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/network_kernels.cu(379): warning #177-D: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning #177-D: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning #177-D: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning #177-D: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(379): warning #177-D: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:379:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#   379 |         layer l = net.layers[net.n - 1];
#       |       ^
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -gencode arch=compute_70,code=[sm_70,compute_70] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'sm_35', and 'sm_37' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++
# CPU times: user 732 ms, sys: 137 ms, total: 868 ms
# Wall time: 1min 36s

# %% [markdown]
# # V. 'darknet' Learning

# %% [markdown]
# * 현재 작업 경로

# %%
# !pwd
# Out:
# /content/yolo_custom_modeling/darknet

# %% [markdown]
# > ## 1) 실행권한 설정

# %% [markdown]
# * 실행권한 확인

# %%
# !ls -l darknet
# Out:
# -rwxr-xr-x 1 root root 6747168 Apr  9 01:02 darknet

# %% [markdown]
# * 실행권한 추가

# %%
# !chmod +x darknet

# %% [markdown]
# * Configuration Check

# %%
# !./darknet detector
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.7.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.2.0
# usage: ./darknet detector [train/test/valid/demo/map] [data] [cfg] [weights (optional)]

# %% [markdown]
# > ## 2) 실행환경 설정

# %% [markdown]
# * 현재 작업 경로

# %%
# !pwd
# Out:
# /content/yolo_custom_modeling/darknet

# %% [markdown]
# * 작업 경로 변경

# %%
# %cd ..
# Out:
# /content/yolo_custom_modeling

# %% [markdown]
# * 'backup' 디렉토리 생성

# %%
# !mkdir backup

# %% [markdown]
# * 'backup' 디렉토리 생성 확인

# %%
# !ls -l
# Out:
# total 20
# drwxr-xr-x  2 root root 4096 Apr  9 01:02 backup
# -rw-r--r--  1 root root 2523 Feb  1 15:06 creating-files-data-and-name.py
# -rw-r--r--  1 root root 3024 Feb  2 02:16 creating-train-and-test-txt-files.py
# drwxr-xr-x 16 root root 4096 Apr  9 01:02 darknet
# drwxr-xr-x  5 root root 4096 Apr  9 01:00 dataset

# %% [markdown]
# * labelled_data.data 파일 확인

# %%
# !ls -l dataset/labelled_data.data
# Out:
# -rw-r--r-- 1 root root 107 Apr  9 01:00 dataset/labelled_data.data

# %% [markdown]
# * yolov3-tiny-custom.cfg 파일 확인

# %%
# !ls -l dataset/yolov3-tiny-custom.cfg
# Out:
# -rw-r--r-- 1 root root 1988 Feb  1 15:06 dataset/yolov3-tiny-custom.cfg

# %% [markdown]
# > ## 3) 학습 실행
#
# * 120분
#  - 6000 epochs

# %%
# %%time

# !darknet/darknet detector train dataset/labelled_data.data dataset/yolov3-tiny-custom.cfg -map -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.722404), count: 31, class_loss = 2.353117, iou_loss = 1.364868, total_loss = 3.717984
#  total_bbox = 1601594, rewritten_bbox = 0.598154 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.746061), count: 9, class_loss = 0.917940, iou_loss = 0.588082, total_loss = 1.506021
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.729364), count: 14, class_loss = 1.862087, iou_loss = 0.729192, total_loss = 2.591279
#  total_bbox = 1601617, rewritten_bbox = 0.598145 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.794147), count: 5, class_loss = 0.388151, iou_loss = 0.157867, total_loss = 0.546018
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.716022), count: 7, class_loss = 0.551339, iou_loss = 0.365481, total_loss = 0.916820
#  total_bbox = 1601629, rewritten_bbox = 0.598141 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.776155), count: 9, class_loss = 0.621630, iou_loss = 0.578547, total_loss = 1.200177
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.040145, iou_loss = 0.000000, total_loss = 0.040145
#  total_bbox = 1601638, rewritten_bbox = 0.598138 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5911: 1.422706, 1.125020 avg loss, 0.000100 rate, 1.344404 seconds, 378304 images, 0.062773 hours left
# Loaded: 0.000100 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.786908), count: 8, class_loss = 0.653119, iou_loss = 0.301853, total_loss = 0.954971
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.766325), count: 4, class_loss = 0.314703, iou_loss = 0.550194, total_loss = 0.864898
#  total_bbox = 1601650, rewritten_bbox = 0.598133 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.846633), count: 9, class_loss = 0.675576, iou_loss = 0.261209, total_loss = 0.936785
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.756226), count: 3, class_loss = 0.085156, iou_loss = 0.080540, total_loss = 0.165696
#  total_bbox = 1601662, rewritten_bbox = 0.598129 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.829117), count: 4, class_loss = 0.057792, iou_loss = 0.116019, total_loss = 0.173812
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.662678), count: 5, class_loss = 0.909402, iou_loss = 0.495990, total_loss = 1.405392
#  total_bbox = 1601671, rewritten_bbox = 0.598125 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.899975), count: 2, class_loss = 0.000941, iou_loss = 0.013886, total_loss = 0.014826
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.748245), count: 10, class_loss = 0.444766, iou_loss = 0.483350, total_loss = 0.928115
#  total_bbox = 1601683, rewritten_bbox = 0.598121 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.841900), count: 3, class_loss = 0.029556, iou_loss = 0.060722, total_loss = 0.090277
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.693124), count: 11, class_loss = 1.018215, iou_loss = 0.502020, total_loss = 1.520236
#  total_bbox = 1601697, rewritten_bbox = 0.598116 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.710868), count: 1, class_loss = 0.116763, iou_loss = 0.072903, total_loss = 0.189666
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.763130), count: 26, class_loss = 2.581244, iou_loss = 1.148358, total_loss = 3.729603
#  total_bbox = 1601724, rewritten_bbox = 0.598106 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.840672), count: 3, class_loss = 0.247878, iou_loss = 0.078605, total_loss = 0.326483
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.747811), count: 12, class_loss = 0.431213, iou_loss = 0.423370, total_loss = 0.854584
#  total_bbox = 1601739, rewritten_bbox = 0.598100 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.874034), count: 7, class_loss = 0.034411, iou_loss = 0.114542, total_loss = 0.148953
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.796651), count: 3, class_loss = 0.028165, iou_loss = 0.125062, total_loss = 0.153227
#  total_bbox = 1601749, rewritten_bbox = 0.598096 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.823345), count: 4, class_loss = 0.447811, iou_loss = 0.084421, total_loss = 0.532232
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.002642, iou_loss = 0.000000, total_loss = 0.002642
#  total_bbox = 1601753, rewritten_bbox = 0.598095 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.774094), count: 8, class_loss = 0.738824, iou_loss = 0.323524, total_loss = 1.062348
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.807494), count: 6, class_loss = 0.308205, iou_loss = 0.329357, total_loss = 0.637562
#  total_bbox = 1601767, rewritten_bbox = 0.598089 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.858207), count: 3, class_loss = 0.213181, iou_loss = 0.049245, total_loss = 0.262427
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.801442), count: 12, class_loss = 1.388317, iou_loss = 0.358254, total_loss = 1.746570
#  total_bbox = 1601782, rewritten_bbox = 0.598084 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.723865), count: 3, class_loss = 0.177803, iou_loss = 0.142209, total_loss = 0.320012
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.757000), count: 6, class_loss = 0.711938, iou_loss = 0.276181, total_loss = 0.988119
#  total_bbox = 1601791, rewritten_bbox = 0.598081 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.822508), count: 5, class_loss = 0.006509, iou_loss = 0.087597, total_loss = 0.094106
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.727952), count: 37, class_loss = 2.977839, iou_loss = 1.239575, total_loss = 4.217414
#  total_bbox = 1601833, rewritten_bbox = 0.598065 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.766734), count: 5, class_loss = 0.466154, iou_loss = 0.190946, total_loss = 0.657099
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.751731), count: 14, class_loss = 1.274270, iou_loss = 0.753111, total_loss = 2.027381
#  total_bbox = 1601852, rewritten_bbox = 0.598058 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.824046), count: 3, class_loss = 0.117644, iou_loss = 0.127918, total_loss = 0.245563
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.724444), count: 8, class_loss = 0.725275, iou_loss = 0.441207, total_loss = 1.166481
#  total_bbox = 1601863, rewritten_bbox = 0.598054 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.751603), count: 11, class_loss = 2.148515, iou_loss = 0.728077, total_loss = 2.876593
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.609358), count: 5, class_loss = 0.775446, iou_loss = 1.429582, total_loss = 2.205028
#  total_bbox = 1601879, rewritten_bbox = 0.598048 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5912: 0.984347, 1.110953 avg loss, 0.000100 rate, 1.284245 seconds, 378368 images, 0.062498 hours left
# Loaded: 0.000071 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.820937), count: 9, class_loss = 0.217317, iou_loss = 0.218099, total_loss = 0.435415
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.784033), count: 4, class_loss = 0.418032, iou_loss = 0.208245, total_loss = 0.626277
#  total_bbox = 1601892, rewritten_bbox = 0.598043 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.788666), count: 3, class_loss = 0.404300, iou_loss = 0.188128, total_loss = 0.592428
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.793004), count: 5, class_loss = 0.088872, iou_loss = 0.117438, total_loss = 0.206309
#  total_bbox = 1601900, rewritten_bbox = 0.598040 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.858607), count: 5, class_loss = 0.001871, iou_loss = 0.094811, total_loss = 0.096682
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.717682), count: 11, class_loss = 1.030860, iou_loss = 0.548301, total_loss = 1.579160
#  total_bbox = 1601916, rewritten_bbox = 0.598034 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.739033), count: 2, class_loss = 0.356999, iou_loss = 0.279585, total_loss = 0.636584
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.706299), count: 3, class_loss = 0.062012, iou_loss = 0.369518, total_loss = 0.431530
#  total_bbox = 1601921, rewritten_bbox = 0.598032 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.712668), count: 3, class_loss = 0.529269, iou_loss = 0.177703, total_loss = 0.706972
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.758754), count: 10, class_loss = 0.976198, iou_loss = 0.483702, total_loss = 1.459901
#  total_bbox = 1601934, rewritten_bbox = 0.598027 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.792786), count: 5, class_loss = 0.198779, iou_loss = 0.137939, total_loss = 0.336718
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.751185), count: 19, class_loss = 1.970819, iou_loss = 1.142020, total_loss = 3.112840
#  total_bbox = 1601958, rewritten_bbox = 0.598018 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.801182), count: 4, class_loss = 0.738275, iou_loss = 0.175817, total_loss = 0.914092
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.737061), count: 4, class_loss = 0.385392, iou_loss = 0.280242, total_loss = 0.665634
#  total_bbox = 1601966, rewritten_bbox = 0.598015 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.836900), count: 5, class_loss = 0.153649, iou_loss = 0.093090, total_loss = 0.246739
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.686717), count: 1, class_loss = 0.139655, iou_loss = 0.104156, total_loss = 0.243811
#  total_bbox = 1601972, rewritten_bbox = 0.598013 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.849834), count: 6, class_loss = 0.499264, iou_loss = 0.114751, total_loss = 0.614015
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.718536), count: 12, class_loss = 0.851509, iou_loss = 0.750875, total_loss = 1.602384
#  total_bbox = 1601990, rewritten_bbox = 0.598006 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.868935), count: 4, class_loss = 0.023048, iou_loss = 0.047962, total_loss = 0.071010
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.652355), count: 24, class_loss = 1.460395, iou_loss = 1.137296, total_loss = 2.597690
#  total_bbox = 1602018, rewritten_bbox = 0.597996 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.824442), count: 2, class_loss = 0.000099, iou_loss = 0.059190, total_loss = 0.059289
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.669359), count: 4, class_loss = 0.178296, iou_loss = 0.326716, total_loss = 0.505013
#  total_bbox = 1602024, rewritten_bbox = 0.597994 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.832474), count: 11, class_loss = 0.330023, iou_loss = 0.220049, total_loss = 0.550072
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.613382), count: 3, class_loss = 0.796935, iou_loss = 0.340761, total_loss = 1.137696
#  total_bbox = 1602038, rewritten_bbox = 0.597988 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.803905), count: 5, class_loss = 0.035311, iou_loss = 0.123539, total_loss = 0.158850
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000100, iou_loss = 0.000000, total_loss = 0.000100
#  total_bbox = 1602043, rewritten_bbox = 0.597986 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.893852), count: 7, class_loss = 0.252619, iou_loss = 0.078584, total_loss = 0.331203
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.724914), count: 26, class_loss = 1.754865, iou_loss = 1.575631, total_loss = 3.330496
#  total_bbox = 1602076, rewritten_bbox = 0.597974 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.779373), count: 3, class_loss = 0.215503, iou_loss = 0.113925, total_loss = 0.329429
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.871579), count: 10, class_loss = 0.513669, iou_loss = 0.166996, total_loss = 0.680664
#  total_bbox = 1602089, rewritten_bbox = 0.597969 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.836223), count: 3, class_loss = 0.229889, iou_loss = 0.066135, total_loss = 0.296024
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.592799), count: 23, class_loss = 1.545492, iou_loss = 1.385294, total_loss = 2.930785
#  total_bbox = 1602115, rewritten_bbox = 0.597960 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5913: 0.858932, 1.085751 avg loss, 0.000100 rate, 1.390702 seconds, 378432 images, 0.062187 hours left
# Loaded: 0.000068 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.825947), count: 6, class_loss = 0.324163, iou_loss = 0.201912, total_loss = 0.526075
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.870597), count: 4, class_loss = 0.196614, iou_loss = 0.038358, total_loss = 0.234973
#  total_bbox = 1602125, rewritten_bbox = 0.597956 %
# libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.835551), count: 8, class_loss = 0.374705, iou_loss = 0.226198, total_loss = 0.600902
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.621075), count: 1, class_loss = 0.238849, iou_loss = 0.110502, total_loss = 0.349351
#  total_bbox = 1602134, rewritten_bbox = 0.597952 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.882511), count: 4, class_loss = 0.052816, iou_loss = 0.054159, total_loss = 0.106975
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.774142), count: 37, class_loss = 3.085020, iou_loss = 1.448718, total_loss = 4.533737
#  total_bbox = 1602175, rewritten_bbox = 0.597937 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.825629), count: 4, class_loss = 0.212182, iou_loss = 0.105675, total_loss = 0.317857
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.882476), count: 2, class_loss = 0.005427, iou_loss = 0.009866, total_loss = 0.015292
#  total_bbox = 1602181, rewritten_bbox = 0.597935 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.829306), count: 10, class_loss = 0.787641, iou_loss = 0.257332, total_loss = 1.044973
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.799437), count: 16, class_loss = 1.270823, iou_loss = 0.511703, total_loss = 1.782526
#  total_bbox = 1602207, rewritten_bbox = 0.597925 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.898372), count: 2, class_loss = 0.054000, iou_loss = 0.017351, total_loss = 0.071351
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.752100), count: 7, class_loss = 0.299713, iou_loss = 0.310864, total_loss = 0.610577
#  total_bbox = 1602216, rewritten_bbox = 0.597922 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.849293), count: 9, class_loss = 0.451462, iou_loss = 0.159979, total_loss = 0.611441
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.771119), count: 3, class_loss = 0.656872, iou_loss = 0.127769, total_loss = 0.784641
#  total_bbox = 1602228, rewritten_bbox = 0.597917 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.874169), count: 3, class_loss = 0.245096, iou_loss = 0.078872, total_loss = 0.323968
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.759732), count: 2, class_loss = 0.038090, iou_loss = 0.069356, total_loss = 0.107445
#  total_bbox = 1602233, rewritten_bbox = 0.597916 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802570), count: 10, class_loss = 0.937164, iou_loss = 0.336646, total_loss = 1.273810
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.724190), count: 10, class_loss = 0.867786, iou_loss = 0.581225, total_loss = 1.449012
#  total_bbox = 1602253, rewritten_bbox = 0.597908 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827699), count: 3, class_loss = 0.287246, iou_loss = 0.113509, total_loss = 0.400755
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.788810), count: 11, class_loss = 1.094197, iou_loss = 0.366473, total_loss = 1.460669
#  total_bbox = 1602267, rewritten_bbox = 0.597903 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.779491), count: 5, class_loss = 0.366985, iou_loss = 0.266878, total_loss = 0.633863
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.803995), count: 7, class_loss = 0.350641, iou_loss = 0.142886, total_loss = 0.493527
#  total_bbox = 1602279, rewritten_bbox = 0.597898 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.787878), count: 4, class_loss = 0.886876, iou_loss = 0.220084, total_loss = 1.106960
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.752539), count: 7, class_loss = 0.609186, iou_loss = 0.238356, total_loss = 0.847541
#  total_bbox = 1602290, rewritten_bbox = 0.597894 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.809567), count: 2, class_loss = 0.000998, iou_loss = 0.027946, total_loss = 0.028944
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.724819), count: 6, class_loss = 0.523743, iou_loss = 0.416927, total_loss = 0.940670
#  total_bbox = 1602298, rewritten_bbox = 0.597891 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.876637), count: 2, class_loss = 0.000896, iou_loss = 0.064181, total_loss = 0.065077
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.725393), count: 16, class_loss = 1.273187, iou_loss = 0.765735, total_loss = 2.038922
#  total_bbox = 1602316, rewritten_bbox = 0.597885 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.826673), count: 7, class_loss = 0.409462, iou_loss = 0.146130, total_loss = 0.555593
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.800148), count: 6, class_loss = 0.852350, iou_loss = 0.164807, total_loss = 1.017157
#  total_bbox = 1602329, rewritten_bbox = 0.597880 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802731), count: 4, class_loss = 0.281077, iou_loss = 0.176819, total_loss = 0.457895
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.792095), count: 19, class_loss = 1.578558, iou_loss = 0.793407, total_loss = 2.371965
#  total_bbox = 1602352, rewritten_bbox = 0.597871 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5914: 0.848889, 1.062064 avg loss, 0.000100 rate, 1.678706 seconds, 378496 images, 0.061902 hours left
# Loaded: 0.000067 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.786777), count: 7, class_loss = 0.773743, iou_loss = 0.257418, total_loss = 1.031161
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.801381), count: 6, class_loss = 0.483440, iou_loss = 0.220347, total_loss = 0.703787
#  total_bbox = 1602365, rewritten_bbox = 0.597866 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.872830), count: 2, class_loss = 0.022015, iou_loss = 0.020592, total_loss = 0.042607
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.758342), count: 21, class_loss = 2.197898, iou_loss = 0.812940, total_loss = 3.010838
#  total_bbox = 1602388, rewritten_bbox = 0.597858 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.804312), count: 4, class_loss = 0.037569, iou_loss = 0.131971, total_loss = 0.169540
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761549), count: 16, class_loss = 1.274346, iou_loss = 0.621094, total_loss = 1.895441
#  total_bbox = 1602408, rewritten_bbox = 0.597850 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.676621), count: 5, class_loss = 0.809243, iou_loss = 0.425888, total_loss = 1.235130
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.753422), count: 11, class_loss = 0.737422, iou_loss = 0.367625, total_loss = 1.105047
#  total_bbox = 1602424, rewritten_bbox = 0.597844 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.779167), count: 3, class_loss = 0.477330, iou_loss = 0.227269, total_loss = 0.704600
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.737085), count: 13, class_loss = 0.875180, iou_loss = 0.693351, total_loss = 1.568531
#  total_bbox = 1602440, rewritten_bbox = 0.597838 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.855607), count: 11, class_loss = 0.175462, iou_loss = 0.200229, total_loss = 0.375692
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.801298), count: 7, class_loss = 0.252509, iou_loss = 0.369665, total_loss = 0.622174
#  total_bbox = 1602458, rewritten_bbox = 0.597832 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.822271), count: 3, class_loss = 0.162395, iou_loss = 0.075106, total_loss = 0.237502
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.812319), count: 6, class_loss = 0.337367, iou_loss = 0.126567, total_loss = 0.463934
#  total_bbox = 1602467, rewritten_bbox = 0.597828 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.782615), count: 5, class_loss = 0.450706, iou_loss = 0.240609, total_loss = 0.691314
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000176, iou_loss = 0.000000, total_loss = 0.000176
#  total_bbox = 1602472, rewritten_bbox = 0.597826 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.802657), count: 4, class_loss = 0.029330, iou_loss = 0.214596, total_loss = 0.243926
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.796802), count: 4, class_loss = 0.366230, iou_loss = 0.135445, total_loss = 0.501675
#  total_bbox = 1602480, rewritten_bbox = 0.597823 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.765371), count: 8, class_loss = 0.348963, iou_loss = 0.478332, total_loss = 0.827295
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.836011), count: 1, class_loss = 0.149069, iou_loss = 0.015939, total_loss = 0.165008
#  total_bbox = 1602489, rewritten_bbox = 0.597820 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.825061), count: 4, class_loss = 0.294450, iou_loss = 0.191170, total_loss = 0.485620
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.630539), count: 2, class_loss = 0.254851, iou_loss = 0.163501, total_loss = 0.418352
#  total_bbox = 1602495, rewritten_bbox = 0.597818 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.837756), count: 4, class_loss = 0.064623, iou_loss = 0.116170, total_loss = 0.180794
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.781284), count: 8, class_loss = 0.516955, iou_loss = 0.392132, total_loss = 0.909087
#  total_bbox = 1602507, rewritten_bbox = 0.597813 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.673540), count: 5, class_loss = 0.929551, iou_loss = 0.615849, total_loss = 1.545400
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.681964), count: 14, class_loss = 1.662483, iou_loss = 0.768833, total_loss = 2.431316
#  total_bbox = 1602526, rewritten_bbox = 0.597806 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.000000), count: 1, class_loss = 0.004874, iou_loss = 0.000000, total_loss = 0.004874
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.742034), count: 36, class_loss = 2.512981, iou_loss = 1.713641, total_loss = 4.226622
#  total_bbox = 1602562, rewritten_bbox = 0.597793 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.763662), count: 2, class_loss = 0.010945, iou_loss = 0.068652, total_loss = 0.079596
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.847030), count: 4, class_loss = 0.462348, iou_loss = 0.075677, total_loss = 0.538025
#  total_bbox = 1602568, rewritten_bbox = 0.597791 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.863835), count: 4, class_loss = 0.007982, iou_loss = 0.038770, total_loss = 0.046752
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.808894), count: 2, class_loss = 0.027311, iou_loss = 0.054216, total_loss = 0.081527
#  total_bbox = 1602574, rewritten_bbox = 0.597788 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5915: 0.829479, 1.038806 avg loss, 0.000100 rate, 1.289469 seconds, 378560 images, 0.061684 hours left
# Loaded: 0.000083 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.825660), count: 3, class_loss = 0.182444, iou_loss = 0.071038, total_loss = 0.253482
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.787821), count: 5, class_loss = 0.410184, iou_loss = 0.130660, total_loss = 0.540844
#  total_bbox = 1602582, rewritten_bbox = 0.597785 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.814333), count: 5, class_loss = 0.479734, iou_loss = 0.135640, total_loss = 0.615375
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.833548), count: 3, class_loss = 0.079429, iou_loss = 0.088207, total_loss = 0.167636
#  total_bbox = 1602590, rewritten_bbox = 0.597782 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.845366), count: 6, class_loss = 0.159422, iou_loss = 0.126195, total_loss = 0.285617
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.776328), count: 5, class_loss = 0.274586, iou_loss = 0.161215, total_loss = 0.435801
#  total_bbox = 1602601, rewritten_bbox = 0.597778 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827826), count: 5, class_loss = 0.899747, iou_loss = 0.140194, total_loss = 1.039941
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.069272, iou_loss = 0.000000, total_loss = 0.069272
#  total_bbox = 1602606, rewritten_bbox = 0.597776 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.897799), count: 1, class_loss = 0.001040, iou_loss = 0.006326, total_loss = 0.007367
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.748120), count: 18, class_loss = 1.451329, iou_loss = 0.636750, total_loss = 2.088079
#  total_bbox = 1602625, rewritten_bbox = 0.597769 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.763164), count: 5, class_loss = 0.563207, iou_loss = 0.185320, total_loss = 0.748526
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.853010), count: 1, class_loss = 0.074480, iou_loss = 0.015365, total_loss = 0.089846
#  total_bbox = 1602631, rewritten_bbox = 0.597767 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.782847), count: 3, class_loss = 0.015548, iou_loss = 0.128275, total_loss = 0.143823
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.709609), count: 15, class_loss = 0.839606, iou_loss = 0.547437, total_loss = 1.387043
#  total_bbox = 1602649, rewritten_bbox = 0.597760 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.771139), count: 5, class_loss = 0.335522, iou_loss = 0.207682, total_loss = 0.543204
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.855060), count: 1, class_loss = 0.001755, iou_loss = 0.015776, total_loss = 0.017530
#  total_bbox = 1602655, rewritten_bbox = 0.597758 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.786636), count: 3, class_loss = 0.083911, iou_loss = 0.120755, total_loss = 0.204665
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.683124), count: 8, class_loss = 1.187684, iou_loss = 0.430674, total_loss = 1.618358
#  total_bbox = 1602666, rewritten_bbox = 0.597754 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.781759), count: 4, class_loss = 0.360612, iou_loss = 0.156260, total_loss = 0.516872
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.703576), count: 27, class_loss = 3.538695, iou_loss = 1.592336, total_loss = 5.131031
#  total_bbox = 1602697, rewritten_bbox = 0.597742 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.801341), count: 4, class_loss = 0.311222, iou_loss = 0.121108, total_loss = 0.432330
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.564418), count: 30, class_loss = 2.017830, iou_loss = 1.307666, total_loss = 3.325495
#  total_bbox = 1602731, rewritten_bbox = 0.597855 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.751445), count: 3, class_loss = 0.178101, iou_loss = 0.139175, total_loss = 0.317275
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.763185), count: 7, class_loss = 0.380109, iou_loss = 0.383413, total_loss = 0.763522
#  total_bbox = 1602741, rewritten_bbox = 0.597851 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.860375), count: 4, class_loss = 0.015500, iou_loss = 0.041464, total_loss = 0.056963
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.668014), count: 7, class_loss = 0.499794, iou_loss = 0.858412, total_loss = 1.358206
#  total_bbox = 1602752, rewritten_bbox = 0.597847 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.844308), count: 6, class_loss = 0.365167, iou_loss = 0.111191, total_loss = 0.476357
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.755817), count: 13, class_loss = 0.863918, iou_loss = 0.603904, total_loss = 1.467821
#  total_bbox = 1602771, rewritten_bbox = 0.597840 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.822264), count: 15, class_loss = 0.779319, iou_loss = 0.308782, total_loss = 1.088102
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.722262), count: 10, class_loss = 1.361932, iou_loss = 0.602742, total_loss = 1.964674
#  total_bbox = 1602796, rewritten_bbox = 0.597830 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.858863), count: 5, class_loss = 0.197037, iou_loss = 0.059448, total_loss = 0.256485
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.724664), count: 17, class_loss = 2.285930, iou_loss = 0.961210, total_loss = 3.247141
#  total_bbox = 1602818, rewritten_bbox = 0.597822 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5916: 0.958084, 1.030734 avg loss, 0.000100 rate, 1.291559 seconds, 378624 images, 0.061371 hours left
# Loaded: 0.000059 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.831472), count: 1, class_loss = 0.001379, iou_loss = 0.081842, total_loss = 0.083220
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.812164), count: 17, class_loss = 0.569289, iou_loss = 0.427814, total_loss = 0.997103
#  total_bbox = 1602836, rewritten_bbox = 0.597815 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.901587), count: 1, class_loss = 0.002027, iou_loss = 0.005711, total_loss = 0.007738
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.730763), count: 30, class_loss = 2.098349, iou_loss = 1.580514, total_loss = 3.678863
#  total_bbox = 1602867, rewritten_bbox = 0.597804 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.842273), count: 5, class_loss = 0.115015, iou_loss = 0.163410, total_loss = 0.278425
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.662560), count: 6, class_loss = 0.553032, iou_loss = 0.317108, total_loss = 0.870140
#  total_bbox = 1602878, rewritten_bbox = 0.597800 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.831569), count: 4, class_loss = 0.197949, iou_loss = 0.161108, total_loss = 0.359057
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.484629), count: 16, class_loss = 2.296699, iou_loss = 1.391063, total_loss = 3.687761
#  total_bbox = 1602898, rewritten_bbox = 0.597792 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.771159), count: 3, class_loss = 0.312336, iou_loss = 0.232989, total_loss = 0.545325
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.750024), count: 17, class_loss = 1.480303, iou_loss = 0.968859, total_loss = 2.449162
#  total_bbox = 1602918, rewritten_bbox = 0.597785 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.762737), count: 3, class_loss = 0.185938, iou_loss = 0.166536, total_loss = 0.352474
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.751200), count: 3, class_loss = 0.056278, iou_loss = 0.147707, total_loss = 0.203986
#  total_bbox = 1602924, rewritten_bbox = 0.597783 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.792428), count: 8, class_loss = 0.430185, iou_loss = 0.232323, total_loss = 0.662509
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.733912), count: 12, class_loss = 1.070273, iou_loss = 0.632629, total_loss = 1.702901
#  total_bbox = 1602944, rewritten_bbox = 0.597775 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.732688), count: 4, class_loss = 0.472978, iou_loss = 0.240262, total_loss = 0.713240
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.621269), count: 3, class_loss = 0.685336, iou_loss = 0.124179, total_loss = 0.809515
#  total_bbox = 1602951, rewritten_bbox = 0.597772 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.771367), count: 6, class_loss = 0.621514, iou_loss = 0.279193, total_loss = 0.900707
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.713089), count: 64, class_loss = 4.837370, iou_loss = 3.191195, total_loss = 8.028565
#  total_bbox = 1603021, rewritten_bbox = 0.597746 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.849892), count: 3, class_loss = 0.210512, iou_loss = 0.061288, total_loss = 0.271799
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.753328), count: 5, class_loss = 0.349038, iou_loss = 0.262308, total_loss = 0.611346
#  total_bbox = 1603029, rewritten_bbox = 0.597743 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.783763), count: 8, class_loss = 1.163282, iou_loss = 0.306682, total_loss = 1.469964
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.660978), count: 71, class_loss = 8.237056, iou_loss = 4.943560, total_loss = 13.180615
#  total_bbox = 1603108, rewritten_bbox = 0.597714 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.757972), count: 5, class_loss = 0.651927, iou_loss = 0.172163, total_loss = 0.824090
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.740861), count: 12, class_loss = 1.244596, iou_loss = 1.002378, total_loss = 2.246974
#  total_bbox = 1603125, rewritten_bbox = 0.597708 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.821941), count: 3, class_loss = 0.187999, iou_loss = 0.060004, total_loss = 0.248003
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.704796), count: 16, class_loss = 1.109404, iou_loss = 0.555360, total_loss = 1.664764
#  total_bbox = 1603144, rewritten_bbox = 0.597701 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827508), count: 7, class_loss = 0.015809, iou_loss = 0.177753, total_loss = 0.193562
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.002279, iou_loss = 0.000000, total_loss = 0.002279
#  total_bbox = 1603151, rewritten_bbox = 0.597698 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.843794), count: 2, class_loss = 0.050771, iou_loss = 0.035201, total_loss = 0.085971
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.768478), count: 21, class_loss = 0.908643, iou_loss = 0.649267, total_loss = 1.557909
#  total_bbox = 1603174, rewritten_bbox = 0.597689 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.850742), count: 3, class_loss = 0.238372, iou_loss = 0.075416, total_loss = 0.313788
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.709542), count: 6, class_loss = 0.257451, iou_loss = 0.316184, total_loss = 0.573635
#  total_bbox = 1603183, rewritten_bbox = 0.597686 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5917: 1.549231, 1.082583 avg loss, 0.000100 rate, 1.387345 seconds, 378688 images, 0.061059 hours left
# Loaded: 0.000090 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.825387), count: 6, class_loss = 0.188088, iou_loss = 0.138712, total_loss = 0.326800
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.755160), count: 8, class_loss = 0.825018, iou_loss = 0.338048, total_loss = 1.163066
#  total_bbox = 1603197, rewritten_bbox = 0.597681 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.857299), count: 3, class_loss = 0.165268, iou_loss = 0.027549, total_loss = 0.192817
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.768932), count: 4, class_loss = 0.256151, iou_loss = 0.108185, total_loss = 0.364336
#  total_bbox = 1603204, rewritten_bbox = 0.597678 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.865644), count: 3, class_loss = 0.028308, iou_loss = 0.082250, total_loss = 0.110558
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.731341), count: 17, class_loss = 1.916906, iou_loss = 0.677821, total_loss = 2.594726
#  total_bbox = 1603224, rewritten_bbox = 0.597671 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.850248), count: 4, class_loss = 0.411191, iou_loss = 0.073380, total_loss = 0.484571
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.808828), count: 1, class_loss = 0.048477, iou_loss = 0.038856, total_loss = 0.087333
#  total_bbox = 1603229, rewritten_bbox = 0.597669 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.857480), count: 4, class_loss = 0.049100, iou_loss = 0.069034, total_loss = 0.118134
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.663267), count: 55, class_loss = 7.265964, iou_loss = 3.958492, total_loss = 11.224456
#  total_bbox = 1603288, rewritten_bbox = 0.597647 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.838679), count: 3, class_loss = 0.000201, iou_loss = 0.036317, total_loss = 0.036518
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.649570), count: 13, class_loss = 1.371042, iou_loss = 0.633658, total_loss = 2.004700
#  total_bbox = 1603304, rewritten_bbox = 0.597641 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.824341), count: 2, class_loss = 0.063742, iou_loss = 0.051549, total_loss = 0.115292
# libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.826985), count: 9, class_loss = 0.623102, iou_loss = 0.222362, total_loss = 0.845464
#  total_bbox = 1603315, rewritten_bbox = 0.597637 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.778664), count: 3, class_loss = 0.299348, iou_loss = 0.102885, total_loss = 0.402233
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.762698), count: 14, class_loss = 0.785012, iou_loss = 0.236565, total_loss = 1.021577
#  total_bbox = 1603332, rewritten_bbox = 0.597630 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.834152), count: 4, class_loss = 0.084177, iou_loss = 0.119336, total_loss = 0.203513
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.777462), count: 23, class_loss = 1.683049, iou_loss = 0.675335, total_loss = 2.358384
#  total_bbox = 1603359, rewritten_bbox = 0.597620 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.801837), count: 2, class_loss = 0.066287, iou_loss = 0.053173, total_loss = 0.119459
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.759789), count: 14, class_loss = 0.651411, iou_loss = 0.374582, total_loss = 1.025993
#  total_bbox = 1603375, rewritten_bbox = 0.597614 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.854159), count: 5, class_loss = 0.085673, iou_loss = 0.102940, total_loss = 0.188614
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.761365), count: 13, class_loss = 1.048451, iou_loss = 0.494829, total_loss = 1.543279
#  total_bbox = 1603393, rewritten_bbox = 0.597608 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.906192), count: 2, class_loss = 0.149010, iou_loss = 0.018409, total_loss = 0.167419
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.633011), count: 17, class_loss = 0.743460, iou_loss = 0.731921, total_loss = 1.475382
#  total_bbox = 1603412, rewritten_bbox = 0.597601 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.845147), count: 4, class_loss = 0.209511, iou_loss = 0.062213, total_loss = 0.271723
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.844752), count: 9, class_loss = 0.656479, iou_loss = 0.116055, total_loss = 0.772534
#  total_bbox = 1603425, rewritten_bbox = 0.597596 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.850309), count: 9, class_loss = 0.393717, iou_loss = 0.131222, total_loss = 0.524940
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.762155), count: 9, class_loss = 0.545245, iou_loss = 0.622843, total_loss = 1.168088
#  total_bbox = 1603443, rewritten_bbox = 0.597589 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.814512), count: 5, class_loss = 0.032746, iou_loss = 0.150578, total_loss = 0.183325
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.715969), count: 8, class_loss = 0.902919, iou_loss = 0.526508, total_loss = 1.429427
#  total_bbox = 1603456, rewritten_bbox = 0.597584 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.781012), count: 4, class_loss = 0.339198, iou_loss = 0.139158, total_loss = 0.478355
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.670696), count: 85, class_loss = 8.815113, iou_loss = 6.117346, total_loss = 14.932459
#  total_bbox = 1603545, rewritten_bbox = 0.597551 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5918: 1.497984, 1.124123 avg loss, 0.000100 rate, 1.364368 seconds, 378752 images, 0.060768 hours left
# Loaded: 0.000105 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.823520), count: 5, class_loss = 0.887674, iou_loss = 0.124065, total_loss = 1.011739
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.656969), count: 9, class_loss = 0.930577, iou_loss = 0.578741, total_loss = 1.509318
#  total_bbox = 1603559, rewritten_bbox = 0.597546 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.788663), count: 7, class_loss = 0.337832, iou_loss = 0.301623, total_loss = 0.639456
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.760371), count: 3, class_loss = 0.435693, iou_loss = 0.122070, total_loss = 0.557763
#  total_bbox = 1603569, rewritten_bbox = 0.597542 %
# ...
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.757328), count: 4, class_loss = 0.257986, iou_loss = 0.074091, total_loss = 0.332077
#  total_bbox = 1625977, rewritten_bbox = 0.591214 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.716685), count: 5, class_loss = 0.565037, iou_loss = 0.363748, total_loss = 0.928785
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.764140), count: 12, class_loss = 1.321398, iou_loss = 0.781734, total_loss = 2.103132
#  total_bbox = 1625994, rewritten_bbox = 0.591208 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.765417), count: 4, class_loss = 0.272319, iou_loss = 0.148716, total_loss = 0.421036
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.828293), count: 7, class_loss = 0.249833, iou_loss = 0.195663, total_loss = 0.445496
#  total_bbox = 1626005, rewritten_bbox = 0.591204 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5998: 0.909283, 1.038399 avg loss, 0.000100 rate, 1.271810 seconds, 383872 images, 0.035387 hours left
# Loaded: 0.000073 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.733574), count: 9, class_loss = 1.538804, iou_loss = 0.569700, total_loss = 2.108505
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.680697), count: 18, class_loss = 2.535939, iou_loss = 1.176852, total_loss = 3.712792
#  total_bbox = 1626032, rewritten_bbox = 0.591194 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.867322), count: 3, class_loss = 0.092802, iou_loss = 0.061821, total_loss = 0.154623
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.745000), count: 2, class_loss = 0.103403, iou_loss = 0.046181, total_loss = 0.149584
#  total_bbox = 1626037, rewritten_bbox = 0.591192 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.825239), count: 9, class_loss = 0.552499, iou_loss = 0.310811, total_loss = 0.863310
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.681411), count: 1, class_loss = 0.324065, iou_loss = 0.050381, total_loss = 0.374446
#  total_bbox = 1626047, rewritten_bbox = 0.591188 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.888497), count: 4, class_loss = 0.042661, iou_loss = 0.040645, total_loss = 0.083306
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.711382), count: 5, class_loss = 1.174075, iou_loss = 0.307955, total_loss = 1.482030
#  total_bbox = 1626056, rewritten_bbox = 0.591185 %
# libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.868658), count: 2, class_loss = 0.000112, iou_loss = 0.017314, total_loss = 0.017426
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.682032), count: 9, class_loss = 0.797657, iou_loss = 0.346799, total_loss = 1.144456
#  total_bbox = 1626067, rewritten_bbox = 0.591181 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827083), count: 5, class_loss = 0.045806, iou_loss = 0.082435, total_loss = 0.128240
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.897761), count: 2, class_loss = 0.040665, iou_loss = 0.018265, total_loss = 0.058930
#  total_bbox = 1626074, rewritten_bbox = 0.591179 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.801261), count: 7, class_loss = 0.235558, iou_loss = 0.236721, total_loss = 0.472279
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.768654), count: 9, class_loss = 0.416448, iou_loss = 0.179202, total_loss = 0.595650
#  total_bbox = 1626090, rewritten_bbox = 0.591173 %
# libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.891439), count: 3, class_loss = 0.047146, iou_loss = 0.032280, total_loss = 0.079426
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.700460), count: 68, class_loss = 6.902069, iou_loss = 2.768663, total_loss = 9.670732
#  total_bbox = 1626161, rewritten_bbox = 0.591147 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.823492), count: 3, class_loss = 0.003367, iou_loss = 0.059789, total_loss = 0.063156
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.814296), count: 5, class_loss = 0.002956, iou_loss = 0.072055, total_loss = 0.075012
#  total_bbox = 1626169, rewritten_bbox = 0.591144 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.851118), count: 5, class_loss = 0.004063, iou_loss = 0.080012, total_loss = 0.084075
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.858900), count: 7, class_loss = 0.046695, iou_loss = 0.110445, total_loss = 0.157140
#  total_bbox = 1626181, rewritten_bbox = 0.591140 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.786051), count: 5, class_loss = 0.078415, iou_loss = 0.196139, total_loss = 0.274554
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.711489), count: 9, class_loss = 0.923783, iou_loss = 0.443910, total_loss = 1.367693
#  total_bbox = 1626195, rewritten_bbox = 0.591135 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.846359), count: 8, class_loss = 0.416982, iou_loss = 0.266062, total_loss = 0.683043
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.609930), count: 73, class_loss = 10.206704, iou_loss = 6.213771, total_loss = 16.420475
#  total_bbox = 1626276, rewritten_bbox = 0.591105 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.736655), count: 5, class_loss = 0.309930, iou_loss = 0.321605, total_loss = 0.631535
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000228, iou_loss = 0.000000, total_loss = 0.000228
#  total_bbox = 1626281, rewritten_bbox = 0.591103 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.781821), count: 4, class_loss = 0.209663, iou_loss = 0.113649, total_loss = 0.323312
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.696068), count: 15, class_loss = 1.661920, iou_loss = 0.755244, total_loss = 2.417164
#  total_bbox = 1626300, rewritten_bbox = 0.591096 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.854768), count: 3, class_loss = 0.004310, iou_loss = 0.033303, total_loss = 0.037613
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.805123), count: 8, class_loss = 0.482046, iou_loss = 0.218043, total_loss = 0.700088
#  total_bbox = 1626311, rewritten_bbox = 0.591092 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.904185), count: 7, class_loss = 0.121312, iou_loss = 0.061407, total_loss = 0.182719
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.853626), count: 3, class_loss = 0.052512, iou_loss = 0.045534, total_loss = 0.098045
#  total_bbox = 1626321, rewritten_bbox = 0.591089 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  5999: 1.394112, 1.073970 avg loss, 0.000100 rate, 1.334849 seconds, 383936 images, 0.035040 hours left
# Loaded: 0.000088 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.763919), count: 8, class_loss = 0.855347, iou_loss = 0.309001, total_loss = 1.164348
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.696802), count: 11, class_loss = 0.625086, iou_loss = 0.581077, total_loss = 1.206163
#  total_bbox = 1626340, rewritten_bbox = 0.591082 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827938), count: 4, class_loss = 0.176399, iou_loss = 0.124275, total_loss = 0.300674
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.778869), count: 2, class_loss = 0.424116, iou_loss = 0.074584, total_loss = 0.498700
#  total_bbox = 1626346, rewritten_bbox = 0.591080 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.778623), count: 6, class_loss = 0.231485, iou_loss = 0.218274, total_loss = 0.449759
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.850631), count: 6, class_loss = 0.023402, iou_loss = 0.056540, total_loss = 0.079943
#  total_bbox = 1626358, rewritten_bbox = 0.591075 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.775046), count: 7, class_loss = 0.378048, iou_loss = 0.424690, total_loss = 0.802739
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.812928), count: 8, class_loss = 0.843221, iou_loss = 0.212326, total_loss = 1.055547
#  total_bbox = 1626373, rewritten_bbox = 0.591070 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.813410), count: 9, class_loss = 0.307854, iou_loss = 0.301642, total_loss = 0.609497
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.534800), count: 3, class_loss = 0.619284, iou_loss = 0.709119, total_loss = 1.328403
#  total_bbox = 1626385, rewritten_bbox = 0.591065 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827472), count: 6, class_loss = 0.606758, iou_loss = 0.161909, total_loss = 0.768667
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.693202), count: 2, class_loss = 0.212861, iou_loss = 0.115015, total_loss = 0.327876
#  total_bbox = 1626393, rewritten_bbox = 0.591063 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.871120), count: 5, class_loss = 0.333192, iou_loss = 0.051851, total_loss = 0.385042
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.719049), count: 8, class_loss = 0.783841, iou_loss = 0.794287, total_loss = 1.578128
#  total_bbox = 1626406, rewritten_bbox = 0.591058 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.738958), count: 3, class_loss = 0.363249, iou_loss = 0.124941, total_loss = 0.488190
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.702314), count: 3, class_loss = 0.029101, iou_loss = 0.188416, total_loss = 0.217517
#  total_bbox = 1626412, rewritten_bbox = 0.591056 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.875673), count: 8, class_loss = 0.099947, iou_loss = 0.076995, total_loss = 0.176942
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.754309), count: 5, class_loss = 1.004113, iou_loss = 0.260293, total_loss = 1.264407
#  total_bbox = 1626425, rewritten_bbox = 0.591051 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.700473), count: 3, class_loss = 0.536403, iou_loss = 0.253487, total_loss = 0.789889
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.747908), count: 17, class_loss = 1.645125, iou_loss = 1.057563, total_loss = 2.702688
#  total_bbox = 1626445, rewritten_bbox = 0.591044 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.790689), count: 3, class_loss = 0.254921, iou_loss = 0.222988, total_loss = 0.477909
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.500409), count: 117, class_loss = 6.590270, iou_loss = 7.663728, total_loss = 14.253998
#  total_bbox = 1626565, rewritten_bbox = 0.591307 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.858349), count: 7, class_loss = 0.203531, iou_loss = 0.084158, total_loss = 0.287689
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.733340), count: 8, class_loss = 0.389213, iou_loss = 0.648887, total_loss = 1.038100
#  total_bbox = 1626580, rewritten_bbox = 0.591302 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.870847), count: 1, class_loss = 0.005190, iou_loss = 0.019536, total_loss = 0.024726
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.760313), count: 18, class_loss = 1.107215, iou_loss = 0.575941, total_loss = 1.683157
#  total_bbox = 1626599, rewritten_bbox = 0.591295 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.742925), count: 7, class_loss = 0.561711, iou_loss = 0.659674, total_loss = 1.221384
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.735367), count: 17, class_loss = 1.949363, iou_loss = 1.049300, total_loss = 2.998663
#  total_bbox = 1626623, rewritten_bbox = 0.591286 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.817608), count: 9, class_loss = 0.929273, iou_loss = 0.267349, total_loss = 1.196622
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.760172), count: 5, class_loss = 0.574472, iou_loss = 0.288436, total_loss = 0.862908
#  total_bbox = 1626637, rewritten_bbox = 0.591281 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.914907), count: 1, class_loss = 0.020758, iou_loss = 0.007215, total_loss = 0.027973
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.793433), count: 19, class_loss = 0.993383, iou_loss = 0.519990, total_loss = 1.513373
#  total_bbox = 1626657, rewritten_bbox = 0.591274 %
#
#  (next mAP calculation at 6000 iterations)
#
#  Tensor Cores are used.
#  Last accuracy mAP@0.50 = 87.36 %, best = 87.36 %
#  6000: 1.305676, 1.097141 avg loss, 0.000010 rate, 1.280799 seconds, 384000 images, 0.034693 hours left
# Resizing to initial size: 416 x 416  try to allocate additional workspace_size = 138.41 MB
#  CUDA allocate done!
# valid: Using default 'data/train.txt'
# valid: Using default 'dataset/train.txt'
#
#  calculation mAP (mean average precision)...
#  Detection layer: 16 - type = 28
#  Detection layer: 23 - type = 28
# 368libpng warning: iCCP: Not recognizing known sRGB profile that has been edited
# 592
#  detections_count = 8730, unique_truth_count = 2863
# class_id = 0, name = mask, ap = 91.26%   	 (TP = 2070, FP = 268)
# class_id = 1, name = w_mask, ap = 91.42%   	 (TP = 69, FP = 18)
# class_id = 2, name = no_mask, ap = 80.11%   	 (TP = 434, FP = 144)
#
#  for conf_thresh = 0.25, precision = 0.86, recall = 0.90, F1-score = 0.88
#  for conf_thresh = 0.25, TP = 2573, FP = 430, FN = 290, average IoU = 67.49 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.875980, or 87.60 %
# Total Detection Time: 11 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset
#
#  mean_average_precision (mAP@0.50) = 0.875979
# New best mAP!
# Saving weights to backup/yolov3-tiny-custom_best.weights
# Saving weights to backup/yolov3-tiny-custom_6000.weights
# Saving weights to backup/yolov3-tiny-custom_last.weights
# Saving weights to backup/yolov3-tiny-custom_final.weights
# If you want to train from the beginning, then use flag in the end of training command: -clear
# CPU times: user 1min 24s, sys: 8.65 s, total: 1min 33s
# Wall time: 1h 59min 35s

# %% [markdown]
# > ## 4) 모델 생성 확인

# %% [markdown]
# * Loss & mAP

# %%
from IPython.display import Image

Image('chart.png')

# %% [markdown]
# * 작업 경로 변경

# %%
# %cd darknet/
# Out:
# /content/yolo_custom_modeling/darknet

# %% [markdown]
# * yolov3-tiny-custom_final.weights 생성 확인

# %%
# !ls -l ../backup
# Out:
# total 305208
# -rw-r--r-- 1 root root 34723476 Apr  9 01:21 yolov3-tiny-custom_1000.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 01:42 yolov3-tiny-custom_2000.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 02:02 yolov3-tiny-custom_3000.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 02:21 yolov3-tiny-custom_4000.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 02:41 yolov3-tiny-custom_5000.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 03:01 yolov3-tiny-custom_6000.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 03:01 yolov3-tiny-custom_best.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 03:01 yolov3-tiny-custom_final.weights
# -rw-r--r-- 1 root root 34723476 Apr  9 03:01 yolov3-tiny-custom_last.weights

# %% [markdown]
# # VI. 학습결과 확인

# %% [markdown]
# > ## 1) 'coco.names' Update
#
# * 아래 내용으로 수정 후 진행
#
#  - no_mask
#  - mask

# %%
# !cp -f /content/yolo_custom_modeling/dataset/classes.names /content/yolo_custom_modeling/darknet/data/coco.names

# %% [markdown]
# > ## 2) Object Detection 실행

# %%
# -- mask_test는 1~10까지 임의로 변경하며 테스트 가능
# yolov3-tiny-custom.cfg 에서 Testing의 batch, subdivisions 주석 해제, Training에 주석 달기 
# !./darknet detect ../dataset/yolov3-tiny-custom.cfg ../backup/yolov3-tiny-custom_last.weights ../dataset/test/mask_test_5.png
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.7.0, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 4.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max                2x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv     24       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  24 0.004 BF
#   16 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   17 route  13 		                           ->   13 x  13 x 256
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8 	                           ->   26 x  26 x 384
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv     24       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  24 0.008 BF
#   23 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.451
# avg_outputs = 325268
#  Allocate additional workspace_size = 134.22 MB
# Loading weights from ../backup/yolov3-tiny-custom_last.weights...
#  seen 64, trained: 384 K-images (6 Kilo-batches_64)
# Done! Loaded 24 layers from weights-file
#  Detection layer: 16 - type = 28
#  Detection layer: 23 - type = 28
# ../dataset/test/mask_test_5.png: Predicted in 644.299000 milli-seconds.
# mask: 77%
# mask: 85%
# mask: 99%
# no_mask: 98%
# mask: 98%
# w_mask: 92%
# mask: 100%
# mask: 47%
# mask: 80%
# mask: 46%
# mask: 83%
# mask: 87%
# mask: 93%
# mask: 91%
# mask: 100%
# mask: 84%
# mask: 100%
# mask: 100%
# mask: 69%
# mask: 100%
# mask: 93%
# mask: 93%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:837230): Gtk-WARNING **: 03:01:54.042: cannot open display:

# %% [markdown]
# > ## 3) Object Detection 결과 확인

# %%
import matplotlib.pyplot as plt
from PIL import Image

PIL_img = Image.open('predictions.jpg')

plt.figure(figsize = (12, 9))
plt.imshow(PIL_img)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
