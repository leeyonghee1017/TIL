# %% [markdown]
# # TensorFlow Hub SSD
#
# > ## Image & Video Object Detection
#
# * Pretrained 모델 로드 후 Object Detection 수행

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. TensorFlow Version

# %% [markdown]
# * Import TensorFlow

# %%
import tensorflow as tf

# %% [markdown]
# * TensorFlow Version

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# * GPU Information

# %%
# !nvidia-smi
# Out:
# /bin/bash: nvidia-smi: command not found

# %% [markdown]
# # II. Image File Download

# %% [markdown]
# * KIA.jpg 다운로드

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/image/KIA.jpg
# Out:
# --2023-04-09 00:54:17--  https://raw.githubusercontent.com/rusita-ai/pyData/master/image/KIA.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65805 (64K) [image/jpeg]
# Saving to: ‘KIA.jpg’
#
# KIA.jpg             100%[===================>]  64.26K  --.-KB/s    in 0.004s
#
# 2023-04-09 00:54:17 (15.0 MB/s) - ‘KIA.jpg’ saved [65805/65805]

# %% [markdown]
# * KIA.jpg 확인

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/KIA.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize = (9, 9))
plt.imshow(img_rgb)
plt.xticks([])
plt.yticks([])
plt.show()

print('Image Shape:', img.shape)
# Out:
# Image Shape: (429, 600, 3)

# %% [markdown]
# # III. TenSorFlow Hub

# %% [markdown]
# > ## 1) SSD Model Load
#
# * detector_model

# %%
import tensorflow_hub as hub

module_ssd = 'https://tfhub.dev/tensorflow/ssd_mobilenet_v2/2'

detector_model = hub.load(module_ssd)

# %% [markdown]
# > ## 2) Class ID Setting
#
# * COCO Dataset
#  - TensorFlow SSD

# %%
labels_to_names = {1:'person',2:'bicycle',3:'car',4:'motorcycle',5:'airplane',6:'bus',7:'train',8:'truck',9:'boat',10:'traffic light',
                   11:'fire hydrant',12:'street sign',13:'stop sign',14:'parking meter',15:'bench',16:'bird',17:'cat',18:'dog',19:'horse',20:'sheep',
                   21:'cow',22:'elephant',23:'bear',24:'zebra',25:'giraffe',26:'hat',27:'backpack',28:'umbrella',29:'shoe',30:'eye glasses',
                   31:'handbag',32:'tie',33:'suitcase',34:'frisbee',35:'skis',36:'snowboard',37:'sports ball',38:'kite',39:'baseball bat',40:'baseball glove',
                   41:'skateboard',42:'surfboard',43:'tennis racket',44:'bottle',45:'plate',46:'wine glass',47:'cup',48:'fork',49:'knife',50:'spoon',
                   51:'bowl',52:'banana',53:'apple',54:'sandwich',55:'orange',56:'broccoli',57:'carrot',58:'hot dog',59:'pizza',60:'donut',
                   61:'cake',62:'chair',63:'couch',64:'potted plant',65:'bed',66:'mirror',67:'dining table',68:'window',69:'desk',70:'toilet',
                   71:'door',72:'tv',73:'laptop',74:'mouse',75:'remote',76:'keyboard',77:'cell phone',78:'microwave',79:'oven',80:'toaster',
                   81:'sink',82:'refrigerator',83:'blender',84:'book',85:'clock',86:'vase',87:'scissors',88:'teddy bear',89:'hair drier',90:'toothbrush',
                   91:'hair brush'}

# %% [markdown]
# # IV. Image Inference

# %% [markdown]
# >## 1) Inference 수행 및 시각화

# %%
import cv2
import matplotlib.pyplot as plt

img_array = cv2.cvtColor(cv2.imread('/content/KIA.jpg'), cv2.COLOR_BGR2RGB)

# 원복을 위한 원본 이미지 shape 정보 저장
height = img_array.shape[0]
width = img_array.shape[1]
# 결과 출력 생성용 백업 이미지
draw_img = img_array.copy()

# Bounding Box 및 Caption 글자색
green_color = (0, 255, 0)
red_color = (255, 0, 0)

# Rank 4 Tensor 변환
img_tensor = tf.convert_to_tensor(img_array, dtype = tf.uint8)[tf.newaxis, ...]


# SSD Object Detection 수행
result = detector_model(img_tensor)
# Dictionary to Array
result = {key:value.numpy() for key,value in result.items()}

# Threshold and Detection Count
SCORE_THRESHOLD = 0.5
OBJECT_DEFAULT_COUNT = 100

for i in range(min(result['detection_scores'][0].shape[0], OBJECT_DEFAULT_COUNT)):
  score = result['detection_scores'][0, i]
  if score < SCORE_THRESHOLD:
    break
  box = result['detection_boxes'][0, i]

# Bounding Box 정보: ymin, xmin, ymax, xmax 순서 주의
  left = box[1] * width
  top = box[0] * height
  right = box[3] * width
  bottom = box[2] * height

  class_id = result['detection_classes'][0, i]
  caption = "{}: {:.4f}".format(labels_to_names[class_id], score)
  print(caption)

  cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color = green_color, thickness = 2)
  cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.4, red_color, 1)

plt.figure(figsize = (9, 9))
plt.imshow(draw_img)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# car: 0.8036
# person: 0.6680
# person: 0.6167
# person: 0.5495
# person: 0.5462

# %% [markdown]
# > ## 2) get_detected_img( ) 정의

# %%
import time

def get_detected_img(model, img_array, score_threshold, object_show_count = 100, is_print = True):   
  height = img_array.shape[0]
  width = img_array.shape[1]

  draw_img = img_array.copy()

  green_color = (0, 255, 0)
  red_color = (255, 0, 0)

  img_tensor = tf.convert_to_tensor(img_array, dtype=tf.uint8)[tf.newaxis, ...]

  start_time = time.time()
  result = model(img_tensor)
  result = {key:value.numpy() for key,value in result.items()}

  for i in range(min(result['detection_scores'][0].shape[0], object_show_count)):
    score = result['detection_scores'][0, i]
    if score < score_threshold:
      break
    box = result['detection_boxes'][0, i]

    left = box[1] * width
    top = box[0] * height
    right = box[3] * width
    bottom = box[2] * height

    class_id = result['detection_classes'][0, i]
    caption = "{}: {:.4f}".format(labels_to_names[class_id], score)
    print(caption)

    cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color = green_color, thickness = 2)
    cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.4, red_color, 1)

  if is_print:
    print('Detection Time:',round(time.time() - start_time, 2), 'Seconds')

  return draw_img

# %% [markdown]
# > ## 3) get_detected_img( ) 실행

# %%
img_array = cv2.cvtColor(cv2.imread('/content/KIA.jpg'), cv2.COLOR_BGR2RGB)
draw_img = get_detected_img(detector_model, img_array, score_threshold = 0.5, object_show_count = 100, is_print = True)

plt.figure(figsize = (9, 9))
plt.imshow(draw_img)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# car: 0.8036
# person: 0.6680
# person: 0.6167
# person: 0.5495
# person: 0.5462
# Detection Time: 0.11 Seconds

# %% [markdown]
# # V. Video Inference

# %% [markdown]
# > ## 1) matrix.mp4 Download

# %%
# !wget https://raw.githubusercontent.com/rusita-ai/pyData/master/image/matrix.mp4
# Out:
# --2023-04-09 00:54:48--  https://raw.githubusercontent.com/rusita-ai/pyData/master/image/matrix.mp4
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 386522 (377K) [application/octet-stream]
# Saving to: ‘matrix.mp4’
#
# matrix.mp4          100%[===================>] 377.46K  --.-KB/s    in 0.01s
#
# 2023-04-09 00:54:48 (28.5 MB/s) - ‘matrix.mp4’ saved [386522/386522]

# %% [markdown]
# > ## 2) do_detected_video( ) 정의

# %%
def do_detected_video(model, input_path, output_path, score_threshold, is_print):
    
    cap = cv2.VideoCapture(input_path)

    codec = cv2.VideoWriter_fourcc(*'XVID')

    vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    vid_fps = cap.get(cv2.CAP_PROP_FPS)

    vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size) 

    frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print('Frame Count:', frame_cnt)

    green_color = (0, 255, 0)
    red_color = (255, 0, 0)
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('No more Frames')
            break
        
        img_frame = get_detected_img(model, img_frame, score_threshold = score_threshold, object_show_count = 100, is_print = is_print)
        
        vid_writer.write(img_frame)

    vid_writer.release()
    cap.release()

# %% [markdown]
# > ## 3) do_detected_video( ) 실행

# %%
# %%time

do_detected_video(detector_model, '/content/matrix.mp4', '/content/matrix_thssd.mp4', 0.4, True)
# Out:
# Frame Count: 134
# airplane: 0.6771
# airplane: 0.6314
# Detection Time: 0.08 Seconds
# airplane: 0.6049
# car: 0.4959
# airplane: 0.4398
# Detection Time: 0.08 Seconds
# airplane: 0.6474
# airplane: 0.6461
# Detection Time: 0.09 Seconds
# airplane: 0.6516
# car: 0.6037
# airplane: 0.5687
# car: 0.5305
# car: 0.5138
# car: 0.5132
# airplane: 0.4904
# car: 0.4519
# car: 0.4252
# Detection Time: 0.08 Seconds
# airplane: 0.6489
# car: 0.6016
# airplane: 0.5685
# car: 0.5270
# car: 0.5162
# car: 0.5120
# airplane: 0.4834
# car: 0.4496
# car: 0.4186
# airplane: 0.4031
# truck: 0.4006
# Detection Time: 0.08 Seconds
# airplane: 0.7381
# car: 0.5255
# airplane: 0.5218
# airplane: 0.4635
# car: 0.4374
# airplane: 0.4203
# Detection Time: 0.08 Seconds
# airplane: 0.6534
# motorcycle: 0.6106
# car: 0.5539
# bicycle: 0.4168
# car: 0.4161
# car: 0.4027
# Detection Time: 0.07 Seconds
# person: 0.7008
# car: 0.6146
# motorcycle: 0.5913
# car: 0.4202
# Detection Time: 0.08 Seconds
# person: 0.5658
# car: 0.4743
# car: 0.4482
# motorcycle: 0.4343
# Detection Time: 0.09 Seconds
# person: 0.5729
# person: 0.4580
# motorcycle: 0.4509
# backpack: 0.4452
# car: 0.4296
# Detection Time: 0.1 Seconds
# person: 0.5478
# car: 0.5254
# airplane: 0.4351
# Detection Time: 0.08 Seconds
# car: 0.6052
# car: 0.5119
# person: 0.4932
# airplane: 0.4765
# truck: 0.4623
# truck: 0.4438
# Detection Time: 0.09 Seconds
# car: 0.5785
# car: 0.5035
# person: 0.5012
# airplane: 0.4784
# truck: 0.4731
# truck: 0.4374
# Detection Time: 0.08 Seconds
# car: 0.6495
# motorcycle: 0.5615
# person: 0.5589
# truck: 0.5116
# car: 0.4911
# car: 0.4899
# Detection Time: 0.09 Seconds
# car: 0.7684
# person: 0.5594
# car: 0.5439
# motorcycle: 0.4858
# car: 0.4186
# truck: 0.4095
# Detection Time: 0.08 Seconds
# car: 0.7654
# car: 0.6277
# person: 0.5582
# motorcycle: 0.5146
# Detection Time: 0.08 Seconds
# car: 0.7500
# car: 0.4801
# person: 0.4687
# person: 0.4005
# Detection Time: 0.09 Seconds
# car: 0.7537
# person: 0.4726
# car: 0.4709
# Detection Time: 0.09 Seconds
# car: 0.7709
# car: 0.5686
# person: 0.5365
# motorcycle: 0.4860
# person: 0.4819
# truck: 0.4277
# Detection Time: 0.08 Seconds
# car: 0.7814
# person: 0.6242
# motorcycle: 0.4456
# truck: 0.4040
# Detection Time: 0.08 Seconds
# person: 0.6322
# person: 0.6221
# Detection Time: 0.09 Seconds
# person: 0.5813
# person: 0.5744
# vase: 0.4386
# potted plant: 0.4154
# Detection Time: 0.09 Seconds
# person: 0.5678
# person: 0.5496
# vase: 0.4505
# potted plant: 0.4299
# Detection Time: 0.08 Seconds
# person: 0.5953
# person: 0.5356
# potted plant: 0.4536
# vase: 0.4407
# Detection Time: 0.08 Seconds
# person: 0.6428
# person: 0.6281
# Detection Time: 0.08 Seconds
# person: 0.7160
# person: 0.5201
# Detection Time: 0.09 Seconds
# vase: 0.5832
# potted plant: 0.5431
# person: 0.5206
# vase: 0.4763
# Detection Time: 0.09 Seconds
# vase: 0.5728
# potted plant: 0.5399
# person: 0.5115
# vase: 0.4616
# Detection Time: 0.08 Seconds
# person: 0.5270
# person: 0.5003
# potted plant: 0.4801
# vase: 0.4444
# Detection Time: 0.08 Seconds
# person: 0.5519
# vase: 0.5194
# potted plant: 0.4913
# handbag: 0.4626
# bird: 0.4113
# Detection Time: 0.09 Seconds
# potted plant: 0.6008
# vase: 0.5163
# Detection Time: 0.08 Seconds
# person: 0.6071
# potted plant: 0.5146
# vase: 0.4086
# Detection Time: 0.09 Seconds
# No more Frames
# CPU times: user 19.3 s, sys: 563 ms, total: 19.9 s
# Wall time: 12.6 s

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
