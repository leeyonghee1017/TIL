# %% [markdown]
# # CIFAR 10 - Functional API Modeling
#
# * Categorical Classification

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Tensorflow

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.11.0'

# %% [markdown]
# # I. CIFAR 10 Data_Set Load & Review

# %% [markdown]
# > ## 1) Load CIFAR 10 Data_Set

# %%
from tensorflow.keras.datasets import cifar10

(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# * Train_Data Information

# %%
print(len(X_train))
print(X_train.shape)

print(len(y_train))
print(y_train[0:5])
# Out:
# 50000
# (50000, 32, 32, 3)
# 50000
# [[6]
#  [9]
#  [9]
#  [4]
#  [1]]

# %% [markdown]
# * Test_Data Information

# %%
print(len(X_test))
print(X_test.shape)

print(len(y_test))
print(y_test[0:5])
# Out:
# 10000
# (10000, 32, 32, 3)
# 10000
# [[3]
#  [8]
#  [8]
#  [0]
#  [6]]

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# > ## 3) train_test_split( )
#
# * Train(40,000) vs. Validation(10,000)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train,
                                                      test_size = 0.2,
                                                      random_state = 2045)

X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((40000, 32, 32, 3), (40000, 10), (10000, 32, 32, 3), (10000, 10))

# %% [markdown]
# # III. Keras Functional API Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

input_img = layers.Input((32, 32, 3))

x = layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='valid')(input_img)
x = layers.ReLU()(x)

x = layers.MaxPool2D(pool_size=(2,2))(x)

x = layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='valid')(x)
x = layers.ReLU()(x)

x = layers.MaxPool2D(pool_size=(2,2))(x)

x = layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='valid')(x)
x = layers.ReLU()(x)


x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(64)(x)
x = layers.ReLU()(x)

x = layers.Dense(10)(x)
output_y_hat = layers.Activation('softmax')(x)

CIFAR = models.Model(input_img, output_y_hat)

# %% [markdown]
# * 모델 구조 확인

# %%
CIFAR.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  re_lu (ReLU)                (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  re_lu_1 (ReLU)              (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  re_lu_2 (ReLU)              (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  re_lu_3 (ReLU)              (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
#  activation (Activation)     (None, 10)                0
#
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
CIFAR.compile(loss = 'categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_CIFAR = CIFAR.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 313/313 [==============================] - 13s 9ms/step - loss: 1.7635 - accuracy: 0.3447 - val_loss: 1.4393 - val_accuracy: 0.4675
# Epoch 2/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4165 - accuracy: 0.4836 - val_loss: 1.3316 - val_accuracy: 0.5259
# Epoch 3/100
# 313/313 [==============================] - 3s 9ms/step - loss: 1.2803 - accuracy: 0.5417 - val_loss: 1.1673 - val_accuracy: 0.5787
# Epoch 4/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1810 - accuracy: 0.5781 - val_loss: 1.0857 - val_accuracy: 0.6163
# Epoch 5/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.1141 - accuracy: 0.6057 - val_loss: 1.0425 - val_accuracy: 0.6368
# Epoch 6/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0564 - accuracy: 0.6251 - val_loss: 0.9866 - val_accuracy: 0.6482
# Epoch 7/100
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0106 - accuracy: 0.6443 - val_loss: 0.9394 - val_accuracy: 0.6735
# Epoch 8/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.9755 - accuracy: 0.6544 - val_loss: 0.9188 - val_accuracy: 0.6808
# Epoch 9/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.9418 - accuracy: 0.6686 - val_loss: 0.8947 - val_accuracy: 0.6925
# Epoch 10/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9029 - accuracy: 0.6818 - val_loss: 0.8836 - val_accuracy: 0.6903
# Epoch 11/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8868 - accuracy: 0.6853 - val_loss: 0.8556 - val_accuracy: 0.6965
# Epoch 12/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.8527 - accuracy: 0.7011 - val_loss: 0.8434 - val_accuracy: 0.7023
# Epoch 13/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.8284 - accuracy: 0.7098 - val_loss: 0.8264 - val_accuracy: 0.7127
# Epoch 14/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.8137 - accuracy: 0.7118 - val_loss: 0.8174 - val_accuracy: 0.7117
# Epoch 15/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7893 - accuracy: 0.7206 - val_loss: 0.7960 - val_accuracy: 0.7226
# Epoch 16/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7726 - accuracy: 0.7265 - val_loss: 0.7996 - val_accuracy: 0.7250
# Epoch 17/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7529 - accuracy: 0.7334 - val_loss: 0.7791 - val_accuracy: 0.7280
# Epoch 18/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7391 - accuracy: 0.7387 - val_loss: 0.7823 - val_accuracy: 0.7263
# Epoch 19/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.7167 - accuracy: 0.7461 - val_loss: 0.7656 - val_accuracy: 0.7356
# Epoch 20/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.7029 - accuracy: 0.7520 - val_loss: 0.7390 - val_accuracy: 0.7442
# Epoch 21/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6918 - accuracy: 0.7548 - val_loss: 0.7493 - val_accuracy: 0.7414
# Epoch 22/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6792 - accuracy: 0.7582 - val_loss: 0.7488 - val_accuracy: 0.7407
# Epoch 23/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6637 - accuracy: 0.7648 - val_loss: 0.7320 - val_accuracy: 0.7459
# Epoch 24/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6502 - accuracy: 0.7706 - val_loss: 0.7245 - val_accuracy: 0.7514
# Epoch 25/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6444 - accuracy: 0.7713 - val_loss: 0.7266 - val_accuracy: 0.7495
# Epoch 26/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6244 - accuracy: 0.7767 - val_loss: 0.7376 - val_accuracy: 0.7427
# Epoch 27/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6254 - accuracy: 0.7784 - val_loss: 0.7298 - val_accuracy: 0.7525
# Epoch 28/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.6093 - accuracy: 0.7838 - val_loss: 0.7303 - val_accuracy: 0.7522
# Epoch 29/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6006 - accuracy: 0.7848 - val_loss: 0.7211 - val_accuracy: 0.7533
# Epoch 30/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5980 - accuracy: 0.7867 - val_loss: 0.7302 - val_accuracy: 0.7505
# Epoch 31/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5909 - accuracy: 0.7917 - val_loss: 0.7194 - val_accuracy: 0.7557
# Epoch 32/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5807 - accuracy: 0.7929 - val_loss: 0.7452 - val_accuracy: 0.7521
# Epoch 33/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5714 - accuracy: 0.7970 - val_loss: 0.7232 - val_accuracy: 0.7542
# Epoch 34/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.5584 - accuracy: 0.8019 - val_loss: 0.7036 - val_accuracy: 0.7639
# Epoch 35/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.5609 - accuracy: 0.7985 - val_loss: 0.7081 - val_accuracy: 0.7608
# Epoch 36/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5511 - accuracy: 0.8026 - val_loss: 0.7240 - val_accuracy: 0.7607
# Epoch 37/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5415 - accuracy: 0.8051 - val_loss: 0.7078 - val_accuracy: 0.7624
# Epoch 38/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5343 - accuracy: 0.8085 - val_loss: 0.7357 - val_accuracy: 0.7581
# Epoch 39/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.5345 - accuracy: 0.8076 - val_loss: 0.7153 - val_accuracy: 0.7611
# Epoch 40/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5181 - accuracy: 0.8145 - val_loss: 0.7267 - val_accuracy: 0.7585
# Epoch 41/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5172 - accuracy: 0.8152 - val_loss: 0.7121 - val_accuracy: 0.7648
# Epoch 42/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5094 - accuracy: 0.8166 - val_loss: 0.7107 - val_accuracy: 0.7626
# Epoch 43/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5091 - accuracy: 0.8175 - val_loss: 0.7184 - val_accuracy: 0.7589
# Epoch 44/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.5047 - accuracy: 0.8174 - val_loss: 0.7266 - val_accuracy: 0.7626
# Epoch 45/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4963 - accuracy: 0.8218 - val_loss: 0.7529 - val_accuracy: 0.7538
# Epoch 46/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4972 - accuracy: 0.8203 - val_loss: 0.7257 - val_accuracy: 0.7616
# Epoch 47/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4874 - accuracy: 0.8227 - val_loss: 0.7173 - val_accuracy: 0.7646
# Epoch 48/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4757 - accuracy: 0.8290 - val_loss: 0.7359 - val_accuracy: 0.7551
# Epoch 49/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4737 - accuracy: 0.8298 - val_loss: 0.7227 - val_accuracy: 0.7645
# Epoch 50/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4768 - accuracy: 0.8282 - val_loss: 0.7182 - val_accuracy: 0.7664
# Epoch 51/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4744 - accuracy: 0.8296 - val_loss: 0.7281 - val_accuracy: 0.7630
# Epoch 52/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4680 - accuracy: 0.8331 - val_loss: 0.7203 - val_accuracy: 0.7614
# Epoch 53/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4648 - accuracy: 0.8321 - val_loss: 0.7306 - val_accuracy: 0.7634
# Epoch 54/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4542 - accuracy: 0.8353 - val_loss: 0.7208 - val_accuracy: 0.7674
# Epoch 55/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4475 - accuracy: 0.8366 - val_loss: 0.7174 - val_accuracy: 0.7659
# Epoch 56/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4430 - accuracy: 0.8401 - val_loss: 0.7557 - val_accuracy: 0.7592
# Epoch 57/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4547 - accuracy: 0.8370 - val_loss: 0.7175 - val_accuracy: 0.7657
# Epoch 58/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4389 - accuracy: 0.8403 - val_loss: 0.7348 - val_accuracy: 0.7632
# Epoch 59/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4383 - accuracy: 0.8414 - val_loss: 0.7370 - val_accuracy: 0.7636
# Epoch 60/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4355 - accuracy: 0.8420 - val_loss: 0.7268 - val_accuracy: 0.7656
# Epoch 61/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4321 - accuracy: 0.8436 - val_loss: 0.7220 - val_accuracy: 0.7689
# Epoch 62/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4250 - accuracy: 0.8471 - val_loss: 0.7377 - val_accuracy: 0.7718
# Epoch 63/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4217 - accuracy: 0.8471 - val_loss: 0.7158 - val_accuracy: 0.7710
# Epoch 64/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4268 - accuracy: 0.8475 - val_loss: 0.7498 - val_accuracy: 0.7650
# Epoch 65/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.4264 - accuracy: 0.8460 - val_loss: 0.7560 - val_accuracy: 0.7570
# Epoch 66/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.4181 - accuracy: 0.8496 - val_loss: 0.7774 - val_accuracy: 0.7623
# Epoch 67/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4238 - accuracy: 0.8467 - val_loss: 0.7430 - val_accuracy: 0.7691
# Epoch 68/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4079 - accuracy: 0.8515 - val_loss: 0.7660 - val_accuracy: 0.7714
# Epoch 69/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4137 - accuracy: 0.8496 - val_loss: 0.7507 - val_accuracy: 0.7641
# Epoch 70/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4068 - accuracy: 0.8525 - val_loss: 0.7366 - val_accuracy: 0.7714
# Epoch 71/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.4070 - accuracy: 0.8529 - val_loss: 0.7421 - val_accuracy: 0.7645
# Epoch 72/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4069 - accuracy: 0.8530 - val_loss: 0.7727 - val_accuracy: 0.7606
# Epoch 73/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3966 - accuracy: 0.8579 - val_loss: 0.7610 - val_accuracy: 0.7657
# Epoch 74/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3998 - accuracy: 0.8578 - val_loss: 0.7752 - val_accuracy: 0.7652
# Epoch 75/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3992 - accuracy: 0.8556 - val_loss: 0.7743 - val_accuracy: 0.7583
# Epoch 76/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3924 - accuracy: 0.8576 - val_loss: 0.7722 - val_accuracy: 0.7659
# Epoch 77/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3981 - accuracy: 0.8568 - val_loss: 0.7597 - val_accuracy: 0.7665
# Epoch 78/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3893 - accuracy: 0.8583 - val_loss: 0.7616 - val_accuracy: 0.7655
# Epoch 79/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3844 - accuracy: 0.8594 - val_loss: 0.7774 - val_accuracy: 0.7623
# Epoch 80/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3841 - accuracy: 0.8610 - val_loss: 0.7555 - val_accuracy: 0.7657
# Epoch 81/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3853 - accuracy: 0.8593 - val_loss: 0.7782 - val_accuracy: 0.7627
# Epoch 82/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3834 - accuracy: 0.8611 - val_loss: 0.7578 - val_accuracy: 0.7692
# Epoch 83/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3760 - accuracy: 0.8619 - val_loss: 0.7738 - val_accuracy: 0.7659
# Epoch 84/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3843 - accuracy: 0.8601 - val_loss: 0.7751 - val_accuracy: 0.7654
# Epoch 85/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3758 - accuracy: 0.8662 - val_loss: 0.7477 - val_accuracy: 0.7646
# Epoch 86/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3849 - accuracy: 0.8621 - val_loss: 0.7642 - val_accuracy: 0.7613
# Epoch 87/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.3762 - accuracy: 0.8637 - val_loss: 0.7933 - val_accuracy: 0.7620
# Epoch 88/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3724 - accuracy: 0.8632 - val_loss: 0.7720 - val_accuracy: 0.7664
# Epoch 89/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3709 - accuracy: 0.8650 - val_loss: 0.7795 - val_accuracy: 0.7666
# Epoch 90/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3733 - accuracy: 0.8669 - val_loss: 0.7674 - val_accuracy: 0.7701
# Epoch 91/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3749 - accuracy: 0.8640 - val_loss: 0.7801 - val_accuracy: 0.7650
# Epoch 92/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3812 - accuracy: 0.8615 - val_loss: 0.8329 - val_accuracy: 0.7578
# Epoch 93/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3608 - accuracy: 0.8695 - val_loss: 0.7943 - val_accuracy: 0.7643
# Epoch 94/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3595 - accuracy: 0.8693 - val_loss: 0.7708 - val_accuracy: 0.7684
# Epoch 95/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3610 - accuracy: 0.8689 - val_loss: 0.7855 - val_accuracy: 0.7674
# Epoch 96/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3532 - accuracy: 0.8720 - val_loss: 0.7948 - val_accuracy: 0.7639
# Epoch 97/100
# 313/313 [==============================] - 2s 8ms/step - loss: 0.3586 - accuracy: 0.8685 - val_loss: 0.8041 - val_accuracy: 0.7559
# Epoch 98/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.3590 - accuracy: 0.8687 - val_loss: 0.7763 - val_accuracy: 0.7665
# Epoch 99/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3554 - accuracy: 0.8710 - val_loss: 0.7966 - val_accuracy: 0.7647
# Epoch 100/100
# 313/313 [==============================] - 2s 7ms/step - loss: 0.3517 - accuracy: 0.8712 - val_loss: 0.8157 - val_accuracy: 0.7626
# CPU times: user 4min 4s, sys: 20.7 s, total: 4min 25s
# Wall time: 4min 24s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_CIFAR.history['loss']) + 1)

plt.figure(figsize = (15, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, Hist_CIFAR.history['loss'], 'b-')
plt.plot(epochs, Hist_CIFAR.history['val_loss'], 'r--')
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs, Hist_CIFAR.history['accuracy'], 'b-')
plt.plot(epochs, Hist_CIFAR.history['val_accuracy'], 'r--')
plt.title('Training & Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.grid()

plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = CIFAR.evaluate(X_test, y_test, verbose = 0)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# Loss = 0.85262
# Accuracy = 0.75510

# %% [markdown]
# # IV. 성능평가

# %% [markdown]
# > ## 1) Label Name 지정

# %%
import numpy as np

CLASSES = np.array(['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 
                    'Dog', 'Frog', 'Horse', 'Ship', 'Truck'])

preds = CIFAR.predict(X_test, verbose = 0)
preds_single = CLASSES[np.argmax(preds, axis = -1)]
actual_single = CLASSES[np.argmax(y_test, axis = -1)]

# %% [markdown]
# > ## 2) 비교 시각화

# %%
import matplotlib.pyplot as plt

n_to_show = 10
indices = np.random.choice(range(len(X_test)), n_to_show)

fig = plt.figure(figsize = (15, 3))
fig.subplots_adjust(hspace = 0.4, wspace = 0.4)

for i, idx in enumerate(indices):
    img = X_test[idx]
    ax = fig.add_subplot(1, n_to_show, i + 1)
    ax.axis('off')
    ax.text(0.5, -0.35, 
            'Pred = ' + str(preds_single[idx]), 
            fontsize = 10, 
            ha = 'center', 
            transform = ax.transAxes) 
    ax.text(0.5, -0.7, 
            'Act = ' + str(actual_single[idx]), 
            fontsize = 10, 
            ha = 'center', 
            transform = ax.transAxes)
    ax.imshow(img)

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
